# %%
import sys
sys.path.append('F:\Cambridge\Project\MHMC-for-VAE/hmc_pytorch')
from hmc_base_pytorch import *
from hmc_unconstrained_pytorch import *
import autograd.numpy as np
import torch
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.distributions.normal import Normal
import matplotlib.pyplot as plt

# %% [markdown]
# # Get pdf p(y) of proxy variable y for x = g(y) where p(x) is known

# %%
def reparameter_pdf(transform, x_pdf, y):
    '''
    transform: function x = g(y) that transforms random variable y into x
    x_pdf: pdf of x
    '''
    # get gradient g'(y)
    #y.grad.zero_()
    #yy = torch.tensor([y.item()], requires_grad=True)
    #y.retain_grad()
    yy = y.clone()
    yy.retain_grad()
    x = transform(yy)
    print("x "+str(x))
    x.backward(retain_graph=True)
    print("y grad "+str(yy.grad))
    grad = torch.abs(yy.grad).float()

    
    # get p_x(x)
    px = x_pdf(x)
    print("px "+str(px))
    result = px*grad
    yy.grad.data.zero_()
    print("result "+str(result))
    #print(px.dtype)
    return result

# %%
def transform(y):
    return torch.log(1 + torch.exp(y))

def x_pdf(x):
    m = Normal(torch.tensor([0.]), torch.tensor([1.]))
    m.requires_grad=True
    n = torch.exp(m.log_prob(x))
    #n.requires_grad=True
    return n

def energy_function(y, cache):
    y.retain_grad()
    p = reparameter_pdf(transform, x_pdf, y)
    #y.grad.zero_()
    return 0-torch.log(p)

# %%
"""
def energy_function(y, cache):
    y.retain_grad()
    m = Normal(torch.tensor([0.]), torch.tensor([1.]))
    n = torch.exp(m.log_prob(y))
    return 0 - torch.log(n)
    
def gradient(pos, cache):
    pos.retain_grad()
    r = energy_function(pos, cache)
    r.backward(retain_graph=True)
    g = pos.grad.clone()
    
    print("g:"+str(pos.grad))
    #pos.grad.zero_()
    pos.grad.data.zero_()
    return g
    
pos = torch.tensor([0.], requires_grad=True)
gradient(pos, None)
"""
# Out:
# '\ndef energy_function(y, cache):\n    y.retain_grad()\n    m = Normal(torch.tensor([0.]), torch.tensor([1.]))\n    n = torch.exp(m.log_prob(y))\n    return 0 - torch.log(n)\n    \ndef gradient(pos, cache):\n    pos.retain_grad()\n    r = energy_function(pos, cache)\n    r.backward(retain_graph=True)\n    g = pos.grad.clone()\n    \n    print("g:"+str(pos.grad))\n    #pos.grad.zero_()\n    pos.grad.data.zero_()\n    return g\n    \npos = torch.tensor([0.], requires_grad=True)\ngradient(pos, None)\n'

# %%
y = torch.tensor([0.], requires_grad=True)
transform(y).requires_grad
#energy_function(y, None).requires_grad
# Out:
# True

# %%
sampler = IsotropicHmcSampler(energy_function, energy_grad=None, prng=None,
                 mom_resample_coeff=1., dtype=np.float64)

# %%
init = torch.tensor([0.], requires_grad=True)
pos_samples, mom_samples, ratio = sampler.get_samples(init, 0.1, 3, 500, torch.tensor([1.], requires_grad=True))
num = pos_samples.shape[0]
y_list = []
for i in range(num):
    y_list.append(pos_samples[i].item())
# Out:
# ========== 1st hamiltonian ==============
# x tensor([ 0.6931])
# y grad tensor([ 0.5000])
# px tensor([ 0.3137])
# result tensor([ 0.1569])
# Sample: 1
# ========== simulate ==============
# pos:tensor([ 0.]) True
# ------calling energy function------
# x tensor([ 0.6931])
# y grad tensor([ 0.5000])
# px tensor([ 0.3137])
# result tensor([ 0.1569])
# g:tensor([ 0.8466])
# grad1:tensor([ 0.8466])
# momtensor([-1.4303])
# ------calling energy function------
# x tensor([ 0.6222])
# y grad tensor([ 0.4633])
# px tensor([ 0.3287])
# result tensor([ 0.1523])
# g:tensor([ 0.7515])
# ------calling energy function------
# x tensor([ 0.5535])
# y grad tensor([ 0.4251])
# px tensor([ 0.3423])
# result tensor([ 0.1455])
# g:tensor([ 0.6603])
# ------calling energy function------
# x tensor([ 0.4880])
# y grad tensor([ 0.3862])
# px tensor([ 0.3542])
# result tensor([ 0.1368])
# g:tensor([ 0.5746])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4880])
# y grad tensor([ 0.3862])
# px tensor([ 0.3542])
# result tensor([ 0.1368])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6931])
# y grad tensor([ 0.5000])
# px tensor([ 0.3137])
# result tensor([ 0.1569])
# Sample: 2
# ========== simulate ==============
# pos:tensor([ 0.]) True
# ------calling energy function------
# x tensor([ 0.6931])
# y grad tensor([ 0.5000])
# px tensor([ 0.3137])
# result tensor([ 0.1569])
# g:tensor([ 0.8466])
# grad1:tensor([ 0.8466])
# momtensor([ 1.1851])
# ------calling energy function------
# x tensor([ 0.7519])
# y grad tensor([ 0.5285])
# px tensor([ 0.3007])
# result tensor([ 0.1589])
# g:tensor([ 0.9260])
# ------calling energy function------
# x tensor([ 0.8088])
# y grad tensor([ 0.5546])
# px tensor([ 0.2876])
# result tensor([ 0.1595])
# g:tensor([ 1.0032])
# ------calling energy function------
# x tensor([ 0.8626])
# y grad tensor([ 0.5779])
# px tensor([ 0.2750])
# result tensor([ 0.1589])
# g:tensor([ 1.0764])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8626])
# y grad tensor([ 0.5779])
# px tensor([ 0.2750])
# result tensor([ 0.1589])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8626])
# y grad tensor([ 0.5779])
# px tensor([ 0.2750])
# result tensor([ 0.1589])
# Sample: 3
# ========== simulate ==============
# pos:tensor([ 0.3143]) True
# ------calling energy function------
# x tensor([ 0.8626])
# y grad tensor([ 0.5779])
# px tensor([ 0.2750])
# result tensor([ 0.1589])
# g:tensor([ 1.0764])
# grad1:tensor([ 1.0764])
# momtensor([-0.3916])
# ------calling energy function------
# x tensor([ 0.8371])
# y grad tensor([ 0.5670])
# px tensor([ 0.2810])
# result tensor([ 0.1594])
# g:tensor([ 1.0417])
# ------calling energy function------
# x tensor([ 0.8063])
# y grad tensor([ 0.5535])
# px tensor([ 0.2882])
# result tensor([ 0.1595])
# g:tensor([ 0.9998])
# ------calling energy function------
# x tensor([ 0.7709])
# y grad tensor([ 0.5374])
# px tensor([ 0.2964])
# result tensor([ 0.1593])
# g:tensor([ 0.9516])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7709])
# y grad tensor([ 0.5374])
# px tensor([ 0.2964])
# result tensor([ 0.1593])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7709])
# y grad tensor([ 0.5374])
# px tensor([ 0.2964])
# result tensor([ 0.1593])
# Sample: 4
# ========== simulate ==============
# pos:tensor([ 0.1498]) True
# ------calling energy function------
# x tensor([ 0.7709])
# y grad tensor([ 0.5374])
# px tensor([ 0.2964])
# result tensor([ 0.1593])
# g:tensor([ 0.9516])
# grad1:tensor([ 0.9516])
# momtensor([-0.5644])
# ------calling energy function------
# x tensor([ 0.7384])
# y grad tensor([ 0.5221])
# px tensor([ 0.3037])
# result tensor([ 0.1586])
# g:tensor([ 0.9077])
# ------calling energy function------
# x tensor([ 0.7024])
# y grad tensor([ 0.5046])
# px tensor([ 0.3117])
# result tensor([ 0.1573])
# g:tensor([ 0.8590])
# ------calling energy function------
# x tensor([ 0.6633])
# y grad tensor([ 0.4849])
# px tensor([ 0.3202])
# result tensor([ 0.1552])
# g:tensor([ 0.8065])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6633])
# y grad tensor([ 0.4849])
# px tensor([ 0.3202])
# result tensor([ 0.1552])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7709])
# y grad tensor([ 0.5374])
# px tensor([ 0.2964])
# result tensor([ 0.1593])
# Sample: 5
# ========== simulate ==============
# pos:tensor([ 0.1498]) True
# ------calling energy function------
# x tensor([ 0.7709])
# y grad tensor([ 0.5374])
# px tensor([ 0.2964])
# result tensor([ 0.1593])
# g:tensor([ 0.9516])
# grad1:tensor([ 0.9516])
# momtensor([-0.8597])
# ------calling energy function------
# x tensor([ 0.7231])
# y grad tensor([ 0.5148])
# px tensor([ 0.3072])
# result tensor([ 0.1581])
# g:tensor([ 0.8870])
# ------calling energy function------
# x tensor([ 0.6731])
# y grad tensor([ 0.4899])
# px tensor([ 0.3181])
# result tensor([ 0.1558])
# g:tensor([ 0.8196])
# ------calling energy function------
# x tensor([ 0.6217])
# y grad tensor([ 0.4630])
# px tensor([ 0.3288])
# result tensor([ 0.1522])
# g:tensor([ 0.7508])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6217])
# y grad tensor([ 0.4630])
# px tensor([ 0.3288])
# result tensor([ 0.1522])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6217])
# y grad tensor([ 0.4630])
# px tensor([ 0.3288])
# result tensor([ 0.1522])
# Sample: 6
# ========== simulate ==============
# pos:tensor([-0.1483]) True
# ------calling energy function------
# x tensor([ 0.6217])
# y grad tensor([ 0.4630])
# px tensor([ 0.3288])
# result tensor([ 0.1522])
# g:tensor([ 0.7508])
# grad1:tensor([ 0.7508])
# momtensor(1.00000e-02 *
#        [-5.9409])
# ------calling energy function------
# x tensor([ 0.6173])
# y grad tensor([ 0.4606])
# px tensor([ 0.3297])
# result tensor([ 0.1519])
# g:tensor([ 0.7449])
# ------calling energy function------
# x tensor([ 0.6094])
# y grad tensor([ 0.4563])
# px tensor([ 0.3313])
# result tensor([ 0.1512])
# g:tensor([ 0.7344])
# ------calling energy function------
# x tensor([ 0.5983])
# y grad tensor([ 0.4503])
# px tensor([ 0.3336])
# result tensor([ 0.1502])
# g:tensor([ 0.7196])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5983])
# y grad tensor([ 0.4503])
# px tensor([ 0.3336])
# result tensor([ 0.1502])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5983])
# y grad tensor([ 0.4503])
# px tensor([ 0.3336])
# result tensor([ 0.1502])
# Sample: 7
# ========== simulate ==============
# pos:tensor([-0.1996]) True
# ------calling energy function------
# x tensor([ 0.5983])
# y grad tensor([ 0.4503])
# px tensor([ 0.3336])
# result tensor([ 0.1502])
# g:tensor([ 0.7196])
# grad1:tensor([ 0.7196])
# momtensor([ 0.3090])
# ------calling energy function------
# x tensor([ 0.6107])
# y grad tensor([ 0.4570])
# px tensor([ 0.3311])
# result tensor([ 0.1513])
# g:tensor([ 0.7361])
# ------calling energy function------
# x tensor([ 0.6198])
# y grad tensor([ 0.4620])
# px tensor([ 0.3292])
# result tensor([ 0.1521])
# g:tensor([ 0.7483])
# ------calling energy function------
# x tensor([ 0.6256])
# y grad tensor([ 0.4651])
# px tensor([ 0.3280])
# result tensor([ 0.1526])
# g:tensor([ 0.7560])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6256])
# y grad tensor([ 0.4651])
# px tensor([ 0.3280])
# result tensor([ 0.1526])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6256])
# y grad tensor([ 0.4651])
# px tensor([ 0.3280])
# result tensor([ 0.1526])
# Sample: 8
# ========== simulate ==============
# pos:tensor([-0.1399]) True
# ------calling energy function------
# x tensor([ 0.6256])
# y grad tensor([ 0.4651])
# px tensor([ 0.3280])
# result tensor([ 0.1526])
# g:tensor([ 0.7560])
# grad1:tensor([ 0.7560])
# momtensor([-1.9579])
# ------calling energy function------
# x tensor([ 0.5377])
# y grad tensor([ 0.4159])
# px tensor([ 0.3452])
# result tensor([ 0.1436])
# g:tensor([ 0.6396])
# ------calling energy function------
# x tensor([ 0.4572])
# y grad tensor([ 0.3669])
# px tensor([ 0.3594])
# result tensor([ 0.1319])
# g:tensor([ 0.5347])
# ------calling energy function------
# x tensor([ 0.3847])
# y grad tensor([ 0.3193])
# px tensor([ 0.3705])
# result tensor([ 0.1183])
# g:tensor([ 0.4422])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3847])
# y grad tensor([ 0.3193])
# px tensor([ 0.3705])
# result tensor([ 0.1183])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3847])
# y grad tensor([ 0.3193])
# px tensor([ 0.3705])
# result tensor([ 0.1183])
# Sample: 9
# ========== simulate ==============
# pos:tensor([-0.7568]) True
# ------calling energy function------
# x tensor([ 0.3847])
# y grad tensor([ 0.3193])
# px tensor([ 0.3705])
# result tensor([ 0.1183])
# g:tensor([ 0.4422])
# grad1:tensor([ 0.4422])
# momtensor([ 1.1992])
# ------calling energy function------
# x tensor([ 0.4238])
# y grad tensor([ 0.3455])
# px tensor([ 0.3647])
# result tensor([ 0.1260])
# g:tensor([ 0.4919])
# ------calling energy function------
# x tensor([ 0.4642])
# y grad tensor([ 0.3714])
# px tensor([ 0.3582])
# result tensor([ 0.1330])
# g:tensor([ 0.5438])
# ------calling energy function------
# x tensor([ 0.5055])
# y grad tensor([ 0.3968])
# px tensor([ 0.3511])
# result tensor([ 0.1393])
# g:tensor([ 0.5973])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5055])
# y grad tensor([ 0.3968])
# px tensor([ 0.3511])
# result tensor([ 0.1393])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5055])
# y grad tensor([ 0.3968])
# px tensor([ 0.3511])
# result tensor([ 0.1393])
# Sample: 10
# ========== simulate ==============
# pos:tensor([-0.4189]) True
# ------calling energy function------
# x tensor([ 0.5055])
# y grad tensor([ 0.3968])
# px tensor([ 0.3511])
# result tensor([ 0.1393])
# g:tensor([ 0.5973])
# grad1:tensor([ 0.5973])
# momtensor([ 1.5906])
# ------calling energy function------
# x tensor([ 0.5703])
# y grad tensor([ 0.4347])
# px tensor([ 0.3391])
# result tensor([ 0.1474])
# g:tensor([ 0.6826])
# ------calling energy function------
# x tensor([ 0.6380])
# y grad tensor([ 0.4716])
# px tensor([ 0.3255])
# result tensor([ 0.1535])
# g:tensor([ 0.7725])
# ------calling energy function------
# x tensor([ 0.7072])
# y grad tensor([ 0.5070])
# px tensor([ 0.3107])
# result tensor([ 0.1575])
# g:tensor([ 0.8655])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7072])
# y grad tensor([ 0.5070])
# px tensor([ 0.3107])
# result tensor([ 0.1575])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7072])
# y grad tensor([ 0.5070])
# px tensor([ 0.3107])
# result tensor([ 0.1575])
# Sample: 11
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 2.7925]) True
# ------calling energy function------
# x tensor([ 0.7072])
# y grad tensor([ 0.5070])
# px tensor([ 0.3107])
# result tensor([ 0.1575])
# g:tensor([ 0.8655])
# grad1:tensor([ 0.8655])
# momtensor([-0.2730])
# ------calling energy function------
# x tensor([ 0.6913])
# y grad tensor([ 0.4991])
# px tensor([ 0.3141])
# result tensor([ 0.1568])
# g:tensor([ 0.8441])
# ------calling energy function------
# x tensor([ 0.6715])
# y grad tensor([ 0.4891])
# px tensor([ 0.3184])
# result tensor([ 0.1557])
# g:tensor([ 0.8175])
# ------calling energy function------
# x tensor([ 0.6482])
# y grad tensor([ 0.4770])
# px tensor([ 0.3233])
# result tensor([ 0.1542])
# g:tensor([ 0.7862])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6482])
# y grad tensor([ 0.4770])
# px tensor([ 0.3233])
# result tensor([ 0.1542])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6482])
# y grad tensor([ 0.4770])
# px tensor([ 0.3233])
# result tensor([ 0.1542])
# Sample: 12
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [-9.2008]) True
# ------calling energy function------
# x tensor([ 0.6482])
# y grad tensor([ 0.4770])
# px tensor([ 0.3233])
# result tensor([ 0.1542])
# g:tensor([ 0.7862])
# grad1:tensor([ 0.7862])
# momtensor([-0.1408])
# ------calling energy function------
# x tensor([ 0.6396])
# y grad tensor([ 0.4725])
# px tensor([ 0.3251])
# result tensor([ 0.1536])
# g:tensor([ 0.7748])
# ------calling energy function------
# x tensor([ 0.6276])
# y grad tensor([ 0.4661])
# px tensor([ 0.3276])
# result tensor([ 0.1527])
# g:tensor([ 0.7586])
# ------calling energy function------
# x tensor([ 0.6122])
# y grad tensor([ 0.4578])
# px tensor([ 0.3308])
# result tensor([ 0.1514])
# g:tensor([ 0.7381])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6122])
# y grad tensor([ 0.4578])
# px tensor([ 0.3308])
# result tensor([ 0.1514])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6122])
# y grad tensor([ 0.4578])
# px tensor([ 0.3308])
# result tensor([ 0.1514])
# Sample: 13
# ========== simulate ==============
# pos:tensor([-0.1691]) True
# ------calling energy function------
# x tensor([ 0.6122])
# y grad tensor([ 0.4578])
# px tensor([ 0.3308])
# result tensor([ 0.1514])
# g:tensor([ 0.7381])
# grad1:tensor([ 0.7381])
# momtensor([-0.2605])
# ------calling energy function------
# x tensor([ 0.5986])
# y grad tensor([ 0.4504])
# px tensor([ 0.3335])
# result tensor([ 0.1502])
# g:tensor([ 0.7201])
# ------calling energy function------
# x tensor([ 0.5822])
# y grad tensor([ 0.4413])
# px tensor([ 0.3368])
# result tensor([ 0.1486])
# g:tensor([ 0.6982])
# ------calling energy function------
# x tensor([ 0.5630])
# y grad tensor([ 0.4305])
# px tensor([ 0.3405])
# result tensor([ 0.1466])
# g:tensor([ 0.6729])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5630])
# y grad tensor([ 0.4305])
# px tensor([ 0.3405])
# result tensor([ 0.1466])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5630])
# y grad tensor([ 0.4305])
# px tensor([ 0.3405])
# result tensor([ 0.1466])
# Sample: 14
# ========== simulate ==============
# pos:tensor([-0.2797]) True
# ------calling energy function------
# x tensor([ 0.5630])
# y grad tensor([ 0.4305])
# px tensor([ 0.3405])
# result tensor([ 0.1466])
# g:tensor([ 0.6729])
# grad1:tensor([ 0.6729])
# momtensor([-0.4867])
# ------calling energy function------
# x tensor([ 0.5410])
# y grad tensor([ 0.4178])
# px tensor([ 0.3446])
# result tensor([ 0.1440])
# g:tensor([ 0.6438])
# ------calling energy function------
# x tensor([ 0.5169])
# y grad tensor([ 0.4037])
# px tensor([ 0.3490])
# result tensor([ 0.1409])
# g:tensor([ 0.6123])
# ------calling energy function------
# x tensor([ 0.4914])
# y grad tensor([ 0.3882])
# px tensor([ 0.3536])
# result tensor([ 0.1373])
# g:tensor([ 0.5790])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4914])
# y grad tensor([ 0.3882])
# px tensor([ 0.3536])
# result tensor([ 0.1373])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4914])
# y grad tensor([ 0.3882])
# px tensor([ 0.3536])
# result tensor([ 0.1373])
# Sample: 15
# ========== simulate ==============
# pos:tensor([-0.4549]) True
# ------calling energy function------
# x tensor([ 0.4914])
# y grad tensor([ 0.3882])
# px tensor([ 0.3536])
# result tensor([ 0.1373])
# g:tensor([ 0.5790])
# grad1:tensor([ 0.5790])
# momtensor([ 2.3644])
# ------calling energy function------
# x tensor([ 0.5886])
# y grad tensor([ 0.4449])
# px tensor([ 0.3355])
# result tensor([ 0.1493])
# g:tensor([ 0.7068])
# ------calling energy function------
# x tensor([ 0.6957])
# y grad tensor([ 0.5013])
# px tensor([ 0.3132])
# result tensor([ 0.1570])
# g:tensor([ 0.8501])
# ------calling energy function------
# x tensor([ 0.8109])
# y grad tensor([ 0.5556])
# px tensor([ 0.2872])
# result tensor([ 0.1595])
# g:tensor([ 1.0061])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8109])
# y grad tensor([ 0.5556])
# px tensor([ 0.2872])
# result tensor([ 0.1595])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8109])
# y grad tensor([ 0.5556])
# px tensor([ 0.2872])
# result tensor([ 0.1595])
# Sample: 16
# ========== simulate ==============
# pos:tensor([ 0.2231]) True
# ------calling energy function------
# x tensor([ 0.8109])
# y grad tensor([ 0.5556])
# px tensor([ 0.2872])
# result tensor([ 0.1595])
# g:tensor([ 1.0061])
# grad1:tensor([ 1.0061])
# momtensor([ 0.2417])
# ------calling energy function------
# x tensor([ 0.8216])
# y grad tensor([ 0.5603])
# px tensor([ 0.2847])
# result tensor([ 0.1595])
# g:tensor([ 1.0206])
# ------calling energy function------
# x tensor([ 0.8266])
# y grad tensor([ 0.5625])
# px tensor([ 0.2835])
# result tensor([ 0.1595])
# g:tensor([ 1.0274])
# ------calling energy function------
# x tensor([ 0.8259])
# y grad tensor([ 0.5621])
# px tensor([ 0.2837])
# result tensor([ 0.1595])
# g:tensor([ 1.0264])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8259])
# y grad tensor([ 0.5621])
# px tensor([ 0.2837])
# result tensor([ 0.1595])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8259])
# y grad tensor([ 0.5621])
# px tensor([ 0.2837])
# result tensor([ 0.1595])
# Sample: 17
# ========== simulate ==============
# pos:tensor([ 0.2499]) True
# ------calling energy function------
# x tensor([ 0.8259])
# y grad tensor([ 0.5621])
# px tensor([ 0.2837])
# result tensor([ 0.1595])
# g:tensor([ 1.0264])
# grad1:tensor([ 1.0264])
# momtensor([ 0.9750])
# ------calling energy function------
# x tensor([ 0.8788])
# y grad tensor([ 0.5847])
# px tensor([ 0.2711])
# result tensor([ 0.1585])
# g:tensor([ 1.0986])
# ------calling energy function------
# x tensor([ 0.9272])
# y grad tensor([ 0.6043])
# px tensor([ 0.2596])
# result tensor([ 0.1569])
# g:tensor([ 1.1647])
# ------calling energy function------
# x tensor([ 0.9699])
# y grad tensor([ 0.6209])
# px tensor([ 0.2492])
# result tensor([ 0.1548])
# g:tensor([ 1.2231])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.9699])
# y grad tensor([ 0.6209])
# px tensor([ 0.2492])
# result tensor([ 0.1548])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.9699])
# y grad tensor([ 0.6209])
# px tensor([ 0.2492])
# result tensor([ 0.1548])
# Sample: 18
# ========== simulate ==============
# pos:tensor([ 0.4933]) True
# ------calling energy function------
# x tensor([ 0.9699])
# y grad tensor([ 0.6209])
# px tensor([ 0.2492])
# result tensor([ 0.1548])
# g:tensor([ 1.2231])
# grad1:tensor([ 1.2231])
# momtensor([-0.4229])
# ------calling energy function------
# x tensor([ 0.9402])
# y grad tensor([ 0.6094])
# px tensor([ 0.2564])
# result tensor([ 0.1563])
# g:tensor([ 1.1824])
# ------calling energy function------
# x tensor([ 0.9039])
# y grad tensor([ 0.5950])
# px tensor([ 0.2652])
# result tensor([ 0.1578])
# g:tensor([ 1.1328])
# ------calling energy function------
# x tensor([ 0.8619])
# y grad tensor([ 0.5777])
# px tensor([ 0.2752])
# result tensor([ 0.1589])
# g:tensor([ 1.0755])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8619])
# y grad tensor([ 0.5777])
# px tensor([ 0.2752])
# result tensor([ 0.1589])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8619])
# y grad tensor([ 0.5777])
# px tensor([ 0.2752])
# result tensor([ 0.1589])
# Sample: 19
# ========== simulate ==============
# pos:tensor([ 0.3131]) True
# ------calling energy function------
# x tensor([ 0.8619])
# y grad tensor([ 0.5777])
# px tensor([ 0.2752])
# result tensor([ 0.1589])
# g:tensor([ 1.0755])
# grad1:tensor([ 1.0755])
# momtensor(1.00000e-02 *
#        [ 4.5406])
# ------calling energy function------
# x tensor([ 0.8614])
# y grad tensor([ 0.5774])
# px tensor([ 0.2753])
# result tensor([ 0.1590])
# g:tensor([ 1.0749])
# ------calling energy function------
# x tensor([ 0.8548])
# y grad tensor([ 0.5746])
# px tensor([ 0.2769])
# result tensor([ 0.1591])
# g:tensor([ 1.0658])
# ------calling energy function------
# x tensor([ 0.8420])
# y grad tensor([ 0.5692])
# px tensor([ 0.2799])
# result tensor([ 0.1593])
# g:tensor([ 1.0484])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8420])
# y grad tensor([ 0.5692])
# px tensor([ 0.2799])
# result tensor([ 0.1593])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8420])
# y grad tensor([ 0.5692])
# px tensor([ 0.2799])
# result tensor([ 0.1593])
# Sample: 20
# ========== simulate ==============
# pos:tensor([ 0.2785]) True
# ------calling energy function------
# x tensor([ 0.8420])
# y grad tensor([ 0.5692])
# px tensor([ 0.2799])
# result tensor([ 0.1593])
# g:tensor([ 1.0484])
# grad1:tensor([ 1.0484])
# momtensor([ 1.4913])
# ------calling energy function------
# x tensor([ 0.9265])
# y grad tensor([ 0.6040])
# px tensor([ 0.2597])
# result tensor([ 0.1569])
# g:tensor([ 1.1637])
# ------calling energy function------
# x tensor([ 1.0084])
# y grad tensor([ 0.6352])
# px tensor([ 0.2399])
# result tensor([ 0.1524])
# g:tensor([ 1.2758])
# ------calling energy function------
# x tensor([ 1.0860])
# y grad tensor([ 0.6624])
# px tensor([ 0.2212])
# result tensor([ 0.1465])
# g:tensor([ 1.3818])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.0860])
# y grad tensor([ 0.6624])
# px tensor([ 0.2212])
# result tensor([ 0.1465])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.0860])
# y grad tensor([ 0.6624])
# px tensor([ 0.2212])
# result tensor([ 0.1465])
# Sample: 21
# ========== simulate ==============
# pos:tensor([ 0.6741]) True
# ------calling energy function------
# x tensor([ 1.0860])
# y grad tensor([ 0.6624])
# px tensor([ 0.2212])
# result tensor([ 0.1465])
# g:tensor([ 1.3818])
# grad1:tensor([ 1.3818])
# momtensor([ 1.3182])
# ------calling energy function------
# x tensor([ 1.1704])
# y grad tensor([ 0.6898])
# px tensor([ 0.2011])
# result tensor([ 0.1387])
# g:tensor([ 1.4971])
# ------calling energy function------
# x tensor([ 1.2475])
# y grad tensor([ 0.7128])
# px tensor([ 0.1832])
# result tensor([ 0.1306])
# g:tensor([ 1.6020])
# ------calling energy function------
# x tensor([ 1.3154])
# y grad tensor([ 0.7316])
# px tensor([ 0.1680])
# result tensor([ 0.1229])
# g:tensor([ 1.6940])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.3154])
# y grad tensor([ 0.7316])
# px tensor([ 0.1680])
# result tensor([ 0.1229])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.3154])
# y grad tensor([ 0.7316])
# px tensor([ 0.1680])
# result tensor([ 0.1229])
# Sample: 22
# ========== simulate ==============
# pos:tensor([ 1.0029]) True
# ------calling energy function------
# x tensor([ 1.3154])
# y grad tensor([ 0.7316])
# px tensor([ 0.1680])
# result tensor([ 0.1229])
# g:tensor([ 1.6940])
# grad1:tensor([ 1.6940])
# momtensor([-0.2054])
# ------calling energy function------
# x tensor([ 1.2942])
# y grad tensor([ 0.7259])
# px tensor([ 0.1727])
# result tensor([ 0.1253])
# g:tensor([ 1.6654])
# ------calling energy function------
# x tensor([ 1.2613])
# y grad tensor([ 0.7167])
# px tensor([ 0.1801])
# result tensor([ 0.1291])
# g:tensor([ 1.6207])
# ------calling energy function------
# x tensor([ 1.2173])
# y grad tensor([ 0.7040])
# px tensor([ 0.1902])
# result tensor([ 0.1339])
# g:tensor([ 1.5610])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.2173])
# y grad tensor([ 0.7040])
# px tensor([ 0.1902])
# result tensor([ 0.1339])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.2173])
# y grad tensor([ 0.7040])
# px tensor([ 0.1902])
# result tensor([ 0.1339])
# Sample: 23
# ========== simulate ==============
# pos:tensor([ 0.8663]) True
# ------calling energy function------
# x tensor([ 1.2173])
# y grad tensor([ 0.7040])
# px tensor([ 0.1902])
# result tensor([ 0.1339])
# g:tensor([ 1.5610])
# grad1:tensor([ 1.5610])
# momtensor([ 0.5597])
# ------calling energy function------
# x tensor([ 1.2515])
# y grad tensor([ 0.7139])
# px tensor([ 0.1823])
# result tensor([ 0.1302])
# g:tensor([ 1.6074])
# ------calling energy function------
# x tensor([ 1.2745])
# y grad tensor([ 0.7204])
# px tensor([ 0.1771])
# result tensor([ 0.1276])
# g:tensor([ 1.6386])
# ------calling energy function------
# x tensor([ 1.2859])
# y grad tensor([ 0.7236])
# px tensor([ 0.1745])
# result tensor([ 0.1263])
# g:tensor([ 1.6540])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.2859])
# y grad tensor([ 0.7236])
# px tensor([ 0.1745])
# result tensor([ 0.1263])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.2859])
# y grad tensor([ 0.7236])
# px tensor([ 0.1745])
# result tensor([ 0.1263])
# Sample: 24
# ========== simulate ==============
# pos:tensor([ 0.9623]) True
# ------calling energy function------
# x tensor([ 1.2859])
# y grad tensor([ 0.7236])
# px tensor([ 0.1745])
# result tensor([ 0.1263])
# g:tensor([ 1.6540])
# grad1:tensor([ 1.6540])
# momtensor([-0.9272])
# ------calling energy function------
# x tensor([ 1.2138])
# y grad tensor([ 0.7029])
# px tensor([ 0.1910])
# result tensor([ 0.1342])
# g:tensor([ 1.5562])
# ------calling energy function------
# x tensor([ 1.1333])
# y grad tensor([ 0.6780])
# px tensor([ 0.2099])
# result tensor([ 0.1423])
# g:tensor([ 1.4465])
# ------calling energy function------
# x tensor([ 1.0464])
# y grad tensor([ 0.6488])
# px tensor([ 0.2308])
# result tensor([ 0.1497])
# g:tensor([ 1.3277])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.0464])
# y grad tensor([ 0.6488])
# px tensor([ 0.2308])
# result tensor([ 0.1497])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.0464])
# y grad tensor([ 0.6488])
# px tensor([ 0.2308])
# result tensor([ 0.1497])
# Sample: 25
# ========== simulate ==============
# pos:tensor([ 0.6138]) True
# ------calling energy function------
# x tensor([ 1.0464])
# y grad tensor([ 0.6488])
# px tensor([ 0.2308])
# result tensor([ 0.1497])
# g:tensor([ 1.3277])
# grad1:tensor([ 1.3277])
# momtensor([-1.1540])
# ------calling energy function------
# x tensor([ 0.9689])
# y grad tensor([ 0.6205])
# px tensor([ 0.2495])
# result tensor([ 0.1548])
# g:tensor([ 1.2218])
# ------calling energy function------
# x tensor([ 0.8878])
# y grad tensor([ 0.5884])
# px tensor([ 0.2690])
# result tensor([ 0.1583])
# g:tensor([ 1.1108])
# ------calling energy function------
# x tensor([ 0.8048])
# y grad tensor([ 0.5528])
# px tensor([ 0.2886])
# result tensor([ 0.1595])
# g:tensor([ 0.9978])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8048])
# y grad tensor([ 0.5528])
# px tensor([ 0.2886])
# result tensor([ 0.1595])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8048])
# y grad tensor([ 0.5528])
# px tensor([ 0.2886])
# result tensor([ 0.1595])
# Sample: 26
# ========== simulate ==============
# pos:tensor([ 0.2121]) True
# ------calling energy function------
# x tensor([ 0.8048])
# y grad tensor([ 0.5528])
# px tensor([ 0.2886])
# result tensor([ 0.1595])
# g:tensor([ 0.9978])
# grad1:tensor([ 0.9978])
# momtensor([-2.0860])
# ------calling energy function------
# x tensor([ 0.6924])
# y grad tensor([ 0.4996])
# px tensor([ 0.3139])
# result tensor([ 0.1568])
# g:tensor([ 0.8456])
# ------calling energy function------
# x tensor([ 0.5876])
# y grad tensor([ 0.4443])
# px tensor([ 0.3357])
# result tensor([ 0.1492])
# g:tensor([ 0.7055])
# ------calling energy function------
# x tensor([ 0.4922])
# y grad tensor([ 0.3887])
# px tensor([ 0.3534])
# result tensor([ 0.1374])
# g:tensor([ 0.5801])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4922])
# y grad tensor([ 0.3887])
# px tensor([ 0.3534])
# result tensor([ 0.1374])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4922])
# y grad tensor([ 0.3887])
# px tensor([ 0.3534])
# result tensor([ 0.1374])
# Sample: 27
# ========== simulate ==============
# pos:tensor([-0.4526]) True
# ------calling energy function------
# x tensor([ 0.4922])
# y grad tensor([ 0.3887])
# px tensor([ 0.3534])
# result tensor([ 0.1374])
# g:tensor([ 0.5801])
# grad1:tensor([ 0.5801])
# momtensor([-0.7751])
# ------calling energy function------
# x tensor([ 0.4617])
# y grad tensor([ 0.3698])
# px tensor([ 0.3586])
# result tensor([ 0.1326])
# g:tensor([ 0.5406])
# ------calling energy function------
# x tensor([ 0.4308])
# y grad tensor([ 0.3500])
# px tensor([ 0.3636])
# result tensor([ 0.1273])
# g:tensor([ 0.5009])
# ------calling energy function------
# x tensor([ 0.4000])
# y grad tensor([ 0.3297])
# px tensor([ 0.3683])
# result tensor([ 0.1214])
# g:tensor([ 0.4615])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4000])
# y grad tensor([ 0.3297])
# px tensor([ 0.3683])
# result tensor([ 0.1214])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4000])
# y grad tensor([ 0.3297])
# px tensor([ 0.3683])
# result tensor([ 0.1214])
# Sample: 28
# ========== simulate ==============
# pos:tensor([-0.7097]) True
# ------calling energy function------
# x tensor([ 0.4000])
# y grad tensor([ 0.3297])
# px tensor([ 0.3683])
# result tensor([ 0.1214])
# g:tensor([ 0.4615])
# grad1:tensor([ 0.4615])
# momtensor([-1.1967])
# ------calling energy function------
# x tensor([ 0.3614])
# y grad tensor([ 0.3033])
# px tensor([ 0.3737])
# result tensor([ 0.1133])
# g:tensor([ 0.4129])
# ------calling energy function------
# x tensor([ 0.3248])
# y grad tensor([ 0.2773])
# px tensor([ 0.3784])
# result tensor([ 0.1050])
# g:tensor([ 0.3674])
# ------calling energy function------
# x tensor([ 0.2905])
# y grad tensor([ 0.2521])
# px tensor([ 0.3825])
# result tensor(1.00000e-02 *
#        [ 9.6411])
# g:tensor([ 0.3253])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2905])
# y grad tensor([ 0.2521])
# px tensor([ 0.3825])
# result tensor(1.00000e-02 *
#        [ 9.6411])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2905])
# y grad tensor([ 0.2521])
# px tensor([ 0.3825])
# result tensor(1.00000e-02 *
#        [ 9.6411])
# Sample: 29
# ========== simulate ==============
# pos:tensor([-1.0876]) True
# ------calling energy function------
# x tensor([ 0.2905])
# y grad tensor([ 0.2521])
# px tensor([ 0.3825])
# result tensor(1.00000e-02 *
#        [ 9.6411])
# g:tensor([ 0.3253])
# grad1:tensor([ 0.3253])
# momtensor([ 0.1272])
# ------calling energy function------
# x tensor([ 0.2933])
# y grad tensor([ 0.2542])
# px tensor([ 0.3822])
# result tensor(1.00000e-02 *
#        [ 9.7133])
# g:tensor([ 0.3287])
# ------calling energy function------
# x tensor([ 0.2953])
# y grad tensor([ 0.2557])
# px tensor([ 0.3819])
# result tensor(1.00000e-02 *
#        [ 9.7643])
# g:tensor([ 0.3311])
# ------calling energy function------
# x tensor([ 0.2964])
# y grad tensor([ 0.2565])
# px tensor([ 0.3818])
# result tensor(1.00000e-02 *
#        [ 9.7937])
# g:tensor([ 0.3325])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2964])
# y grad tensor([ 0.2565])
# px tensor([ 0.3818])
# result tensor(1.00000e-02 *
#        [ 9.7937])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2964])
# y grad tensor([ 0.2565])
# px tensor([ 0.3818])
# result tensor(1.00000e-02 *
#        [ 9.7937])
# Sample: 30
# ========== simulate ==============
# pos:tensor([-1.0642]) True
# ------calling energy function------
# x tensor([ 0.2964])
# y grad tensor([ 0.2565])
# px tensor([ 0.3818])
# result tensor(1.00000e-02 *
#        [ 9.7937])
# g:tensor([ 0.3325])
# grad1:tensor([ 0.3325])
# momtensor([ 0.4750])
# ------calling energy function------
# x tensor([ 0.3084])
# y grad tensor([ 0.2654])
# px tensor([ 0.3804])
# result tensor([ 0.1009])
# g:tensor([ 0.3472])
# ------calling energy function------
# x tensor([ 0.3198])
# y grad tensor([ 0.2737])
# px tensor([ 0.3791])
# result tensor([ 0.1037])
# g:tensor([ 0.3612])
# ------calling energy function------
# x tensor([ 0.3305])
# y grad tensor([ 0.2815])
# px tensor([ 0.3777])
# result tensor([ 0.1063])
# g:tensor([ 0.3745])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3305])
# y grad tensor([ 0.2815])
# px tensor([ 0.3777])
# result tensor([ 0.1063])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3305])
# y grad tensor([ 0.2815])
# px tensor([ 0.3777])
# result tensor([ 0.1063])
# Sample: 31
# ========== simulate ==============
# pos:tensor([-0.9372]) True
# ------calling energy function------
# x tensor([ 0.3305])
# y grad tensor([ 0.2815])
# px tensor([ 0.3777])
# result tensor([ 0.1063])
# g:tensor([ 0.3745])
# grad1:tensor([ 0.3745])
# momtensor([ 1.3599])
# ------calling energy function------
# x tensor([ 0.3701])
# y grad tensor([ 0.3094])
# px tensor([ 0.3725])
# result tensor([ 0.1152])
# g:tensor([ 0.4239])
# ------calling energy function------
# x tensor([ 0.4122])
# y grad tensor([ 0.3378])
# px tensor([ 0.3665])
# result tensor([ 0.1238])
# g:tensor([ 0.4770])
# ------calling energy function------
# x tensor([ 0.4562])
# y grad tensor([ 0.3663])
# px tensor([ 0.3595])
# result tensor([ 0.1317])
# g:tensor([ 0.5334])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4562])
# y grad tensor([ 0.3663])
# px tensor([ 0.3595])
# result tensor([ 0.1317])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4562])
# y grad tensor([ 0.3663])
# px tensor([ 0.3595])
# result tensor([ 0.1317])
# Sample: 32
# ========== simulate ==============
# pos:tensor([-0.5481]) True
# ------calling energy function------
# x tensor([ 0.4562])
# y grad tensor([ 0.3663])
# px tensor([ 0.3595])
# result tensor([ 0.1317])
# g:tensor([ 0.5334])
# grad1:tensor([ 0.5334])
# momtensor([ 0.1627])
# ------calling energy function------
# x tensor([ 0.4612])
# y grad tensor([ 0.3695])
# px tensor([ 0.3587])
# result tensor([ 0.1325])
# g:tensor([ 0.5399])
# ------calling energy function------
# x tensor([ 0.4642])
# y grad tensor([ 0.3714])
# px tensor([ 0.3582])
# result tensor([ 0.1330])
# g:tensor([ 0.5438])
# ------calling energy function------
# x tensor([ 0.4653])
# y grad tensor([ 0.3720])
# px tensor([ 0.3580])
# result tensor([ 0.1332])
# g:tensor([ 0.5451])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4653])
# y grad tensor([ 0.3720])
# px tensor([ 0.3580])
# result tensor([ 0.1332])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4653])
# y grad tensor([ 0.3720])
# px tensor([ 0.3580])
# result tensor([ 0.1332])
# Sample: 33
# ========== simulate ==============
# pos:tensor([-0.5235]) True
# ------calling energy function------
# x tensor([ 0.4653])
# y grad tensor([ 0.3720])
# px tensor([ 0.3580])
# result tensor([ 0.1332])
# g:tensor([ 0.5451])
# grad1:tensor([ 0.5451])
# momtensor([ 0.3360])
# ------calling energy function------
# x tensor([ 0.4769])
# y grad tensor([ 0.3793])
# px tensor([ 0.3561])
# result tensor([ 0.1350])
# g:tensor([ 0.5601])
# ------calling energy function------
# x tensor([ 0.4865])
# y grad tensor([ 0.3852])
# px tensor([ 0.3544])
# result tensor([ 0.1365])
# g:tensor([ 0.5727])
# ------calling energy function------
# x tensor([ 0.4941])
# y grad tensor([ 0.3899])
# px tensor([ 0.3531])
# result tensor([ 0.1377])
# g:tensor([ 0.5825])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4941])
# y grad tensor([ 0.3899])
# px tensor([ 0.3531])
# result tensor([ 0.1377])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4941])
# y grad tensor([ 0.3899])
# px tensor([ 0.3531])
# result tensor([ 0.1377])
# Sample: 34
# ========== simulate ==============
# pos:tensor([-0.4478]) True
# ------calling energy function------
# x tensor([ 0.4941])
# y grad tensor([ 0.3899])
# px tensor([ 0.3531])
# result tensor([ 0.1377])
# g:tensor([ 0.5825])
# grad1:tensor([ 0.5825])
# momtensor([ 1.6099])
# ------calling energy function------
# x tensor([ 0.5587])
# y grad tensor([ 0.4281])
# px tensor([ 0.3413])
# result tensor([ 0.1461])
# g:tensor([ 0.6672])
# ------calling energy function------
# x tensor([ 0.6264])
# y grad tensor([ 0.4655])
# px tensor([ 0.3279])
# result tensor([ 0.1526])
# g:tensor([ 0.7570])
# ------calling energy function------
# x tensor([ 0.6959])
# y grad tensor([ 0.5014])
# px tensor([ 0.3132])
# result tensor([ 0.1570])
# g:tensor([ 0.8503])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6959])
# y grad tensor([ 0.5014])
# px tensor([ 0.3132])
# result tensor([ 0.1570])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6959])
# y grad tensor([ 0.5014])
# px tensor([ 0.3132])
# result tensor([ 0.1570])
# Sample: 35
# ========== simulate ==============
# pos:tensor(1.00000e-03 *
#        [ 5.4777]) True
# ------calling energy function------
# x tensor([ 0.6959])
# y grad tensor([ 0.5014])
# px tensor([ 0.3132])
# result tensor([ 0.1570])
# g:tensor([ 0.8503])
# grad1:tensor([ 0.8503])
# momtensor([ 0.7527])
# ------calling energy function------
# x tensor([ 0.7321])
# y grad tensor([ 0.5191])
# px tensor([ 0.3052])
# result tensor([ 0.1584])
# g:tensor([ 0.8992])
# ------calling energy function------
# x tensor([ 0.7648])
# y grad tensor([ 0.5346])
# px tensor([ 0.2978])
# result tensor([ 0.1592])
# g:tensor([ 0.9434])
# ------calling energy function------
# x tensor([ 0.7933])
# y grad tensor([ 0.5476])
# px tensor([ 0.2912])
# result tensor([ 0.1595])
# g:tensor([ 0.9821])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7933])
# y grad tensor([ 0.5476])
# px tensor([ 0.2912])
# result tensor([ 0.1595])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7933])
# y grad tensor([ 0.5476])
# px tensor([ 0.2912])
# result tensor([ 0.1595])
# Sample: 36
# ========== simulate ==============
# pos:tensor([ 0.1911]) True
# ------calling energy function------
# x tensor([ 0.7933])
# y grad tensor([ 0.5476])
# px tensor([ 0.2912])
# result tensor([ 0.1595])
# g:tensor([ 0.9821])
# grad1:tensor([ 0.9821])
# momtensor([-0.3381])
# ------calling energy function------
# x tensor([ 0.7722])
# y grad tensor([ 0.5380])
# px tensor([ 0.2961])
# result tensor([ 0.1593])
# g:tensor([ 0.9535])
# ------calling energy function------
# x tensor([ 0.7466])
# y grad tensor([ 0.5260])
# px tensor([ 0.3019])
# result tensor([ 0.1588])
# g:tensor([ 0.9187])
# ------calling energy function------
# x tensor([ 0.7168])
# y grad tensor([ 0.5117])
# px tensor([ 0.3086])
# result tensor([ 0.1579])
# g:tensor([ 0.8784])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7168])
# y grad tensor([ 0.5117])
# px tensor([ 0.3086])
# result tensor([ 0.1579])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7168])
# y grad tensor([ 0.5117])
# px tensor([ 0.3086])
# result tensor([ 0.1579])
# Sample: 37
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 4.6709]) True
# ------calling energy function------
# x tensor([ 0.7168])
# y grad tensor([ 0.5117])
# px tensor([ 0.3086])
# result tensor([ 0.1579])
# g:tensor([ 0.8784])
# grad1:tensor([ 0.8784])
# momtensor([-0.6873])
# ------calling energy function------
# x tensor([ 0.6800])
# y grad tensor([ 0.4934])
# px tensor([ 0.3166])
# result tensor([ 0.1562])
# g:tensor([ 0.8289])
# ------calling energy function------
# x tensor([ 0.6407])
# y grad tensor([ 0.4731])
# px tensor([ 0.3249])
# result tensor([ 0.1537])
# g:tensor([ 0.7762])
# ------calling energy function------
# x tensor([ 0.5995])
# y grad tensor([ 0.4509])
# px tensor([ 0.3333])
# result tensor([ 0.1503])
# g:tensor([ 0.7212])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5995])
# y grad tensor([ 0.4509])
# px tensor([ 0.3333])
# result tensor([ 0.1503])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5995])
# y grad tensor([ 0.4509])
# px tensor([ 0.3333])
# result tensor([ 0.1503])
# Sample: 38
# ========== simulate ==============
# pos:tensor([-0.1970]) True
# ------calling energy function------
# x tensor([ 0.5995])
# y grad tensor([ 0.4509])
# px tensor([ 0.3333])
# result tensor([ 0.1503])
# g:tensor([ 0.7212])
# grad1:tensor([ 0.7212])
# momtensor([ 0.3333])
# ------calling energy function------
# x tensor([ 0.6130])
# y grad tensor([ 0.4583])
# px tensor([ 0.3306])
# result tensor([ 0.1515])
# g:tensor([ 0.7392])
# ------calling energy function------
# x tensor([ 0.6233])
# y grad tensor([ 0.4638])
# px tensor([ 0.3285])
# result tensor([ 0.1524])
# g:tensor([ 0.7529])
# ------calling energy function------
# x tensor([ 0.6302])
# y grad tensor([ 0.4675])
# px tensor([ 0.3271])
# result tensor([ 0.1529])
# g:tensor([ 0.7621])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6302])
# y grad tensor([ 0.4675])
# px tensor([ 0.3271])
# result tensor([ 0.1529])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6302])
# y grad tensor([ 0.4675])
# px tensor([ 0.3271])
# result tensor([ 0.1529])
# Sample: 39
# ========== simulate ==============
# pos:tensor([-0.1302]) True
# ------calling energy function------
# x tensor([ 0.6302])
# y grad tensor([ 0.4675])
# px tensor([ 0.3271])
# result tensor([ 0.1529])
# g:tensor([ 0.7621])
# grad1:tensor([ 0.7621])
# momtensor([ 0.8141])
# ------calling energy function------
# x tensor([ 0.6672])
# y grad tensor([ 0.4869])
# px tensor([ 0.3193])
# result tensor([ 0.1555])
# g:tensor([ 0.8117])
# ------calling energy function------
# x tensor([ 0.7016])
# y grad tensor([ 0.5042])
# px tensor([ 0.3119])
# result tensor([ 0.1573])
# g:tensor([ 0.8580])
# ------calling energy function------
# x tensor([ 0.7328])
# y grad tensor([ 0.5194])
# px tensor([ 0.3050])
# result tensor([ 0.1584])
# g:tensor([ 0.9001])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7328])
# y grad tensor([ 0.5194])
# px tensor([ 0.3050])
# result tensor([ 0.1584])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7328])
# y grad tensor([ 0.5194])
# px tensor([ 0.3050])
# result tensor([ 0.1584])
# Sample: 40
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 7.7825]) True
# ------calling energy function------
# x tensor([ 0.7328])
# y grad tensor([ 0.5194])
# px tensor([ 0.3050])
# result tensor([ 0.1584])
# g:tensor([ 0.9001])
# grad1:tensor([ 0.9001])
# momtensor([ 0.2440])
# ------calling energy function------
# x tensor([ 0.7432])
# y grad tensor([ 0.5244])
# px tensor([ 0.3027])
# result tensor([ 0.1587])
# g:tensor([ 0.9142])
# ------calling energy function------
# x tensor([ 0.7489])
# y grad tensor([ 0.5271])
# px tensor([ 0.3014])
# result tensor([ 0.1589])
# g:tensor([ 0.9218])
# ------calling energy function------
# x tensor([ 0.7497])
# y grad tensor([ 0.5275])
# px tensor([ 0.3012])
# result tensor([ 0.1589])
# g:tensor([ 0.9229])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7497])
# y grad tensor([ 0.5275])
# px tensor([ 0.3012])
# result tensor([ 0.1589])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7497])
# y grad tensor([ 0.5275])
# px tensor([ 0.3012])
# result tensor([ 0.1589])
# Sample: 41
# ========== simulate ==============
# pos:tensor([ 0.1100]) True
# ------calling energy function------
# x tensor([ 0.7497])
# y grad tensor([ 0.5275])
# px tensor([ 0.3012])
# result tensor([ 0.1589])
# g:tensor([ 0.9229])
# grad1:tensor([ 0.9229])
# momtensor([ 0.7445])
# ------calling energy function------
# x tensor([ 0.7871])
# y grad tensor([ 0.5448])
# px tensor([ 0.2927])
# result tensor([ 0.1595])
# g:tensor([ 0.9737])
# ------calling energy function------
# x tensor([ 0.8203])
# y grad tensor([ 0.5597])
# px tensor([ 0.2850])
# result tensor([ 0.1595])
# g:tensor([ 1.0188])
# ------calling energy function------
# x tensor([ 0.8485])
# y grad tensor([ 0.5720])
# px tensor([ 0.2783])
# result tensor([ 0.1592])
# g:tensor([ 1.0573])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8485])
# y grad tensor([ 0.5720])
# px tensor([ 0.2783])
# result tensor([ 0.1592])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8485])
# y grad tensor([ 0.5720])
# px tensor([ 0.2783])
# result tensor([ 0.1592])
# Sample: 42
# ========== simulate ==============
# pos:tensor([ 0.2899]) True
# ------calling energy function------
# x tensor([ 0.8485])
# y grad tensor([ 0.5720])
# px tensor([ 0.2783])
# result tensor([ 0.1592])
# g:tensor([ 1.0573])
# grad1:tensor([ 1.0573])
# momtensor([ 0.4392])
# ------calling energy function------
# x tensor([ 0.8708])
# y grad tensor([ 0.5814])
# px tensor([ 0.2730])
# result tensor([ 0.1587])
# g:tensor([ 1.0877])
# ------calling energy function------
# x tensor([ 0.8871])
# y grad tensor([ 0.5881])
# px tensor([ 0.2692])
# result tensor([ 0.1583])
# g:tensor([ 1.1098])
# ------calling energy function------
# x tensor([ 0.8969])
# y grad tensor([ 0.5922])
# px tensor([ 0.2668])
# result tensor([ 0.1580])
# g:tensor([ 1.1233])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8969])
# y grad tensor([ 0.5922])
# px tensor([ 0.2668])
# result tensor([ 0.1580])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8969])
# y grad tensor([ 0.5922])
# px tensor([ 0.2668])
# result tensor([ 0.1580])
# Sample: 43
# ========== simulate ==============
# pos:tensor([ 0.3729]) True
# ------calling energy function------
# x tensor([ 0.8969])
# y grad tensor([ 0.5922])
# px tensor([ 0.2668])
# result tensor([ 0.1580])
# g:tensor([ 1.1233])
# grad1:tensor([ 1.1233])
# momtensor([ 0.2845])
# ------calling energy function------
# x tensor([ 0.9105])
# y grad tensor([ 0.5977])
# px tensor([ 0.2636])
# result tensor([ 0.1575])
# g:tensor([ 1.1418])
# ------calling energy function------
# x tensor([ 0.9173])
# y grad tensor([ 0.6004])
# px tensor([ 0.2619])
# result tensor([ 0.1573])
# g:tensor([ 1.1512])
# ------calling energy function------
# x tensor([ 0.9173])
# y grad tensor([ 0.6004])
# px tensor([ 0.2619])
# result tensor([ 0.1573])
# g:tensor([ 1.1511])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.9173])
# y grad tensor([ 0.6004])
# px tensor([ 0.2619])
# result tensor([ 0.1573])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.9173])
# y grad tensor([ 0.6004])
# px tensor([ 0.2619])
# result tensor([ 0.1573])
# Sample: 44
# ========== simulate ==============
# pos:tensor([ 0.4071]) True
# ------calling energy function------
# x tensor([ 0.9173])
# y grad tensor([ 0.6004])
# px tensor([ 0.2619])
# result tensor([ 0.1573])
# g:tensor([ 1.1511])
# grad1:tensor([ 1.1511])
# momtensor([-0.5430])
# ------calling energy function------
# x tensor([ 0.8816])
# y grad tensor([ 0.5859])
# px tensor([ 0.2705])
# result tensor([ 0.1585])
# g:tensor([ 1.1024])
# ------calling energy function------
# x tensor([ 0.8406])
# y grad tensor([ 0.5686])
# px tensor([ 0.2802])
# result tensor([ 0.1593])
# g:tensor([ 1.0465])
# ------calling energy function------
# x tensor([ 0.7951])
# y grad tensor([ 0.5484])
# px tensor([ 0.2908])
# result tensor([ 0.1595])
# g:tensor([ 0.9845])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7951])
# y grad tensor([ 0.5484])
# px tensor([ 0.2908])
# result tensor([ 0.1595])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7951])
# y grad tensor([ 0.5484])
# px tensor([ 0.2908])
# result tensor([ 0.1595])
# Sample: 45
# ========== simulate ==============
# pos:tensor([ 0.1944]) True
# ------calling energy function------
# x tensor([ 0.7951])
# y grad tensor([ 0.5484])
# px tensor([ 0.2908])
# result tensor([ 0.1595])
# g:tensor([ 0.9845])
# grad1:tensor([ 0.9845])
# momtensor([ 0.2026])
# ------calling energy function------
# x tensor([ 0.8035])
# y grad tensor([ 0.5522])
# px tensor([ 0.2889])
# result tensor([ 0.1595])
# g:tensor([ 0.9960])
# ------calling energy function------
# x tensor([ 0.8065])
# y grad tensor([ 0.5536])
# px tensor([ 0.2882])
# result tensor([ 0.1595])
# g:tensor([ 1.0000])
# ------calling energy function------
# x tensor([ 0.8039])
# y grad tensor([ 0.5524])
# px tensor([ 0.2888])
# result tensor([ 0.1595])
# g:tensor([ 0.9965])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8039])
# y grad tensor([ 0.5524])
# px tensor([ 0.2888])
# result tensor([ 0.1595])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8039])
# y grad tensor([ 0.5524])
# px tensor([ 0.2888])
# result tensor([ 0.1595])
# Sample: 46
# ========== simulate ==============
# pos:tensor([ 0.2105]) True
# ------calling energy function------
# x tensor([ 0.8039])
# y grad tensor([ 0.5524])
# px tensor([ 0.2888])
# result tensor([ 0.1595])
# g:tensor([ 0.9965])
# grad1:tensor([ 0.9965])
# momtensor([-0.2522])
# ------calling energy function------
# x tensor([ 0.7873])
# y grad tensor([ 0.5449])
# px tensor([ 0.2926])
# result tensor([ 0.1595])
# g:tensor([ 0.9740])
# ------calling energy function------
# x tensor([ 0.7658])
# y grad tensor([ 0.5350])
# px tensor([ 0.2976])
# result tensor([ 0.1592])
# g:tensor([ 0.9447])
# ------calling energy function------
# x tensor([ 0.7397])
# y grad tensor([ 0.5227])
# px tensor([ 0.3035])
# result tensor([ 0.1586])
# g:tensor([ 0.9094])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7397])
# y grad tensor([ 0.5227])
# px tensor([ 0.3035])
# result tensor([ 0.1586])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7397])
# y grad tensor([ 0.5227])
# px tensor([ 0.3035])
# result tensor([ 0.1586])
# Sample: 47
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 9.0959]) True
# ------calling energy function------
# x tensor([ 0.7397])
# y grad tensor([ 0.5227])
# px tensor([ 0.3035])
# result tensor([ 0.1586])
# g:tensor([ 0.9094])
# grad1:tensor([ 0.9094])
# momtensor([ 0.4230])
# ------calling energy function------
# x tensor([ 0.7596])
# y grad tensor([ 0.5321])
# px tensor([ 0.2990])
# result tensor([ 0.1591])
# g:tensor([ 0.9363])
# ------calling energy function------
# x tensor([ 0.7748])
# y grad tensor([ 0.5392])
# px tensor([ 0.2955])
# result tensor([ 0.1593])
# g:tensor([ 0.9570])
# ------calling energy function------
# x tensor([ 0.7850])
# y grad tensor([ 0.5439])
# px tensor([ 0.2932])
# result tensor([ 0.1594])
# g:tensor([ 0.9708])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7850])
# y grad tensor([ 0.5439])
# px tensor([ 0.2932])
# result tensor([ 0.1594])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7850])
# y grad tensor([ 0.5439])
# px tensor([ 0.2932])
# result tensor([ 0.1594])
# Sample: 48
# ========== simulate ==============
# pos:tensor([ 0.1759]) True
# ------calling energy function------
# x tensor([ 0.7850])
# y grad tensor([ 0.5439])
# px tensor([ 0.2932])
# result tensor([ 0.1594])
# g:tensor([ 0.9708])
# grad1:tensor([ 0.9708])
# momtensor(1.00000e-02 *
#        [-2.8886])
# ------calling energy function------
# x tensor([ 0.7808])
# y grad tensor([ 0.5419])
# px tensor([ 0.2941])
# result tensor([ 0.1594])
# g:tensor([ 0.9651])
# ------calling energy function------
# x tensor([ 0.7714])
# y grad tensor([ 0.5376])
# px tensor([ 0.2963])
# result tensor([ 0.1593])
# g:tensor([ 0.9523])
# ------calling energy function------
# x tensor([ 0.7570])
# y grad tensor([ 0.5309])
# px tensor([ 0.2996])
# result tensor([ 0.1590])
# g:tensor([ 0.9328])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7570])
# y grad tensor([ 0.5309])
# px tensor([ 0.2996])
# result tensor([ 0.1590])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7570])
# y grad tensor([ 0.5309])
# px tensor([ 0.2996])
# result tensor([ 0.1590])
# Sample: 49
# ========== simulate ==============
# pos:tensor([ 0.1239]) True
# ------calling energy function------
# x tensor([ 0.7570])
# y grad tensor([ 0.5309])
# px tensor([ 0.2996])
# result tensor([ 0.1590])
# g:tensor([ 0.9328])
# grad1:tensor([ 0.9328])
# momtensor([ 0.5695])
# ------calling energy function------
# x tensor([ 0.7851])
# y grad tensor([ 0.5439])
# px tensor([ 0.2931])
# result tensor([ 0.1594])
# g:tensor([ 0.9710])
# ------calling energy function------
# x tensor([ 0.8085])
# y grad tensor([ 0.5545])
# px tensor([ 0.2877])
# result tensor([ 0.1595])
# g:tensor([ 1.0027])
# ------calling energy function------
# x tensor([ 0.8266])
# y grad tensor([ 0.5625])
# px tensor([ 0.2835])
# result tensor([ 0.1595])
# g:tensor([ 1.0275])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8266])
# y grad tensor([ 0.5625])
# px tensor([ 0.2835])
# ...
# x tensor([ 0.7143])
# y grad tensor([ 0.5105])
# px tensor([ 0.3091])
# result tensor([ 0.1578])
# g:tensor([ 0.8751])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7143])
# y grad tensor([ 0.5105])
# px tensor([ 0.3091])
# result tensor([ 0.1578])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7143])
# y grad tensor([ 0.5105])
# px tensor([ 0.3091])
# result tensor([ 0.1578])
# Sample: 484
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 4.1836]) True
# ------calling energy function------
# x tensor([ 0.7143])
# y grad tensor([ 0.5105])
# px tensor([ 0.3091])
# result tensor([ 0.1578])
# g:tensor([ 0.8751])
# grad1:tensor([ 0.8751])
# momtensor([ 0.3722])
# ------calling energy function------
# x tensor([ 0.7312])
# y grad tensor([ 0.5187])
# px tensor([ 0.3054])
# result tensor([ 0.1584])
# g:tensor([ 0.8979])
# ------calling energy function------
# x tensor([ 0.7436])
# y grad tensor([ 0.5246])
# px tensor([ 0.3026])
# result tensor([ 0.1587])
# g:tensor([ 0.9147])
# ------calling energy function------
# x tensor([ 0.7514])
# y grad tensor([ 0.5283])
# px tensor([ 0.3008])
# result tensor([ 0.1589])
# g:tensor([ 0.9252])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7514])
# y grad tensor([ 0.5283])
# px tensor([ 0.3008])
# result tensor([ 0.1589])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7514])
# y grad tensor([ 0.5283])
# px tensor([ 0.3008])
# result tensor([ 0.1589])
# Sample: 485
# ========== simulate ==============
# pos:tensor([ 0.1133]) True
# ------calling energy function------
# x tensor([ 0.7514])
# y grad tensor([ 0.5283])
# px tensor([ 0.3008])
# result tensor([ 0.1589])
# g:tensor([ 0.9252])
# grad1:tensor([ 0.9252])
# momtensor([ 1.0234])
# ------calling energy function------
# x tensor([ 0.8042])
# y grad tensor([ 0.5525])
# px tensor([ 0.2887])
# result tensor([ 0.1595])
# g:tensor([ 0.9969])
# ------calling energy function------
# x tensor([ 0.8536])
# y grad tensor([ 0.5741])
# px tensor([ 0.2771])
# result tensor([ 0.1591])
# g:tensor([ 1.0642])
# ------calling energy function------
# x tensor([ 0.8986])
# y grad tensor([ 0.5929])
# px tensor([ 0.2664])
# result tensor([ 0.1580])
# g:tensor([ 1.1256])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8986])
# y grad tensor([ 0.5929])
# px tensor([ 0.2664])
# result tensor([ 0.1580])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8986])
# y grad tensor([ 0.5929])
# px tensor([ 0.2664])
# result tensor([ 0.1580])
# Sample: 486
# ========== simulate ==============
# pos:tensor([ 0.3758]) True
# ------calling energy function------
# x tensor([ 0.8986])
# y grad tensor([ 0.5929])
# px tensor([ 0.2664])
# result tensor([ 0.1580])
# g:tensor([ 1.1256])
# grad1:tensor([ 1.1256])
# momtensor([ 2.2721])
# ------calling energy function------
# x tensor([ 1.0358])
# y grad tensor([ 0.6451])
# px tensor([ 0.2333])
# result tensor([ 0.1505])
# g:tensor([ 1.3132])
# ------calling energy function------
# x tensor([ 1.1751])
# y grad tensor([ 0.6912])
# px tensor([ 0.2000])
# result tensor([ 0.1382])
# g:tensor([ 1.5035])
# ------calling energy function------
# x tensor([ 1.3127])
# y grad tensor([ 0.7309])
# px tensor([ 0.1685])
# result tensor([ 0.1232])
# g:tensor([ 1.6904])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.3127])
# y grad tensor([ 0.7309])
# px tensor([ 0.1685])
# result tensor([ 0.1232])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.3127])
# y grad tensor([ 0.7309])
# px tensor([ 0.1685])
# result tensor([ 0.1232])
# Sample: 487
# ========== simulate ==============
# pos:tensor([ 0.9993]) True
# ------calling energy function------
# x tensor([ 1.3127])
# y grad tensor([ 0.7309])
# px tensor([ 0.1685])
# result tensor([ 0.1232])
# g:tensor([ 1.6904])
# grad1:tensor([ 1.6904])
# momtensor([-0.2410])
# ------calling energy function------
# x tensor([ 1.2890])
# y grad tensor([ 0.7245])
# px tensor([ 0.1738])
# result tensor([ 0.1259])
# g:tensor([ 1.6583])
# ------calling energy function------
# x tensor([ 1.2537])
# y grad tensor([ 0.7145])
# px tensor([ 0.1818])
# result tensor([ 0.1299])
# g:tensor([ 1.6103])
# ------calling energy function------
# x tensor([ 1.2075])
# y grad tensor([ 0.7011])
# px tensor([ 0.1924])
# result tensor([ 0.1349])
# g:tensor([ 1.5476])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.2075])
# y grad tensor([ 0.7011])
# px tensor([ 0.1924])
# result tensor([ 0.1349])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.2075])
# y grad tensor([ 0.7011])
# px tensor([ 0.1924])
# result tensor([ 0.1349])
# Sample: 488
# ========== simulate ==============
# pos:tensor([ 0.8523]) True
# ------calling energy function------
# x tensor([ 1.2075])
# y grad tensor([ 0.7011])
# px tensor([ 0.1924])
# result tensor([ 0.1349])
# g:tensor([ 1.5476])
# grad1:tensor([ 1.5476])
# momtensor([ 0.6645])
# ------calling energy function------
# x tensor([ 1.2490])
# y grad tensor([ 0.7132])
# px tensor([ 0.1829])
# result tensor([ 0.1304])
# g:tensor([ 1.6040])
# ------calling energy function------
# x tensor([ 1.2796])
# y grad tensor([ 0.7219])
# px tensor([ 0.1759])
# result tensor([ 0.1270])
# g:tensor([ 1.6456])
# ------calling energy function------
# x tensor([ 1.2986])
# y grad tensor([ 0.7271])
# px tensor([ 0.1717])
# result tensor([ 0.1248])
# g:tensor([ 1.6713])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.2986])
# y grad tensor([ 0.7271])
# px tensor([ 0.1717])
# result tensor([ 0.1248])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.2986])
# y grad tensor([ 0.7271])
# px tensor([ 0.1717])
# result tensor([ 0.1248])
# Sample: 489
# ========== simulate ==============
# pos:tensor([ 0.9799]) True
# ------calling energy function------
# x tensor([ 1.2986])
# y grad tensor([ 0.7271])
# px tensor([ 0.1717])
# result tensor([ 0.1248])
# g:tensor([ 1.6713])
# grad1:tensor([ 1.6713])
# momtensor([-0.4514])
# ------calling energy function------
# x tensor([ 1.2600])
# y grad tensor([ 0.7163])
# px tensor([ 0.1804])
# result tensor([ 0.1292])
# g:tensor([ 1.6190])
# ------calling energy function------
# x tensor([ 1.2106])
# y grad tensor([ 0.7020])
# px tensor([ 0.1917])
# result tensor([ 0.1346])
# g:tensor([ 1.5518])
# ------calling energy function------
# x tensor([ 1.1515])
# y grad tensor([ 0.6839])
# px tensor([ 0.2056])
# result tensor([ 0.1406])
# g:tensor([ 1.4713])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.1515])
# y grad tensor([ 0.6839])
# px tensor([ 0.2056])
# result tensor([ 0.1406])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.1515])
# y grad tensor([ 0.6839])
# px tensor([ 0.2056])
# result tensor([ 0.1406])
# Sample: 490
# ========== simulate ==============
# pos:tensor([ 0.7715]) True
# ------calling energy function------
# x tensor([ 1.1515])
# y grad tensor([ 0.6839])
# px tensor([ 0.2056])
# result tensor([ 0.1406])
# g:tensor([ 1.4713])
# grad1:tensor([ 1.4713])
# momtensor([ 1.0543])
# ------calling energy function------
# x tensor([ 1.2196])
# y grad tensor([ 0.7047])
# px tensor([ 0.1896])
# result tensor([ 0.1336])
# g:tensor([ 1.5641])
# ------calling energy function------
# x tensor([ 1.2784])
# y grad tensor([ 0.7215])
# px tensor([ 0.1762])
# result tensor([ 0.1271])
# g:tensor([ 1.6439])
# ------calling energy function------
# x tensor([ 1.3265])
# y grad tensor([ 0.7346])
# px tensor([ 0.1655])
# result tensor([ 0.1216])
# g:tensor([ 1.7090])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.3265])
# y grad tensor([ 0.7346])
# px tensor([ 0.1655])
# result tensor([ 0.1216])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.3265])
# y grad tensor([ 0.7346])
# px tensor([ 0.1655])
# result tensor([ 0.1216])
# Sample: 491
# ========== simulate ==============
# pos:tensor([ 1.0180]) True
# ------calling energy function------
# x tensor([ 1.3265])
# y grad tensor([ 0.7346])
# px tensor([ 0.1655])
# result tensor([ 0.1216])
# g:tensor([ 1.7090])
# grad1:tensor([ 1.7090])
# momtensor([ 1.0186])
# ------calling energy function------
# x tensor([ 1.3959])
# y grad tensor([ 0.7524])
# px tensor([ 0.1506])
# result tensor([ 0.1133])
# g:tensor([ 1.8026])
# ------calling energy function------
# x tensor([ 1.4530])
# y grad tensor([ 0.7661])
# px tensor([ 0.1388])
# result tensor([ 0.1064])
# g:tensor([ 1.8794])
# ------calling energy function------
# x tensor([ 1.4966])
# y grad tensor([ 0.7761])
# px tensor([ 0.1302])
# result tensor([ 0.1010])
# g:tensor([ 1.9376])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.4966])
# y grad tensor([ 0.7761])
# px tensor([ 0.1302])
# result tensor([ 0.1010])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.4966])
# y grad tensor([ 0.7761])
# px tensor([ 0.1302])
# result tensor([ 0.1010])
# Sample: 492
# ========== simulate ==============
# pos:tensor([ 1.2431]) True
# ------calling energy function------
# x tensor([ 1.4966])
# y grad tensor([ 0.7761])
# px tensor([ 0.1302])
# result tensor([ 0.1010])
# g:tensor([ 1.9376])
# grad1:tensor([ 1.9376])
# momtensor([-0.7092])
# ------calling energy function------
# x tensor([ 1.4346])
# y grad tensor([ 0.7618])
# px tensor([ 0.1426])
# result tensor([ 0.1086])
# g:tensor([ 1.8547])
# ------calling energy function------
# x tensor([ 1.3600])
# y grad tensor([ 0.7433])
# px tensor([ 0.1582])
# result tensor([ 0.1176])
# g:tensor([ 1.7543])
# ------calling energy function------
# x tensor([ 1.2746])
# y grad tensor([ 0.7204])
# px tensor([ 0.1771])
# result tensor([ 0.1276])
# g:tensor([ 1.6387])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.2746])
# y grad tensor([ 0.7204])
# px tensor([ 0.1771])
# result tensor([ 0.1276])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.2746])
# y grad tensor([ 0.7204])
# px tensor([ 0.1771])
# result tensor([ 0.1276])
# Sample: 493
# ========== simulate ==============
# pos:tensor([ 0.9467]) True
# ------calling energy function------
# x tensor([ 1.2746])
# y grad tensor([ 0.7204])
# px tensor([ 0.1771])
# result tensor([ 0.1276])
# g:tensor([ 1.6387])
# grad1:tensor([ 1.6387])
# momtensor(1.00000e-02 *
#        [-7.8223])
# ------calling energy function------
# x tensor([ 1.2631])
# y grad tensor([ 0.7172])
# px tensor([ 0.1797])
# result tensor([ 0.1289])
# g:tensor([ 1.6231])
# ------calling energy function------
# x tensor([ 1.2400])
# y grad tensor([ 0.7106])
# px tensor([ 0.1849])
# result tensor([ 0.1314])
# g:tensor([ 1.5918])
# ------calling energy function------
# x tensor([ 1.2060])
# y grad tensor([ 0.7006])
# px tensor([ 0.1928])
# result tensor([ 0.1351])
# g:tensor([ 1.5456])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.2060])
# y grad tensor([ 0.7006])
# px tensor([ 0.1928])
# result tensor([ 0.1351])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.2060])
# y grad tensor([ 0.7006])
# px tensor([ 0.1928])
# result tensor([ 0.1351])
# Sample: 494
# ========== simulate ==============
# pos:tensor([ 0.8503]) True
# ------calling energy function------
# x tensor([ 1.2060])
# y grad tensor([ 0.7006])
# px tensor([ 0.1928])
# result tensor([ 0.1351])
# g:tensor([ 1.5456])
# grad1:tensor([ 1.5456])
# momtensor([-0.8615])
# ------calling energy function------
# x tensor([ 1.1412])
# y grad tensor([ 0.6806])
# px tensor([ 0.2080])
# result tensor([ 0.1416])
# g:tensor([ 1.4572])
# ------calling energy function------
# x tensor([ 1.0687])
# y grad tensor([ 0.6565])
# px tensor([ 0.2254])
# result tensor([ 0.1480])
# g:tensor([ 1.3582])
# ------calling energy function------
# x tensor([ 0.9903])
# y grad tensor([ 0.6285])
# px tensor([ 0.2443])
# result tensor([ 0.1536])
# g:tensor([ 1.2509])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.9903])
# y grad tensor([ 0.6285])
# px tensor([ 0.2443])
# result tensor([ 0.1536])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.9903])
# y grad tensor([ 0.6285])
# px tensor([ 0.2443])
# result tensor([ 0.1536])
# Sample: 495
# ========== simulate ==============
# pos:tensor([ 0.5259]) True
# ------calling energy function------
# x tensor([ 0.9903])
# y grad tensor([ 0.6285])
# px tensor([ 0.2443])
# result tensor([ 0.1536])
# g:tensor([ 1.2509])
# grad1:tensor([ 1.2509])
# momtensor([ 1.1843])
# ------calling energy function------
# x tensor([ 1.0622])
# y grad tensor([ 0.6543])
# px tensor([ 0.2269])
# result tensor([ 0.1485])
# g:tensor([ 1.3494])
# ------calling energy function------
# x tensor([ 1.1279])
# y grad tensor([ 0.6763])
# px tensor([ 0.2112])
# result tensor([ 0.1428])
# g:tensor([ 1.4391])
# ------calling energy function------
# x tensor([ 1.1857])
# y grad tensor([ 0.6945])
# px tensor([ 0.1975])
# result tensor([ 0.1372])
# g:tensor([ 1.5178])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.1857])
# y grad tensor([ 0.6945])
# px tensor([ 0.1975])
# result tensor([ 0.1372])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.1857])
# y grad tensor([ 0.6945])
# px tensor([ 0.1975])
# result tensor([ 0.1372])
# Sample: 496
# ========== simulate ==============
# pos:tensor([ 0.8210]) True
# ------calling energy function------
# x tensor([ 1.1857])
# y grad tensor([ 0.6945])
# px tensor([ 0.1975])
# result tensor([ 0.1372])
# g:tensor([ 1.5178])
# grad1:tensor([ 1.5178])
# momtensor([-0.4140])
# ------calling energy function------
# x tensor([ 1.1519])
# y grad tensor([ 0.6840])
# px tensor([ 0.2055])
# result tensor([ 0.1405])
# g:tensor([ 1.4718])
# ------calling energy function------
# x tensor([ 1.1088])
# y grad tensor([ 0.6700])
# px tensor([ 0.2158])
# result tensor([ 0.1446])
# g:tensor([ 1.4129])
# ------calling energy function------
# x tensor([ 1.0573])
# y grad tensor([ 0.6526])
# px tensor([ 0.2281])
# result tensor([ 0.1489])
# g:tensor([ 1.3426])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.0573])
# y grad tensor([ 0.6526])
# px tensor([ 0.2281])
# result tensor([ 0.1489])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.1857])
# y grad tensor([ 0.6945])
# px tensor([ 0.1975])
# result tensor([ 0.1372])
# Sample: 497
# ========== simulate ==============
# pos:tensor([ 0.8210]) True
# ------calling energy function------
# x tensor([ 1.1857])
# y grad tensor([ 0.6945])
# px tensor([ 0.1975])
# result tensor([ 0.1372])
# g:tensor([ 1.5178])
# grad1:tensor([ 1.5178])
# momtensor([-0.8228])
# ------calling energy function------
# x tensor([ 1.1241])
# y grad tensor([ 0.6751])
# px tensor([ 0.2121])
# result tensor([ 0.1432])
# g:tensor([ 1.4339])
# ------calling energy function------
# x tensor([ 1.0550])
# y grad tensor([ 0.6518])
# px tensor([ 0.2287])
# result tensor([ 0.1491])
# g:tensor([ 1.3394])
# ------calling energy function------
# x tensor([ 0.9799])
# y grad tensor([ 0.6247])
# px tensor([ 0.2468])
# result tensor([ 0.1542])
# g:tensor([ 1.2368])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.9799])
# y grad tensor([ 0.6247])
# px tensor([ 0.2468])
# result tensor([ 0.1542])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.1857])
# y grad tensor([ 0.6945])
# px tensor([ 0.1975])
# result tensor([ 0.1372])
# Sample: 498
# ========== simulate ==============
# pos:tensor([ 0.8210]) True
# ------calling energy function------
# x tensor([ 1.1857])
# y grad tensor([ 0.6945])
# px tensor([ 0.1975])
# result tensor([ 0.1372])
# g:tensor([ 1.5178])
# grad1:tensor([ 1.5178])
# momtensor([ 0.5771])
# ------calling energy function------
# x tensor([ 1.2207])
# y grad tensor([ 0.7050])
# px tensor([ 0.1894])
# result tensor([ 0.1335])
# g:tensor([ 1.5656])
# ------calling energy function------
# x tensor([ 1.2452])
# y grad tensor([ 0.7121])
# px tensor([ 0.1838])
# result tensor([ 0.1309])
# g:tensor([ 1.5988])
# ------calling energy function------
# x tensor([ 1.2584])
# y grad tensor([ 0.7159])
# px tensor([ 0.1807])
# result tensor([ 0.1294])
# g:tensor([ 1.6167])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.2584])
# y grad tensor([ 0.7159])
# px tensor([ 0.1807])
# result tensor([ 0.1294])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.2584])
# y grad tensor([ 0.7159])
# px tensor([ 0.1807])
# result tensor([ 0.1294])
# Sample: 499
# ========== simulate ==============
# pos:tensor([ 0.9241]) True
# ------calling energy function------
# x tensor([ 1.2584])
# y grad tensor([ 0.7159])
# px tensor([ 0.1807])
# result tensor([ 0.1294])
# g:tensor([ 1.6167])
# grad1:tensor([ 1.6167])
# momtensor([ 0.6472])
# ------calling energy function------
# x tensor([ 1.2992])
# y grad tensor([ 0.7273])
# px tensor([ 0.1715])
# result tensor([ 0.1248])
# g:tensor([ 1.6721])
# ------calling energy function------
# x tensor([ 1.3284])
# y grad tensor([ 0.7351])
# px tensor([ 0.1651])
# result tensor([ 0.1214])
# g:tensor([ 1.7116])
# ------calling energy function------
# x tensor([ 1.3452])
# y grad tensor([ 0.7395])
# px tensor([ 0.1614])
# result tensor([ 0.1194])
# g:tensor([ 1.7343])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.3452])
# y grad tensor([ 0.7395])
# px tensor([ 0.1614])
# result tensor([ 0.1194])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.3452])
# y grad tensor([ 0.7395])
# px tensor([ 0.1614])
# result tensor([ 0.1194])

# %%
x_list = [np.log(1+np.exp(e)) for e in y_list]
plt.hist(x_list)
plt.show()

# %%
"""
x_list = []
y_list = []
for i in range(100):
    pos_samples, mom_samples, ratio = sampler.get_samples(init, 0.1, 5, 1, torch.tensor([1.], requires_grad=True))
    y = pos_samples.detach().numpy()[0][0]
    x = torch.log(1+torch.exp(pos_samples)).detach().numpy()[0][0]
    x_list.append(x)
    y_list.append(y)
"""
# Out:
# '\nx_list = []\ny_list = []\nfor i in range(100):\n    pos_samples, mom_samples, ratio = sampler.get_samples(init, 0.1, 5, 1, torch.tensor([1.], requires_grad=True))\n    y = pos_samples.detach().numpy()[0][0]\n    x = torch.log(1+torch.exp(pos_samples)).detach().numpy()[0][0]\n    x_list.append(x)\n    y_list.append(y)\n'

# %%
l = []
for i in range(1000):
    prng = np.random.RandomState()
    x = prng.normal(0)
    l.append(x)
x = prng.normal([0, 0])
print(x)
plt.hist(l)
plt.show()
# Out:
# [ 1.61497581  0.31790423]
