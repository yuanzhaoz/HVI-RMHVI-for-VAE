# %%
import sys
sys.path.append('F:\Cambridge\Project\MHMC-for-VAE/hmc_pytorch')
from hmc_base_pytorch import *
from hmc_unconstrained_pytorch import *
import autograd.numpy as np
import torch
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.distributions.normal import Normal
import matplotlib.pyplot as plt

# %% [markdown]
# # Get pdf p(y) of proxy variable y for x = g(y) where p(x) is known

# %%
def reparameter_pdf(transform, x_pdf, y):
    '''
    transform: function x = g(y) that transforms random variable y into x
    x_pdf: pdf of x
    '''
    # get gradient g'(y)
    #y.grad.zero_()
    #yy = torch.tensor([y.item()], requires_grad=True)
    #y.retain_grad()
    yy = y.clone()
    yy.retain_grad()
    x = transform(yy)
    print("x "+str(x))
    num = yy.shape[0]
    tmp = torch.ones(num)
    x.backward(tmp,retain_graph=True)
    print("y grad "+str(yy.grad))
    grad = torch.abs(yy.grad).float()

    
    # get p_x(x)
    px = x_pdf(x)
    print("px "+str(px))
    result = px*grad
    yy.grad.data.zero_()
    print("result "+str(result))
    #print(px.dtype)
    return result

# %%
def transform(y):
    return torch.log(1 + torch.exp(y))

def x_pdf(x):
    m = Normal(torch.tensor([0.]), torch.tensor([1.]))
    m.requires_grad=True
    n = torch.exp(m.log_prob(x))
    #n.requires_grad=True
    return n

def energy_function(y, cache):
    y.retain_grad()
    p = reparameter_pdf(transform, x_pdf, y)
    #y.grad.zero_()
    return 0-torch.log(p)

# %%
"""
def energy_function(y, cache):
    y.retain_grad()
    m = Normal(torch.tensor([0.]), torch.tensor([1.]))
    n = torch.exp(m.log_prob(y))
    return 0 - torch.log(n)
    
def gradient(pos, cache):
    pos.retain_grad()
    r = energy_function(pos, cache)
    r.backward(retain_graph=True)
    g = pos.grad.clone()
    
    print("g:"+str(pos.grad))
    #pos.grad.zero_()
    pos.grad.data.zero_()
    return g
    
pos = torch.tensor([0.], requires_grad=True)
gradient(pos, None)
"""
# Out:
# '\ndef energy_function(y, cache):\n    y.retain_grad()\n    m = Normal(torch.tensor([0.]), torch.tensor([1.]))\n    n = torch.exp(m.log_prob(y))\n    return 0 - torch.log(n)\n    \ndef gradient(pos, cache):\n    pos.retain_grad()\n    r = energy_function(pos, cache)\n    r.backward(retain_graph=True)\n    g = pos.grad.clone()\n    \n    print("g:"+str(pos.grad))\n    #pos.grad.zero_()\n    pos.grad.data.zero_()\n    return g\n    \npos = torch.tensor([0.], requires_grad=True)\ngradient(pos, None)\n'

# %%
y = torch.tensor([0.], requires_grad=True)
transform(y).requires_grad
#energy_function(y, None).requires_grad
# Out:
# True

# %%
sampler = IsotropicHmcSampler(energy_function, energy_grad=None, prng=None,
                 mom_resample_coeff=1., dtype=np.float64)

# %%
init = torch.tensor([0.], requires_grad=True)
pos_samples, mom_samples, ratio = sampler.get_samples(init, 0.1, 3, 800, torch.tensor([1.], requires_grad=True))
num = pos_samples.shape[0]
y_list = []
for i in range(num):
    y_list.append(pos_samples[i].item())
# Out:
# ========== 1st hamiltonian ==============
# x tensor([ 0.6931])
# y grad tensor([ 0.5000])
# px tensor([ 0.3137])
# result tensor([ 0.1569])
# Sample: 1
# ========== simulate ==============
# pos:tensor([ 0.]) True
# ------calling energy function------
# x tensor([ 0.6931])
# y grad tensor([ 0.5000])
# px tensor([ 0.3137])
# result tensor([ 0.1569])
# g:tensor([ 0.8466])
# grad1:tensor([ 0.8466])
# momtensor([-0.7508])
# ------calling energy function------
# x tensor([ 0.6543])
# y grad tensor([ 0.4802])
# px tensor([ 0.3221])
# result tensor([ 0.1547])
# g:tensor([ 0.7944])
# ------calling energy function------
# x tensor([ 0.6133])
# y grad tensor([ 0.4585])
# px tensor([ 0.3305])
# result tensor([ 0.1515])
# g:tensor([ 0.7396])
# ------calling energy function------
# x tensor([ 0.5710])
# y grad tensor([ 0.4351])
# px tensor([ 0.3389])
# result tensor([ 0.1475])
# g:tensor([ 0.6835])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5710])
# y grad tensor([ 0.4351])
# px tensor([ 0.3389])
# result tensor([ 0.1475])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6931])
# y grad tensor([ 0.5000])
# px tensor([ 0.3137])
# result tensor([ 0.1569])
# Sample: 2
# ========== simulate ==============
# pos:tensor([ 0.]) True
# ------calling energy function------
# x tensor([ 0.6931])
# y grad tensor([ 0.5000])
# px tensor([ 0.3137])
# result tensor([ 0.1569])
# g:tensor([ 0.8466])
# grad1:tensor([ 0.8466])
# momtensor(1.00000e-02 *
#        [ 5.8442])
# ------calling energy function------
# x tensor([ 0.6940])
# y grad tensor([ 0.5004])
# px tensor([ 0.3136])
# result tensor([ 0.1569])
# g:tensor([ 0.8477])
# ------calling energy function------
# x tensor([ 0.6905])
# y grad tensor([ 0.4987])
# px tensor([ 0.3143])
# result tensor([ 0.1567])
# g:tensor([ 0.8430])
# ------calling energy function------
# x tensor([ 0.6829])
# y grad tensor([ 0.4949])
# px tensor([ 0.3160])
# result tensor([ 0.1564])
# g:tensor([ 0.8328])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6829])
# y grad tensor([ 0.4949])
# px tensor([ 0.3160])
# result tensor([ 0.1564])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6829])
# y grad tensor([ 0.4949])
# px tensor([ 0.3160])
# result tensor([ 0.1564])
# Sample: 3
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [-2.0550]) True
# ------calling energy function------
# x tensor([ 0.6829])
# y grad tensor([ 0.4949])
# px tensor([ 0.3160])
# result tensor([ 0.1564])
# g:tensor([ 0.8328])
# grad1:tensor([ 0.8328])
# momtensor([ 0.1070])
# ------calling energy function------
# x tensor([ 0.6862])
# y grad tensor([ 0.4965])
# px tensor([ 0.3153])
# result tensor([ 0.1565])
# g:tensor([ 0.8372])
# ------calling energy function------
# x tensor([ 0.6853])
# y grad tensor([ 0.4960])
# px tensor([ 0.3155])
# result tensor([ 0.1565])
# g:tensor([ 0.8360])
# ------calling energy function------
# x tensor([ 0.6802])
# y grad tensor([ 0.4935])
# px tensor([ 0.3165])
# result tensor([ 0.1562])
# g:tensor([ 0.8292])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6802])
# y grad tensor([ 0.4935])
# px tensor([ 0.3165])
# result tensor([ 0.1562])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6802])
# y grad tensor([ 0.4935])
# px tensor([ 0.3165])
# result tensor([ 0.1562])
# Sample: 4
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [-2.6039]) True
# ------calling energy function------
# x tensor([ 0.6802])
# y grad tensor([ 0.4935])
# px tensor([ 0.3165])
# result tensor([ 0.1562])
# g:tensor([ 0.8292])
# grad1:tensor([ 0.8292])
# momtensor([ 0.5229])
# ------calling energy function------
# x tensor([ 0.7043])
# y grad tensor([ 0.5055])
# px tensor([ 0.3113])
# result tensor([ 0.1574])
# g:tensor([ 0.8615])
# ------calling energy function------
# x tensor([ 0.7244])
# y grad tensor([ 0.5154])
# px tensor([ 0.3069])
# result tensor([ 0.1582])
# g:tensor([ 0.8888])
# ------calling energy function------
# x tensor([ 0.7403])
# y grad tensor([ 0.5231])
# px tensor([ 0.3033])
# result tensor([ 0.1586])
# g:tensor([ 0.9103])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7403])
# y grad tensor([ 0.5231])
# px tensor([ 0.3033])
# result tensor([ 0.1586])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7403])
# y grad tensor([ 0.5231])
# px tensor([ 0.3033])
# result tensor([ 0.1586])
# Sample: 5
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 9.2273]) True
# ------calling energy function------
# x tensor([ 0.7403])
# y grad tensor([ 0.5231])
# px tensor([ 0.3033])
# result tensor([ 0.1586])
# g:tensor([ 0.9103])
# grad1:tensor([ 0.9103])
# momtensor([-0.7278])
# ------calling energy function------
# x tensor([ 0.7006])
# y grad tensor([ 0.5037])
# px tensor([ 0.3121])
# result tensor([ 0.1572])
# g:tensor([ 0.8567])
# ------calling energy function------
# x tensor([ 0.6583])
# y grad tensor([ 0.4823])
# px tensor([ 0.3212])
# result tensor([ 0.1549])
# g:tensor([ 0.7997])
# ------calling energy function------
# x tensor([ 0.6141])
# y grad tensor([ 0.4589])
# px tensor([ 0.3304])
# result tensor([ 0.1516])
# g:tensor([ 0.7407])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6141])
# y grad tensor([ 0.4589])
# px tensor([ 0.3304])
# result tensor([ 0.1516])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6141])
# y grad tensor([ 0.4589])
# px tensor([ 0.3304])
# result tensor([ 0.1516])
# Sample: 6
# ========== simulate ==============
# pos:tensor([-0.1649]) True
# ------calling energy function------
# x tensor([ 0.6141])
# y grad tensor([ 0.4589])
# px tensor([ 0.3304])
# result tensor([ 0.1516])
# g:tensor([ 0.7407])
# grad1:tensor([ 0.7407])
# momtensor([ 0.9235])
# ------calling energy function------
# x tensor([ 0.6558])
# y grad tensor([ 0.4810])
# px tensor([ 0.3218])
# result tensor([ 0.1548])
# g:tensor([ 0.7964])
# ------calling energy function------
# x tensor([ 0.6954])
# y grad tensor([ 0.5011])
# px tensor([ 0.3133])
# result tensor([ 0.1570])
# g:tensor([ 0.8496])
# ------calling energy function------
# x tensor([ 0.7322])
# y grad tensor([ 0.5192])
# px tensor([ 0.3051])
# result tensor([ 0.1584])
# g:tensor([ 0.8993])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7322])
# y grad tensor([ 0.5192])
# px tensor([ 0.3051])
# result tensor([ 0.1584])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7322])
# y grad tensor([ 0.5192])
# px tensor([ 0.3051])
# result tensor([ 0.1584])
# Sample: 7
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 7.6649]) True
# ------calling energy function------
# x tensor([ 0.7322])
# y grad tensor([ 0.5192])
# px tensor([ 0.3051])
# result tensor([ 0.1584])
# g:tensor([ 0.8993])
# grad1:tensor([ 0.8993])
# momtensor([ 1.7097])
# ------calling energy function------
# x tensor([ 0.8221])
# y grad tensor([ 0.5605])
# px tensor([ 0.2846])
# result tensor([ 0.1595])
# g:tensor([ 1.0212])
# ------calling energy function------
# x tensor([ 0.9126])
# y grad tensor([ 0.5985])
# px tensor([ 0.2631])
# result tensor([ 0.1574])
# g:tensor([ 1.1448])
# ------calling energy function------
# x tensor([ 1.0018])
# y grad tensor([ 0.6328])
# px tensor([ 0.2415])
# result tensor([ 0.1528])
# g:tensor([ 1.2667])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.0018])
# y grad tensor([ 0.6328])
# px tensor([ 0.2415])
# result tensor([ 0.1528])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.0018])
# y grad tensor([ 0.6328])
# px tensor([ 0.2415])
# result tensor([ 0.1528])
# Sample: 8
# ========== simulate ==============
# pos:tensor([ 0.5442]) True
# ------calling energy function------
# x tensor([ 1.0018])
# y grad tensor([ 0.6328])
# px tensor([ 0.2415])
# result tensor([ 0.1528])
# g:tensor([ 1.2667])
# grad1:tensor([ 1.2667])
# momtensor([-1.0127])
# ------calling energy function------
# x tensor([ 0.9351])
# y grad tensor([ 0.6074])
# px tensor([ 0.2577])
# result tensor([ 0.1565])
# g:tensor([ 1.1755])
# ------calling energy function------
# x tensor([ 0.8643])
# y grad tensor([ 0.5786])
# px tensor([ 0.2746])
# result tensor([ 0.1589])
# g:tensor([ 1.0788])
# ------calling energy function------
# x tensor([ 0.7911])
# y grad tensor([ 0.5466])
# px tensor([ 0.2918])
# result tensor([ 0.1595])
# g:tensor([ 0.9791])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7911])
# y grad tensor([ 0.5466])
# px tensor([ 0.2918])
# result tensor([ 0.1595])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7911])
# y grad tensor([ 0.5466])
# px tensor([ 0.2918])
# result tensor([ 0.1595])
# Sample: 9
# ========== simulate ==============
# pos:tensor([ 0.1871]) True
# ------calling energy function------
# x tensor([ 0.7911])
# y grad tensor([ 0.5466])
# px tensor([ 0.2918])
# result tensor([ 0.1595])
# g:tensor([ 0.9791])
# grad1:tensor([ 0.9791])
# momtensor([-1.1427])
# ------calling energy function------
# x tensor([ 0.7277])
# y grad tensor([ 0.5170])
# px tensor([ 0.3061])
# result tensor([ 0.1583])
# g:tensor([ 0.8932])
# ------calling energy function------
# x tensor([ 0.6635])
# y grad tensor([ 0.4850])
# px tensor([ 0.3201])
# result tensor([ 0.1552])
# g:tensor([ 0.8067])
# ------calling energy function------
# x tensor([ 0.5998])
# y grad tensor([ 0.4511])
# px tensor([ 0.3333])
# result tensor([ 0.1503])
# g:tensor([ 0.7216])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5998])
# y grad tensor([ 0.4511])
# px tensor([ 0.3333])
# result tensor([ 0.1503])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5998])
# y grad tensor([ 0.4511])
# px tensor([ 0.3333])
# result tensor([ 0.1503])
# Sample: 10
# ========== simulate ==============
# pos:tensor([-0.1963]) True
# ------calling energy function------
# x tensor([ 0.5998])
# y grad tensor([ 0.4511])
# px tensor([ 0.3333])
# result tensor([ 0.1503])
# g:tensor([ 0.7216])
# grad1:tensor([ 0.7216])
# momtensor([ 0.7726])
# ------calling energy function------
# x tensor([ 0.6337])
# y grad tensor([ 0.4694])
# px tensor([ 0.3264])
# result tensor([ 0.1532])
# g:tensor([ 0.7668])
# ------calling energy function------
# x tensor([ 0.6652])
# y grad tensor([ 0.4858])
# px tensor([ 0.3198])
# result tensor([ 0.1553])
# g:tensor([ 0.8090])
# ------calling energy function------
# x tensor([ 0.6937])
# y grad tensor([ 0.5003])
# px tensor([ 0.3136])
# result tensor([ 0.1569])
# g:tensor([ 0.8474])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6937])
# y grad tensor([ 0.5003])
# px tensor([ 0.3136])
# result tensor([ 0.1569])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6937])
# y grad tensor([ 0.5003])
# px tensor([ 0.3136])
# result tensor([ 0.1569])
# Sample: 11
# ========== simulate ==============
# pos:tensor(1.00000e-03 *
#        [ 1.1953]) True
# ------calling energy function------
# x tensor([ 0.6937])
# y grad tensor([ 0.5003])
# px tensor([ 0.3136])
# result tensor([ 0.1569])
# g:tensor([ 0.8474])
# grad1:tensor([ 0.8474])
# momtensor([ 0.2415])
# ------calling energy function------
# x tensor([ 0.7038])
# y grad tensor([ 0.5053])
# px tensor([ 0.3114])
# result tensor([ 0.1574])
# g:tensor([ 0.8609])
# ------calling energy function------
# x tensor([ 0.7095])
# y grad tensor([ 0.5081])
# px tensor([ 0.3102])
# result tensor([ 0.1576])
# g:tensor([ 0.8686])
# ------calling energy function------
# x tensor([ 0.7108])
# y grad tensor([ 0.5088])
# px tensor([ 0.3099])
# result tensor([ 0.1577])
# g:tensor([ 0.8704])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7108])
# y grad tensor([ 0.5088])
# px tensor([ 0.3099])
# result tensor([ 0.1577])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7108])
# y grad tensor([ 0.5088])
# px tensor([ 0.3099])
# result tensor([ 0.1577])
# Sample: 12
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 3.5019]) True
# ------calling energy function------
# x tensor([ 0.7108])
# y grad tensor([ 0.5088])
# px tensor([ 0.3099])
# result tensor([ 0.1577])
# g:tensor([ 0.8704])
# grad1:tensor([ 0.8704])
# momtensor([-1.2865])
# ------calling energy function------
# x tensor([ 0.6454])
# y grad tensor([ 0.4755])
# px tensor([ 0.3239])
# result tensor([ 0.1540])
# g:tensor([ 0.7824])
# ------calling energy function------
# x tensor([ 0.5809])
# y grad tensor([ 0.4406])
# px tensor([ 0.3370])
# result tensor([ 0.1485])
# g:tensor([ 0.6965])
# ------calling energy function------
# x tensor([ 0.5184])
# y grad tensor([ 0.4045])
# px tensor([ 0.3488])
# result tensor([ 0.1411])
# g:tensor([ 0.6142])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5184])
# y grad tensor([ 0.4045])
# px tensor([ 0.3488])
# result tensor([ 0.1411])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5184])
# y grad tensor([ 0.4045])
# px tensor([ 0.3488])
# result tensor([ 0.1411])
# Sample: 13
# ========== simulate ==============
# pos:tensor([-0.3866]) True
# ------calling energy function------
# x tensor([ 0.5184])
# y grad tensor([ 0.4045])
# px tensor([ 0.3488])
# result tensor([ 0.1411])
# g:tensor([ 0.6142])
# grad1:tensor([ 0.6142])
# momtensor([-0.8837])
# ------calling energy function------
# x tensor([ 0.4824])
# y grad tensor([ 0.3827])
# px tensor([ 0.3551])
# result tensor([ 0.1359])
# g:tensor([ 0.5673])
# ------calling energy function------
# x tensor([ 0.4464])
# y grad tensor([ 0.3600])
# px tensor([ 0.3611])
# result tensor([ 0.1300])
# g:tensor([ 0.5208])
# ------calling energy function------
# x tensor([ 0.4107])
# y grad tensor([ 0.3368])
# px tensor([ 0.3667])
# result tensor([ 0.1235])
# g:tensor([ 0.4752])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4107])
# y grad tensor([ 0.3368])
# px tensor([ 0.3667])
# result tensor([ 0.1235])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4107])
# y grad tensor([ 0.3368])
# px tensor([ 0.3667])
# result tensor([ 0.1235])
# Sample: 14
# ========== simulate ==============
# pos:tensor([-0.6775]) True
# ------calling energy function------
# x tensor([ 0.4107])
# y grad tensor([ 0.3368])
# px tensor([ 0.3667])
# result tensor([ 0.1235])
# g:tensor([ 0.4752])
# grad1:tensor([ 0.4752])
# momtensor([ 0.1802])
# ------calling energy function------
# x tensor([ 0.4160])
# y grad tensor([ 0.3403])
# px tensor([ 0.3659])
# result tensor([ 0.1245])
# g:tensor([ 0.4819])
# ------calling energy function------
# x tensor([ 0.4197])
# y grad tensor([ 0.3428])
# px tensor([ 0.3653])
# result tensor([ 0.1252])
# g:tensor([ 0.4866])
# ------calling energy function------
# x tensor([ 0.4218])
# y grad tensor([ 0.3441])
# px tensor([ 0.3650])
# result tensor([ 0.1256])
# g:tensor([ 0.4892])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4218])
# y grad tensor([ 0.3441])
# px tensor([ 0.3650])
# result tensor([ 0.1256])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4218])
# y grad tensor([ 0.3441])
# px tensor([ 0.3650])
# result tensor([ 0.1256])
# Sample: 15
# ========== simulate ==============
# pos:tensor([-0.6450]) True
# ------calling energy function------
# x tensor([ 0.4218])
# y grad tensor([ 0.3441])
# px tensor([ 0.3650])
# result tensor([ 0.1256])
# g:tensor([ 0.4892])
# grad1:tensor([ 0.4892])
# momtensor([-0.4055])
# ------calling energy function------
# x tensor([ 0.4072])
# y grad tensor([ 0.3345])
# px tensor([ 0.3672])
# result tensor([ 0.1228])
# g:tensor([ 0.4707])
# ------calling energy function------
# x tensor([ 0.3915])
# y grad tensor([ 0.3239])
# px tensor([ 0.3695])
# result tensor([ 0.1197])
# g:tensor([ 0.4507])
# ------calling energy function------
# x tensor([ 0.3749])
# y grad tensor([ 0.3126])
# px tensor([ 0.3719])
# result tensor([ 0.1163])
# g:tensor([ 0.4298])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3749])
# y grad tensor([ 0.3126])
# px tensor([ 0.3719])
# result tensor([ 0.1163])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3749])
# y grad tensor([ 0.3126])
# px tensor([ 0.3719])
# result tensor([ 0.1163])
# Sample: 16
# ========== simulate ==============
# pos:tensor([-0.7879]) True
# ------calling energy function------
# x tensor([ 0.3749])
# y grad tensor([ 0.3126])
# px tensor([ 0.3719])
# result tensor([ 0.1163])
# g:tensor([ 0.4298])
# grad1:tensor([ 0.4298])
# momtensor([-1.7475])
# ------calling energy function------
# x tensor([ 0.3228])
# y grad tensor([ 0.2759])
# px tensor([ 0.3787])
# result tensor([ 0.1045])
# g:tensor([ 0.3650])
# ------calling energy function------
# x tensor([ 0.2762])
# y grad tensor([ 0.2413])
# px tensor([ 0.3840])
# result tensor(1.00000e-02 *
#        [ 9.2674])
# g:tensor([ 0.3080])
# ------calling energy function------
# x tensor([ 0.2349])
# y grad tensor([ 0.2093])
# px tensor([ 0.3881])
# result tensor(1.00000e-02 *
#        [ 8.1235])
# g:tensor([ 0.2585])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2349])
# y grad tensor([ 0.2093])
# px tensor([ 0.3881])
# result tensor(1.00000e-02 *
#        [ 8.1235])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2349])
# y grad tensor([ 0.2093])
# px tensor([ 0.3881])
# result tensor(1.00000e-02 *
#        [ 8.1235])
# Sample: 17
# ========== simulate ==============
# pos:tensor([-1.3290]) True
# ------calling energy function------
# x tensor([ 0.2349])
# y grad tensor([ 0.2093])
# px tensor([ 0.3881])
# result tensor(1.00000e-02 *
#        [ 8.1235])
# g:tensor([ 0.2585])
# grad1:tensor([ 0.2585])
# momtensor([-0.8244])
# ------calling energy function------
# x tensor([ 0.2179])
# y grad tensor([ 0.1958])
# px tensor([ 0.3896])
# result tensor(1.00000e-02 *
#        [ 7.6279])
# g:tensor([ 0.2385])
# ------calling energy function------
# x tensor([ 0.2016])
# y grad tensor([ 0.1826])
# px tensor([ 0.3909])
# result tensor(1.00000e-02 *
#        [ 7.1378])
# g:tensor([ 0.2194])
# ------calling energy function------
# x tensor([ 0.1861])
# y grad tensor([ 0.1698])
# px tensor([ 0.3921])
# result tensor(1.00000e-02 *
#        [ 6.6570])
# g:tensor([ 0.2014])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1861])
# y grad tensor([ 0.1698])
# px tensor([ 0.3921])
# result tensor(1.00000e-02 *
#        [ 6.6570])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2349])
# y grad tensor([ 0.2093])
# px tensor([ 0.3881])
# result tensor(1.00000e-02 *
#        [ 8.1235])
# Sample: 18
# ========== simulate ==============
# pos:tensor([-1.3290]) True
# ------calling energy function------
# x tensor([ 0.2349])
# y grad tensor([ 0.2093])
# px tensor([ 0.3881])
# result tensor(1.00000e-02 *
#        [ 8.1235])
# g:tensor([ 0.2585])
# grad1:tensor([ 0.2585])
# momtensor([-1.0260])
# ------calling energy function------
# x tensor([ 0.2140])
# y grad tensor([ 0.1926])
# px tensor([ 0.3899])
# result tensor(1.00000e-02 *
#        [ 7.5114])
# g:tensor([ 0.2339])
# ------calling energy function------
# x tensor([ 0.1944])
# y grad tensor([ 0.1767])
# px tensor([ 0.3915])
# result tensor(1.00000e-02 *
#        [ 6.9158])
# g:tensor([ 0.2110])
# ------calling energy function------
# x tensor([ 0.1761])
# y grad tensor([ 0.1614])
# px tensor([ 0.3928])
# result tensor(1.00000e-02 *
#        [ 6.3418])
# g:tensor([ 0.1899])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1761])
# y grad tensor([ 0.1614])
# px tensor([ 0.3928])
# result tensor(1.00000e-02 *
#        [ 6.3418])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2349])
# y grad tensor([ 0.2093])
# px tensor([ 0.3881])
# result tensor(1.00000e-02 *
#        [ 8.1235])
# Sample: 19
# ========== simulate ==============
# pos:tensor([-1.3290]) True
# ------calling energy function------
# x tensor([ 0.2349])
# y grad tensor([ 0.2093])
# px tensor([ 0.3881])
# result tensor(1.00000e-02 *
#        [ 8.1235])
# g:tensor([ 0.2585])
# grad1:tensor([ 0.2585])
# momtensor([ 0.3906])
# ------calling energy function------
# x tensor([ 0.2429])
# y grad tensor([ 0.2156])
# px tensor([ 0.3873])
# result tensor(1.00000e-02 *
#        [ 8.3527])
# g:tensor([ 0.2680])
# ------calling energy function------
# x tensor([ 0.2506])
# y grad tensor([ 0.2216])
# px tensor([ 0.3866])
# result tensor(1.00000e-02 *
#        [ 8.5686])
# g:tensor([ 0.2772])
# ------calling energy function------
# x tensor([ 0.2578])
# y grad tensor([ 0.2273])
# px tensor([ 0.3859])
# result tensor(1.00000e-02 *
#        [ 8.7699])
# g:tensor([ 0.2858])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2578])
# y grad tensor([ 0.2273])
# px tensor([ 0.3859])
# result tensor(1.00000e-02 *
#        [ 8.7699])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2578])
# y grad tensor([ 0.2273])
# px tensor([ 0.3859])
# result tensor(1.00000e-02 *
#        [ 8.7699])
# Sample: 20
# ========== simulate ==============
# pos:tensor([-1.2239]) True
# ------calling energy function------
# x tensor([ 0.2578])
# y grad tensor([ 0.2273])
# px tensor([ 0.3859])
# result tensor(1.00000e-02 *
#        [ 8.7699])
# g:tensor([ 0.2858])
# grad1:tensor([ 0.2858])
# momtensor([ 0.6394])
# ------calling energy function------
# x tensor([ 0.2724])
# y grad tensor([ 0.2384])
# px tensor([ 0.3844])
# result tensor(1.00000e-02 *
#        [ 9.1653])
# g:tensor([ 0.3034])
# ------calling energy function------
# x tensor([ 0.2869])
# y grad tensor([ 0.2494])
# px tensor([ 0.3829])
# result tensor(1.00000e-02 *
#        [ 9.5480])
# g:tensor([ 0.3209])
# ------calling energy function------
# x tensor([ 0.3012])
# y grad tensor([ 0.2601])
# px tensor([ 0.3813])
# result tensor(1.00000e-02 *
#        [ 9.9150])
# g:tensor([ 0.3384])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3012])
# y grad tensor([ 0.2601])
# px tensor([ 0.3813])
# result tensor(1.00000e-02 *
#        [ 9.9150])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3012])
# y grad tensor([ 0.2601])
# px tensor([ 0.3813])
# result tensor(1.00000e-02 *
#        [ 9.9150])
# Sample: 21
# ========== simulate ==============
# pos:tensor([-1.0456]) True
# ------calling energy function------
# x tensor([ 0.3012])
# y grad tensor([ 0.2601])
# px tensor([ 0.3813])
# result tensor(1.00000e-02 *
#        [ 9.9150])
# g:tensor([ 0.3384])
# grad1:tensor([ 0.3384])
# momtensor([-1.7881])
# ------calling energy function------
# x tensor([ 0.2573])
# y grad tensor([ 0.2269])
# px tensor([ 0.3860])
# result tensor(1.00000e-02 *
#        [ 8.7557])
# g:tensor([ 0.2852])
# ------calling energy function------
# x tensor([ 0.2185])
# y grad tensor([ 0.1963])
# px tensor([ 0.3895])
# result tensor(1.00000e-02 *
#        [ 7.6470])
# g:tensor([ 0.2392])
# ------calling energy function------
# x tensor([ 0.1847])
# y grad tensor([ 0.1686])
# px tensor([ 0.3922])
# result tensor(1.00000e-02 *
#        [ 6.6143])
# g:tensor([ 0.1998])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1847])
# y grad tensor([ 0.1686])
# px tensor([ 0.3922])
# result tensor(1.00000e-02 *
#        [ 6.6143])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1847])
# y grad tensor([ 0.1686])
# px tensor([ 0.3922])
# result tensor(1.00000e-02 *
#        [ 6.6143])
# Sample: 22
# ========== simulate ==============
# pos:tensor([-1.5952]) True
# ------calling energy function------
# x tensor([ 0.1847])
# y grad tensor([ 0.1686])
# px tensor([ 0.3922])
# result tensor(1.00000e-02 *
#        [ 6.6143])
# g:tensor([ 0.1998])
# grad1:tensor([ 0.1998])
# momtensor([ 0.6929])
# ------calling energy function------
# x tensor([ 0.1966])
# y grad tensor([ 0.1784])
# px tensor([ 0.3913])
# result tensor(1.00000e-02 *
#        [ 6.9826])
# g:tensor([ 0.2135])
# ------calling energy function------
# x tensor([ 0.2087])
# y grad tensor([ 0.1883])
# px tensor([ 0.3903])
# result tensor(1.00000e-02 *
#        [ 7.3521])
# g:tensor([ 0.2277])
# ------calling energy function------
# x tensor([ 0.2210])
# y grad tensor([ 0.1983])
# px tensor([ 0.3893])
# result tensor(1.00000e-02 *
#        [ 7.7204])
# g:tensor([ 0.2421])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2210])
# y grad tensor([ 0.1983])
# px tensor([ 0.3893])
# result tensor(1.00000e-02 *
#        [ 7.7204])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2210])
# y grad tensor([ 0.1983])
# px tensor([ 0.3893])
# result tensor(1.00000e-02 *
#        [ 7.7204])
# Sample: 23
# ========== simulate ==============
# pos:tensor([-1.3969]) True
# ------calling energy function------
# x tensor([ 0.2210])
# y grad tensor([ 0.1983])
# px tensor([ 0.3893])
# result tensor(1.00000e-02 *
#        [ 7.7204])
# g:tensor([ 0.2421])
# grad1:tensor([ 0.2421])
# momtensor([ 1.3936])
# ------calling energy function------
# x tensor([ 0.2500])
# y grad tensor([ 0.2212])
# px tensor([ 0.3867])
# result tensor(1.00000e-02 *
#        [ 8.5526])
# g:tensor([ 0.2765])
# ------calling energy function------
# x tensor([ 0.2815])
# y grad tensor([ 0.2454])
# px tensor([ 0.3834])
# result tensor(1.00000e-02 *
#        [ 9.4090])
# g:tensor([ 0.3145])
# ------calling energy function------
# x tensor([ 0.3156])
# y grad tensor([ 0.2707])
# px tensor([ 0.3796])
# result tensor([ 0.1027])
# g:tensor([ 0.3561])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3156])
# y grad tensor([ 0.2707])
# px tensor([ 0.3796])
# result tensor([ 0.1027])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3156])
# y grad tensor([ 0.2707])
# px tensor([ 0.3796])
# result tensor([ 0.1027])
# Sample: 24
# ========== simulate ==============
# pos:tensor([-0.9911]) True
# ------calling energy function------
# x tensor([ 0.3156])
# y grad tensor([ 0.2707])
# px tensor([ 0.3796])
# result tensor([ 0.1027])
# g:tensor([ 0.3561])
# grad1:tensor([ 0.3561])
# momtensor([-0.7875])
# ------calling energy function------
# x tensor([ 0.2945])
# y grad tensor([ 0.2551])
# px tensor([ 0.3820])
# result tensor(1.00000e-02 *
#        [ 9.7445])
# g:tensor([ 0.3302])
# ------calling energy function------
# x tensor([ 0.2738])
# y grad tensor([ 0.2395])
# px tensor([ 0.3843])
# result tensor(1.00000e-02 *
#        [ 9.2026])
# g:tensor([ 0.3050])
# ------calling energy function------
# x tensor([ 0.2536])
# y grad tensor([ 0.2240])
# px tensor([ 0.3863])
# result tensor(1.00000e-02 *
#        [ 8.6542])
# g:tensor([ 0.2808])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2536])
# y grad tensor([ 0.2240])
# px tensor([ 0.3863])
# result tensor(1.00000e-02 *
#        [ 8.6542])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2536])
# y grad tensor([ 0.2240])
# px tensor([ 0.3863])
# result tensor(1.00000e-02 *
#        [ 8.6542])
# Sample: 25
# ========== simulate ==============
# pos:tensor([-1.2424]) True
# ------calling energy function------
# x tensor([ 0.2536])
# y grad tensor([ 0.2240])
# px tensor([ 0.3863])
# result tensor(1.00000e-02 *
#        [ 8.6542])
# g:tensor([ 0.2808])
# grad1:tensor([ 0.2808])
# momtensor(1.00000e-02 *
#        [-6.0324])
# ------calling energy function------
# x tensor([ 0.2520])
# y grad tensor([ 0.2227])
# px tensor([ 0.3865])
# result tensor(1.00000e-02 *
#        [ 8.6079])
# g:tensor([ 0.2788])
# ------calling energy function------
# x tensor([ 0.2497])
# y grad tensor([ 0.2210])
# px tensor([ 0.3867])
# result tensor(1.00000e-02 *
#        [ 8.5446])
# g:tensor([ 0.2761])
# ------calling energy function------
# x tensor([ 0.2468])
# y grad tensor([ 0.2187])
# px tensor([ 0.3870])
# result tensor(1.00000e-02 *
#        [ 8.4644])
# g:tensor([ 0.2727])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2468])
# y grad tensor([ 0.2187])
# px tensor([ 0.3870])
# result tensor(1.00000e-02 *
#        [ 8.4644])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2468])
# y grad tensor([ 0.2187])
# px tensor([ 0.3870])
# result tensor(1.00000e-02 *
#        [ 8.4644])
# Sample: 26
# ========== simulate ==============
# pos:tensor([-1.2731]) True
# ------calling energy function------
# x tensor([ 0.2468])
# y grad tensor([ 0.2187])
# px tensor([ 0.3870])
# result tensor(1.00000e-02 *
#        [ 8.4644])
# g:tensor([ 0.2727])
# grad1:tensor([ 0.2727])
# momtensor([-0.5543])
# ------calling energy function------
# x tensor([ 0.2347])
# y grad tensor([ 0.2092])
# px tensor([ 0.3881])
# result tensor(1.00000e-02 *
#        [ 8.1186])
# g:tensor([ 0.2583])
# ------calling energy function------
# x tensor([ 0.2226])
# y grad tensor([ 0.1995])
# px tensor([ 0.3892])
# result tensor(1.00000e-02 *
#        [ 7.7655])
# g:tensor([ 0.2439])
# ------calling energy function------
# x tensor([ 0.2105])
# y grad tensor([ 0.1898])
# px tensor([ 0.3902])
# result tensor(1.00000e-02 *
#        [ 7.4076])
# g:tensor([ 0.2298])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2105])
# y grad tensor([ 0.1898])
# px tensor([ 0.3902])
# result tensor(1.00000e-02 *
#        [ 7.4076])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2105])
# y grad tensor([ 0.1898])
# px tensor([ 0.3902])
# result tensor(1.00000e-02 *
#        [ 7.4076])
# Sample: 27
# ========== simulate ==============
# pos:tensor([-1.4510]) True
# ------calling energy function------
# x tensor([ 0.2105])
# y grad tensor([ 0.1898])
# px tensor([ 0.3902])
# result tensor(1.00000e-02 *
#        [ 7.4076])
# g:tensor([ 0.2298])
# grad1:tensor([ 0.2298])
# momtensor([ 0.9783])
# ------calling energy function------
# x tensor([ 0.2296])
# y grad tensor([ 0.2052])
# px tensor([ 0.3886])
# result tensor(1.00000e-02 *
#        [ 7.9717])
# g:tensor([ 0.2523])
# ------calling energy function------
# x tensor([ 0.2497])
# y grad tensor([ 0.2209])
# px tensor([ 0.3867])
# result tensor(1.00000e-02 *
#        [ 8.5437])
# g:tensor([ 0.2761])
# ------calling energy function------
# x tensor([ 0.2706])
# y grad tensor([ 0.2371])
# px tensor([ 0.3846])
# result tensor(1.00000e-02 *
#        [ 9.1177])
# g:tensor([ 0.3012])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2706])
# y grad tensor([ 0.2371])
# px tensor([ 0.3846])
# result tensor(1.00000e-02 *
#        [ 9.1177])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2706])
# y grad tensor([ 0.2371])
# px tensor([ 0.3846])
# result tensor(1.00000e-02 *
#        [ 9.1177])
# Sample: 28
# ========== simulate ==============
# pos:tensor([-1.1688]) True
# ------calling energy function------
# x tensor([ 0.2706])
# y grad tensor([ 0.2371])
# px tensor([ 0.3846])
# result tensor(1.00000e-02 *
#        [ 9.1177])
# g:tensor([ 0.3012])
# grad1:tensor([ 0.3012])
# momtensor([-0.9127])
# ------calling energy function------
# x tensor([ 0.2494])
# y grad tensor([ 0.2207])
# px tensor([ 0.3867])
# result tensor(1.00000e-02 *
#        [ 8.5351])
# g:tensor([ 0.2757])
# ------calling energy function------
# x tensor([ 0.2290])
# y grad tensor([ 0.2047])
# px tensor([ 0.3886])
# result tensor(1.00000e-02 *
#        [ 7.9553])
# g:tensor([ 0.2516])
# ------calling energy function------
# x tensor([ 0.2097])
# y grad tensor([ 0.1892])
# px tensor([ 0.3903])
# result tensor(1.00000e-02 *
#        [ 7.3841])
# g:tensor([ 0.2289])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2097])
# y grad tensor([ 0.1892])
# px tensor([ 0.3903])
# result tensor(1.00000e-02 *
#        [ 7.3841])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2097])
# y grad tensor([ 0.1892])
# px tensor([ 0.3903])
# result tensor(1.00000e-02 *
#        [ 7.3841])
# Sample: 29
# ========== simulate ==============
# pos:tensor([-1.4552]) True
# ------calling energy function------
# x tensor([ 0.2097])
# y grad tensor([ 0.1892])
# px tensor([ 0.3903])
# result tensor(1.00000e-02 *
#        [ 7.3841])
# g:tensor([ 0.2289])
# grad1:tensor([ 0.2289])
# momtensor([ 1.7211])
# ------calling energy function------
# x tensor([ 0.2444])
# y grad tensor([ 0.2168])
# px tensor([ 0.3872])
# result tensor(1.00000e-02 *
#        [ 8.3960])
# g:tensor([ 0.2698])
# ------calling energy function------
# x tensor([ 0.2834])
# y grad tensor([ 0.2468])
# px tensor([ 0.3832])
# result tensor(1.00000e-02 *
#        [ 9.4571])
# g:tensor([ 0.3167])
# ------calling energy function------
# x tensor([ 0.3267])
# y grad tensor([ 0.2787])
# px tensor([ 0.3782])
# result tensor([ 0.1054])
# g:tensor([ 0.3698])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3267])
# y grad tensor([ 0.2787])
# px tensor([ 0.3782])
# result tensor([ 0.1054])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3267])
# y grad tensor([ 0.2787])
# px tensor([ 0.3782])
# result tensor([ 0.1054])
# Sample: 30
# ========== simulate ==============
# pos:tensor([-0.9508]) True
# ------calling energy function------
# x tensor([ 0.3267])
# y grad tensor([ 0.2787])
# px tensor([ 0.3782])
# result tensor([ 0.1054])
# g:tensor([ 0.3698])
# grad1:tensor([ 0.3698])
# momtensor([-0.2652])
# ------calling energy function------
# x tensor([ 0.3189])
# y grad tensor([ 0.2731])
# px tensor([ 0.3792])
# result tensor([ 0.1035])
# g:tensor([ 0.3601])
# ------calling energy function------
# x tensor([ 0.3103])
# y grad tensor([ 0.2668])
# px tensor([ 0.3802])
# result tensor([ 0.1014])
# g:tensor([ 0.3495])
# ------calling energy function------
# x tensor([ 0.3009])
# y grad tensor([ 0.2599])
# px tensor([ 0.3813])
# result tensor(1.00000e-02 *
#        [ 9.9084])
# g:tensor([ 0.3381])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3009])
# y grad tensor([ 0.2599])
# px tensor([ 0.3813])
# result tensor(1.00000e-02 *
#        [ 9.9084])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3009])
# y grad tensor([ 0.2599])
# px tensor([ 0.3813])
# result tensor(1.00000e-02 *
#        [ 9.9084])
# Sample: 31
# ========== simulate ==============
# pos:tensor([-1.0466]) True
# ------calling energy function------
# x tensor([ 0.3009])
# y grad tensor([ 0.2599])
# px tensor([ 0.3813])
# result tensor(1.00000e-02 *
#        [ 9.9084])
# g:tensor([ 0.3381])
# grad1:tensor([ 0.3381])
# momtensor([ 0.2315])
# ------calling energy function------
# x tensor([ 0.3066])
# y grad tensor([ 0.2640])
# px tensor([ 0.3806])
# result tensor([ 0.1005])
# g:tensor([ 0.3450])
# ------calling energy function------
# x tensor([ 0.3113])
# y grad tensor([ 0.2675])
# px tensor([ 0.3801])
# result tensor([ 0.1017])
# g:tensor([ 0.3508])
# ------calling energy function------
# x tensor([ 0.3152])
# y grad tensor([ 0.2704])
# px tensor([ 0.3796])
# result tensor([ 0.1026])
# g:tensor([ 0.3556])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3152])
# y grad tensor([ 0.2704])
# px tensor([ 0.3796])
# result tensor([ 0.1026])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3152])
# y grad tensor([ 0.2704])
# px tensor([ 0.3796])
# result tensor([ 0.1026])
# Sample: 32
# ========== simulate ==============
# pos:tensor([-0.9927]) True
# ------calling energy function------
# x tensor([ 0.3152])
# y grad tensor([ 0.2704])
# px tensor([ 0.3796])
# result tensor([ 0.1026])
# g:tensor([ 0.3556])
# grad1:tensor([ 0.3556])
# momtensor([ 0.8471])
# ------calling energy function------
# x tensor([ 0.3384])
# y grad tensor([ 0.2871])
# px tensor([ 0.3767])
# result tensor([ 0.1081])
# g:tensor([ 0.3842])
# ------calling energy function------
# x tensor([ 0.3617])
# y grad tensor([ 0.3035])
# px tensor([ 0.3737])
# result tensor([ 0.1134])
# g:tensor([ 0.4133])
# ------calling energy function------
# x tensor([ 0.3850])
# y grad tensor([ 0.3196])
# px tensor([ 0.3704])
# result tensor([ 0.1184])
# g:tensor([ 0.4426])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3850])
# y grad tensor([ 0.3196])
# px tensor([ 0.3704])
# result tensor([ 0.1184])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3850])
# y grad tensor([ 0.3196])
# px tensor([ 0.3704])
# result tensor([ 0.1184])
# Sample: 33
# ========== simulate ==============
# pos:tensor([-0.7557]) True
# ------calling energy function------
# x tensor([ 0.3850])
# y grad tensor([ 0.3196])
# px tensor([ 0.3704])
# result tensor([ 0.1184])
# g:tensor([ 0.4426])
# grad1:tensor([ 0.4426])
# momtensor([ 0.8623])
# ------calling energy function------
# x tensor([ 0.4127])
# y grad tensor([ 0.3381])
# px tensor([ 0.3664])
# result tensor([ 0.1239])
# g:tensor([ 0.4777])
# ------calling energy function------
# x tensor([ 0.4402])
# y grad tensor([ 0.3561])
# px tensor([ 0.3621])
# result tensor([ 0.1289])
# g:tensor([ 0.5128])
# ------calling energy function------
# x tensor([ 0.4672])
# y grad tensor([ 0.3732])
# px tensor([ 0.3577])
# result tensor([ 0.1335])
# g:tensor([ 0.5476])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4672])
# y grad tensor([ 0.3732])
# px tensor([ 0.3577])
# result tensor([ 0.1335])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4672])
# y grad tensor([ 0.3732])
# px tensor([ 0.3577])
# result tensor([ 0.1335])
# Sample: 34
# ========== simulate ==============
# pos:tensor([-0.5183]) True
# ------calling energy function------
# x tensor([ 0.4672])
# y grad tensor([ 0.3732])
# px tensor([ 0.3577])
# result tensor([ 0.1335])
# g:tensor([ 0.5476])
# grad1:tensor([ 0.5476])
# momtensor([ 1.7306])
# ------calling energy function------
# x tensor([ 0.5342])
# y grad tensor([ 0.4139])
# px tensor([ 0.3459])
# result tensor([ 0.1432])
# g:tensor([ 0.6350])
# ------calling energy function------
# x tensor([ 0.6054])
# y grad tensor([ 0.4541])
# px tensor([ 0.3322])
# result tensor([ 0.1508])
# g:tensor([ 0.7290])
# ------calling energy function------
# x tensor([ 0.6796])
# y grad tensor([ 0.4932])
# px tensor([ 0.3167])
# result tensor([ 0.1562])
# g:tensor([ 0.8283])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6796])
# y grad tensor([ 0.4932])
# px tensor([ 0.3167])
# result tensor([ 0.1562])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6796])
# y grad tensor([ 0.4932])
# px tensor([ 0.3167])
# result tensor([ 0.1562])
# Sample: 35
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [-2.7357]) True
# ------calling energy function------
# x tensor([ 0.6796])
# y grad tensor([ 0.4932])
# px tensor([ 0.3167])
# result tensor([ 0.1562])
# g:tensor([ 0.8283])
# grad1:tensor([ 0.8283])
# momtensor([ 0.3655])
# ------calling energy function------
# x tensor([ 0.6957])
# y grad tensor([ 0.5013])
# px tensor([ 0.3132])
# result tensor([ 0.1570])
# g:tensor([ 0.8500])
# ------calling energy function------
# x tensor([ 0.7077])
# y grad tensor([ 0.5072])
# px tensor([ 0.3106])
# result tensor([ 0.1575])
# g:tensor([ 0.8662])
# ------calling energy function------
# x tensor([ 0.7155])
# y grad tensor([ 0.5111])
# px tensor([ 0.3088])
# result tensor([ 0.1578])
# g:tensor([ 0.8767])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7155])
# y grad tensor([ 0.5111])
# px tensor([ 0.3088])
# result tensor([ 0.1578])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7155])
# y grad tensor([ 0.5111])
# px tensor([ 0.3088])
# result tensor([ 0.1578])
# Sample: 36
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 4.4220]) True
# ------calling energy function------
# x tensor([ 0.7155])
# y grad tensor([ 0.5111])
# px tensor([ 0.3088])
# result tensor([ 0.1578])
# g:tensor([ 0.8767])
# grad1:tensor([ 0.8767])
# momtensor([ 0.3143])
# ------calling energy function------
# x tensor([ 0.7294])
# y grad tensor([ 0.5178])
# px tensor([ 0.3058])
# result tensor([ 0.1583])
# g:tensor([ 0.8955])
# ------calling energy function------
# x tensor([ 0.7388])
# y grad tensor([ 0.5223])
# px tensor([ 0.3037])
# result tensor([ 0.1586])
# g:tensor([ 0.9082])
# ------calling energy function------
# x tensor([ 0.7435])
# y grad tensor([ 0.5246])
# px tensor([ 0.3026])
# result tensor([ 0.1587])
# g:tensor([ 0.9146])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7435])
# y grad tensor([ 0.5246])
# px tensor([ 0.3026])
# result tensor([ 0.1587])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7435])
# y grad tensor([ 0.5246])
# px tensor([ 0.3026])
# result tensor([ 0.1587])
# Sample: 37
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 9.8378]) True
# ------calling energy function------
# x tensor([ 0.7435])
# y grad tensor([ 0.5246])
# px tensor([ 0.3026])
# result tensor([ 0.1587])
# g:tensor([ 0.9146])
# grad1:tensor([ 0.9146])
# momtensor([ 0.7649])
# ------calling energy function------
# x tensor([ 0.7819])
# y grad tensor([ 0.5425])
# px tensor([ 0.2939])
# result tensor([ 0.1594])
# g:tensor([ 0.9666])
# ------calling energy function------
# x tensor([ 0.8162])
# y grad tensor([ 0.5579])
# px tensor([ 0.2859])
# result tensor([ 0.1595])
# g:tensor([ 1.0132])
# ------calling energy function------
# x tensor([ 0.8456])
# y grad tensor([ 0.5707])
# px tensor([ 0.2790])
# result tensor([ 0.1592])
# g:tensor([ 1.0532])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8456])
# y grad tensor([ 0.5707])
# px tensor([ 0.2790])
# result tensor([ 0.1592])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8456])
# y grad tensor([ 0.5707])
# px tensor([ 0.2790])
# result tensor([ 0.1592])
# Sample: 38
# ========== simulate ==============
# pos:tensor([ 0.2847]) True
# ------calling energy function------
# x tensor([ 0.8456])
# y grad tensor([ 0.5707])
# px tensor([ 0.2790])
# result tensor([ 0.1592])
# g:tensor([ 1.0532])
# grad1:tensor([ 1.0532])
# momtensor([ 0.2472])
# ------calling energy function------
# x tensor([ 0.8567])
# y grad tensor([ 0.5754])
# px tensor([ 0.2764])
# result tensor([ 0.1591])
# g:tensor([ 1.0684])
# ------calling energy function------
# x tensor([ 0.8618])
# y grad tensor([ 0.5776])
# px tensor([ 0.2752])
# result tensor([ 0.1590])
# g:tensor([ 1.0753])
# ------calling energy function------
# x tensor([ 0.8606])
# y grad tensor([ 0.5771])
# px tensor([ 0.2755])
# result tensor([ 0.1590])
# g:tensor([ 1.0738])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8606])
# y grad tensor([ 0.5771])
# px tensor([ 0.2755])
# result tensor([ 0.1590])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8606])
# y grad tensor([ 0.5771])
# px tensor([ 0.2755])
# result tensor([ 0.1590])
# Sample: 39
# ========== simulate ==============
# pos:tensor([ 0.3109]) True
# ------calling energy function------
# x tensor([ 0.8606])
# y grad tensor([ 0.5771])
# px tensor([ 0.2755])
# result tensor([ 0.1590])
# g:tensor([ 1.0738])
# grad1:tensor([ 1.0738])
# momtensor([-0.7345])
# ------calling energy function------
# x tensor([ 0.8159])
# y grad tensor([ 0.5578])
# px tensor([ 0.2860])
# result tensor([ 0.1595])
# g:tensor([ 1.0128])
# ------calling energy function------
# x tensor([ 0.7673])
# y grad tensor([ 0.5357])
# px tensor([ 0.2972])
# result tensor([ 0.1592])
# g:tensor([ 0.9468])
# ------calling energy function------
# x tensor([ 0.7158])
# y grad tensor([ 0.5112])
# px tensor([ 0.3088])
# result tensor([ 0.1578])
# g:tensor([ 0.8771])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7158])
# y grad tensor([ 0.5112])
# px tensor([ 0.3088])
# result tensor([ 0.1578])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7158])
# y grad tensor([ 0.5112])
# px tensor([ 0.3088])
# result tensor([ 0.1578])
# Sample: 40
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 4.4715]) True
# ------calling energy function------
# x tensor([ 0.7158])
# y grad tensor([ 0.5112])
# px tensor([ 0.3088])
# result tensor([ 0.1578])
# g:tensor([ 0.8771])
# grad1:tensor([ 0.8771])
# momtensor([-1.4797])
# ------calling energy function------
# x tensor([ 0.6408])
# y grad tensor([ 0.4731])
# px tensor([ 0.3249])
# result tensor([ 0.1537])
# g:tensor([ 0.7763])
# ------calling energy function------
# x tensor([ 0.5682])
# y grad tensor([ 0.4335])
# px tensor([ 0.3395])
# result tensor([ 0.1471])
# g:tensor([ 0.6798])
# ------calling energy function------
# x tensor([ 0.4992])
# y grad tensor([ 0.3930])
# px tensor([ 0.3522])
# result tensor([ 0.1384])
# g:tensor([ 0.5892])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4992])
# y grad tensor([ 0.3930])
# px tensor([ 0.3522])
# result tensor([ 0.1384])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7158])
# y grad tensor([ 0.5112])
# px tensor([ 0.3088])
# result tensor([ 0.1578])
# Sample: 41
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 4.4715]) True
# ------calling energy function------
# x tensor([ 0.7158])
# y grad tensor([ 0.5112])
# px tensor([ 0.3088])
# result tensor([ 0.1578])
# g:tensor([ 0.8771])
# grad1:tensor([ 0.8771])
# momtensor([ 0.5251])
# ------calling energy function------
# x tensor([ 0.7406])
# y grad tensor([ 0.5232])
# px tensor([ 0.3032])
# result tensor([ 0.1587])
# g:tensor([ 0.9107])
# ------calling energy function------
# x tensor([ 0.7612])
# y grad tensor([ 0.5329])
# px tensor([ 0.2986])
# result tensor([ 0.1591])
# g:tensor([ 0.9386])
# ------calling energy function------
# x tensor([ 0.7771])
# y grad tensor([ 0.5403])
# px tensor([ 0.2950])
# result tensor([ 0.1594])
# g:tensor([ 0.9602])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7771])
# y grad tensor([ 0.5403])
# px tensor([ 0.2950])
# result tensor([ 0.1594])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7771])
# y grad tensor([ 0.5403])
# px tensor([ 0.2950])
# result tensor([ 0.1594])
# Sample: 42
# ========== simulate ==============
# pos:tensor([ 0.1615]) True
# ------calling energy function------
# x tensor([ 0.7771])
# y grad tensor([ 0.5403])
# px tensor([ 0.2950])
# result tensor([ 0.1594])
# g:tensor([ 0.9602])
# grad1:tensor([ 0.9602])
# momtensor([-1.2706])
# ------calling energy function------
# x tensor([ 0.7081])
# y grad tensor([ 0.5074])
# px tensor([ 0.3105])
# result tensor([ 0.1575])
# g:tensor([ 0.8667])
# ------calling energy function------
# x tensor([ 0.6392])
# y grad tensor([ 0.4723])
# px tensor([ 0.3252])
# result tensor([ 0.1536])
# g:tensor([ 0.7742])
# ------calling energy function------
# x tensor([ 0.5719])
# y grad tensor([ 0.4356])
# px tensor([ 0.3388])
# result tensor([ 0.1475])
# g:tensor([ 0.6847])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5719])
# y grad tensor([ 0.4356])
# px tensor([ 0.3388])
# result tensor([ 0.1475])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5719])
# y grad tensor([ 0.4356])
# px tensor([ 0.3388])
# result tensor([ 0.1475])
# Sample: 43
# ========== simulate ==============
# pos:tensor([-0.2592]) True
# ------calling energy function------
# x tensor([ 0.5719])
# y grad tensor([ 0.4356])
# px tensor([ 0.3388])
# result tensor([ 0.1475])
# g:tensor([ 0.6847])
# grad1:tensor([ 0.6847])
# momtensor([ 1.5182])
# ------calling energy function------
# x tensor([ 0.6393])
# y grad tensor([ 0.4723])
# px tensor([ 0.3252])
# result tensor([ 0.1536])
# g:tensor([ 0.7743])
# ------calling energy function------
# x tensor([ 0.7082])
# y grad tensor([ 0.5075])
# px tensor([ 0.3105])
# result tensor([ 0.1575])
# g:tensor([ 0.8668])
# ------calling energy function------
# x tensor([ 0.7773])
# y grad tensor([ 0.5404])
# px tensor([ 0.2949])
# result tensor([ 0.1594])
# g:tensor([ 0.9604])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7773])
# y grad tensor([ 0.5404])
# px tensor([ 0.2949])
# result tensor([ 0.1594])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7773])
# y grad tensor([ 0.5404])
# px tensor([ 0.2949])
# result tensor([ 0.1594])
# Sample: 44
# ========== simulate ==============
# pos:tensor([ 0.1619]) True
# ------calling energy function------
# x tensor([ 0.7773])
# y grad tensor([ 0.5404])
# px tensor([ 0.2949])
# result tensor([ 0.1594])
# g:tensor([ 0.9604])
# grad1:tensor([ 0.9604])
# momtensor([ 1.2375])
# ------calling energy function------
# x tensor([ 0.8434])
# y grad tensor([ 0.5697])
# px tensor([ 0.2795])
# result tensor([ 0.1593])
# g:tensor([ 1.0502])
# ------calling energy function------
# x tensor([ 0.9066])
# y grad tensor([ 0.5961])
# px tensor([ 0.2645])
# result tensor([ 0.1577])
# g:tensor([ 1.1365])
# ------calling energy function------
# x tensor([ 0.9656])
# y grad tensor([ 0.6192])
# px tensor([ 0.2503])
# result tensor([ 0.1550])
# g:tensor([ 1.2172])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.9656])
# y grad tensor([ 0.6192])
# px tensor([ 0.2503])
# result tensor([ 0.1550])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.9656])
# y grad tensor([ 0.6192])
# px tensor([ 0.2503])
# result tensor([ 0.1550])
# Sample: 45
# ========== simulate ==============
# pos:tensor([ 0.4863]) True
# ------calling energy function------
# x tensor([ 0.9656])
# y grad tensor([ 0.6192])
# px tensor([ 0.2503])
# result tensor([ 0.1550])
# g:tensor([ 1.2172])
# grad1:tensor([ 1.2172])
# momtensor([-0.6720])
# ------calling energy function------
# x tensor([ 0.9209])
# y grad tensor([ 0.6018])
# px tensor([ 0.2611])
# result tensor([ 0.1571])
# g:tensor([ 1.1560])
# ------calling energy function------
# x tensor([ 0.8707])
# y grad tensor([ 0.5813])
# px tensor([ 0.2731])
# result tensor([ 0.1588])
# g:tensor([ 1.0875])
# ------calling energy function------
# x tensor([ 0.8161])
# y grad tensor([ 0.5579])
# px tensor([ 0.2859])
# result tensor([ 0.1595])
# g:tensor([ 1.0132])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8161])
# y grad tensor([ 0.5579])
# px tensor([ 0.2859])
# result tensor([ 0.1595])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8161])
# y grad tensor([ 0.5579])
# px tensor([ 0.2859])
# result tensor([ 0.1595])
# Sample: 46
# ========== simulate ==============
# pos:tensor([ 0.2325]) True
# ------calling energy function------
# x tensor([ 0.8161])
# y grad tensor([ 0.5579])
# px tensor([ 0.2859])
# result tensor([ 0.1595])
# g:tensor([ 1.0132])
# grad1:tensor([ 1.0132])
# momtensor([ 1.0401])
# ------calling energy function------
# x tensor([ 0.8725])
# y grad tensor([ 0.5821])
# px tensor([ 0.2726])
# result tensor([ 0.1587])
# g:tensor([ 1.0900])
# ------calling energy function------
# x tensor([ 0.9247])
# y grad tensor([ 0.6034])
# px tensor([ 0.2602])
# result tensor([ 0.1570])
# g:tensor([ 1.1613])
# ------calling energy function------
# x tensor([ 0.9715])
# y grad tensor([ 0.6215])
# px tensor([ 0.2489])
# result tensor([ 0.1547])
# g:tensor([ 1.2253])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.9715])
# y grad tensor([ 0.6215])
# px tensor([ 0.2489])
# result tensor([ 0.1547])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.9715])
# y grad tensor([ 0.6215])
# px tensor([ 0.2489])
# result tensor([ 0.1547])
# Sample: 47
# ========== simulate ==============
# pos:tensor([ 0.4959]) True
# ------calling energy function------
# x tensor([ 0.9715])
# y grad tensor([ 0.6215])
# px tensor([ 0.2489])
# result tensor([ 0.1547])
# g:tensor([ 1.2253])
# grad1:tensor([ 1.2253])
# momtensor([ 0.2287])
# ------calling energy function------
# x tensor([ 0.9820])
# y grad tensor([ 0.6254])
# px tensor([ 0.2463])
# result tensor([ 0.1541])
# g:tensor([ 1.2396])
# ------calling energy function------
# x tensor([ 0.9847])
# y grad tensor([ 0.6264])
# px tensor([ 0.2457])
# result tensor([ 0.1539])
# g:tensor([ 1.2433])
# ------calling energy function------
# x tensor([ 0.9796])
# y grad tensor([ 0.6246])
# px tensor([ 0.2469])
# result tensor([ 0.1542])
# g:tensor([ 1.2364])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.9796])
# y grad tensor([ 0.6246])
# px tensor([ 0.2469])
# result tensor([ 0.1542])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.9796])
# y grad tensor([ 0.6246])
# px tensor([ 0.2469])
# result tensor([ 0.1542])
# Sample: 48
# ========== simulate ==============
# pos:tensor([ 0.5089]) True
# ------calling energy function------
# x tensor([ 0.9796])
# y grad tensor([ 0.6246])
# px tensor([ 0.2469])
# result tensor([ 0.1542])
# g:tensor([ 1.2364])
# grad1:tensor([ 1.2364])
# momtensor([ 1.1250])
# ...
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1505])
# y grad tensor([ 0.1397])
# px tensor([ 0.3945])
# result tensor(1.00000e-02 *
#        [ 5.5105])
# Sample: 787
# ========== simulate ==============
# pos:tensor([-1.8178]) True
# ------calling energy function------
# x tensor([ 0.1505])
# y grad tensor([ 0.1397])
# px tensor([ 0.3945])
# result tensor(1.00000e-02 *
#        [ 5.5105])
# g:tensor([ 0.1607])
# grad1:tensor([ 0.1607])
# momtensor([-1.3666])
# ------calling energy function------
# x tensor([ 0.1324])
# y grad tensor([ 0.1240])
# px tensor([ 0.3955])
# result tensor(1.00000e-02 *
#        [ 4.9031])
# g:tensor([ 0.1404])
# ------calling energy function------
# x tensor([ 0.1162])
# y grad tensor([ 0.1097])
# px tensor([ 0.3963])
# result tensor(1.00000e-02 *
#        [ 4.3458])
# g:tensor([ 0.1224])
# ------calling energy function------
# x tensor([ 0.1017])
# y grad tensor(1.00000e-02 *
#        [ 9.6722])
# px tensor([ 0.3969])
# result tensor(1.00000e-02 *
#        [ 3.8388])
# g:tensor([ 0.1066])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1017])
# y grad tensor(1.00000e-02 *
#        [ 9.6722])
# px tensor([ 0.3969])
# result tensor(1.00000e-02 *
#        [ 3.8388])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1505])
# y grad tensor([ 0.1397])
# px tensor([ 0.3945])
# result tensor(1.00000e-02 *
#        [ 5.5105])
# Sample: 788
# ========== simulate ==============
# pos:tensor([-1.8178]) True
# ------calling energy function------
# x tensor([ 0.1505])
# y grad tensor([ 0.1397])
# px tensor([ 0.3945])
# result tensor(1.00000e-02 *
#        [ 5.5105])
# g:tensor([ 0.1607])
# grad1:tensor([ 0.1607])
# momtensor([ 0.1906])
# ------calling energy function------
# x tensor([ 0.1530])
# y grad tensor([ 0.1419])
# px tensor([ 0.3943])
# result tensor(1.00000e-02 *
#        [ 5.5954])
# g:tensor([ 0.1636])
# ------calling energy function------
# x tensor([ 0.1554])
# y grad tensor([ 0.1439])
# px tensor([ 0.3942])
# result tensor(1.00000e-02 *
#        [ 5.6736])
# g:tensor([ 0.1663])
# ------calling energy function------
# x tensor([ 0.1576])
# y grad tensor([ 0.1458])
# px tensor([ 0.3940])
# result tensor(1.00000e-02 *
#        [ 5.7447])
# g:tensor([ 0.1688])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1576])
# y grad tensor([ 0.1458])
# px tensor([ 0.3940])
# result tensor(1.00000e-02 *
#        [ 5.7447])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1576])
# y grad tensor([ 0.1458])
# px tensor([ 0.3940])
# result tensor(1.00000e-02 *
#        [ 5.7447])
# Sample: 789
# ========== simulate ==============
# pos:tensor([-1.7680]) True
# ------calling energy function------
# x tensor([ 0.1576])
# y grad tensor([ 0.1458])
# px tensor([ 0.3940])
# result tensor(1.00000e-02 *
#        [ 5.7447])
# g:tensor([ 0.1688])
# grad1:tensor([ 0.1688])
# momtensor([-1.5957])
# ------calling energy function------
# x tensor([ 0.1357])
# y grad tensor([ 0.1269])
# px tensor([ 0.3953])
# result tensor(1.00000e-02 *
#        [ 5.0174])
# g:tensor([ 0.1442])
# ------calling energy function------
# x tensor([ 0.1166])
# y grad tensor([ 0.1101])
# px tensor([ 0.3962])
# result tensor(1.00000e-02 *
#        [ 4.3606])
# g:tensor([ 0.1229])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 9.9891])
# y grad tensor(1.00000e-02 *
#        [ 9.5064])
# px tensor([ 0.3970])
# result tensor(1.00000e-02 *
#        [ 3.7736])
# g:tensor([ 0.1046])
# ========== 2nd hamiltonian ==============
# x tensor(1.00000e-02 *
#        [ 9.9891])
# y grad tensor(1.00000e-02 *
#        [ 9.5064])
# px tensor([ 0.3970])
# result tensor(1.00000e-02 *
#        [ 3.7736])
# ========== 3rd hamiltonian ==============
# x tensor(1.00000e-02 *
#        [ 9.9891])
# y grad tensor(1.00000e-02 *
#        [ 9.5064])
# px tensor([ 0.3970])
# result tensor(1.00000e-02 *
#        [ 3.7736])
# Sample: 790
# ========== simulate ==============
# pos:tensor([-2.2533]) True
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 9.9891])
# y grad tensor(1.00000e-02 *
#        [ 9.5064])
# px tensor([ 0.3970])
# result tensor(1.00000e-02 *
#        [ 3.7736])
# g:tensor([ 0.1046])
# grad1:tensor([ 0.1046])
# momtensor([-0.8367])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 9.2185])
# y grad tensor(1.00000e-02 *
#        [ 8.8063])
# px tensor([ 0.3973])
# result tensor(1.00000e-02 *
#        [ 3.4983])
# g:tensor(1.00000e-02 *
#        [ 9.6182])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 8.4970])
# y grad tensor(1.00000e-02 *
#        [ 8.1460])
# px tensor([ 0.3975])
# result tensor(1.00000e-02 *
#        [ 3.2381])
# g:tensor(1.00000e-02 *
#        [ 8.8382])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 7.8232])
# y grad tensor(1.00000e-02 *
#        [ 7.5250])
# px tensor([ 0.3977])
# result tensor(1.00000e-02 *
#        [ 2.9929])
# g:tensor(1.00000e-02 *
#        [ 8.1137])
# ========== 2nd hamiltonian ==============
# x tensor(1.00000e-02 *
#        [ 7.8232])
# y grad tensor(1.00000e-02 *
#        [ 7.5250])
# px tensor([ 0.3977])
# result tensor(1.00000e-02 *
#        [ 2.9929])
# ========== 3rd hamiltonian ==============
# x tensor(1.00000e-02 *
#        [ 7.8232])
# y grad tensor(1.00000e-02 *
#        [ 7.5250])
# px tensor([ 0.3977])
# result tensor(1.00000e-02 *
#        [ 2.9929])
# Sample: 791
# ========== simulate ==============
# pos:tensor([-2.5087]) True
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 7.8232])
# y grad tensor(1.00000e-02 *
#        [ 7.5250])
# px tensor([ 0.3977])
# result tensor(1.00000e-02 *
#        [ 2.9929])
# g:tensor(1.00000e-02 *
#        [ 8.1137])
# grad1:tensor(1.00000e-02 *
#        [ 8.1137])
# momtensor([-0.2694])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 7.6200])
# y grad tensor(1.00000e-02 *
#        [ 7.3369])
# px tensor([ 0.3978])
# result tensor(1.00000e-02 *
#        [ 2.9185])
# g:tensor(1.00000e-02 *
#        [ 7.8960])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 7.4163])
# y grad tensor(1.00000e-02 *
#        [ 7.1479])
# px tensor([ 0.3978])
# result tensor(1.00000e-02 *
#        [ 2.8438])
# g:tensor(1.00000e-02 *
#        [ 7.6780])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 7.2124])
# y grad tensor(1.00000e-02 *
#        [ 6.9585])
# px tensor([ 0.3979])
# result tensor(1.00000e-02 *
#        [ 2.7688])
# g:tensor(1.00000e-02 *
#        [ 7.4603])
# ========== 2nd hamiltonian ==============
# x tensor(1.00000e-02 *
#        [ 7.2124])
# y grad tensor(1.00000e-02 *
#        [ 6.9585])
# px tensor([ 0.3979])
# result tensor(1.00000e-02 *
#        [ 2.7688])
# ========== 3rd hamiltonian ==============
# x tensor(1.00000e-02 *
#        [ 7.2124])
# y grad tensor(1.00000e-02 *
#        [ 6.9585])
# px tensor([ 0.3979])
# result tensor(1.00000e-02 *
#        [ 2.7688])
# Sample: 792
# ========== simulate ==============
# pos:tensor([-2.5931]) True
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 7.2124])
# y grad tensor(1.00000e-02 *
#        [ 6.9585])
# px tensor([ 0.3979])
# result tensor(1.00000e-02 *
#        [ 2.7688])
# g:tensor(1.00000e-02 *
#        [ 7.4603])
# grad1:tensor(1.00000e-02 *
#        [ 7.4603])
# momtensor([ 0.6262])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 7.6583])
# y grad tensor(1.00000e-02 *
#        [ 7.3724])
# px tensor([ 0.3978])
# result tensor(1.00000e-02 *
#        [ 2.9326])
# g:tensor(1.00000e-02 *
#        [ 7.9370])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 8.1245])
# y grad tensor(1.00000e-02 *
#        [ 7.8032])
# px tensor([ 0.3976])
# result tensor(1.00000e-02 *
#        [ 3.1028])
# g:tensor(1.00000e-02 *
#        [ 8.4372])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 8.6108])
# y grad tensor(1.00000e-02 *
#        [ 8.2505])
# px tensor([ 0.3975])
# result tensor(1.00000e-02 *
#        [ 3.2793])
# g:tensor(1.00000e-02 *
#        [ 8.9610])
# ========== 2nd hamiltonian ==============
# x tensor(1.00000e-02 *
#        [ 8.6108])
# y grad tensor(1.00000e-02 *
#        [ 8.2505])
# px tensor([ 0.3975])
# result tensor(1.00000e-02 *
#        [ 3.2793])
# ========== 3rd hamiltonian ==============
# x tensor(1.00000e-02 *
#        [ 8.6108])
# y grad tensor(1.00000e-02 *
#        [ 8.2505])
# px tensor([ 0.3975])
# result tensor(1.00000e-02 *
#        [ 3.2793])
# Sample: 793
# ========== simulate ==============
# pos:tensor([-2.4088]) True
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 8.6108])
# y grad tensor(1.00000e-02 *
#        [ 8.2505])
# px tensor([ 0.3975])
# result tensor(1.00000e-02 *
#        [ 3.2793])
# g:tensor(1.00000e-02 *
#        [ 8.9610])
# grad1:tensor(1.00000e-02 *
#        [ 8.9610])
# momtensor([ 1.1288])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 9.5878])
# y grad tensor(1.00000e-02 *
#        [ 9.1425])
# px tensor([ 0.3971])
# result tensor(1.00000e-02 *
#        [ 3.6306])
# g:tensor([ 0.1002])
# ------calling energy function------
# x tensor([ 0.1066])
# y grad tensor([ 0.1011])
# px tensor([ 0.3967])
# result tensor(1.00000e-02 *
#        [ 4.0109])
# g:tensor([ 0.1119])
# ------calling energy function------
# x tensor([ 0.1183])
# y grad tensor([ 0.1116])
# px tensor([ 0.3962])
# result tensor(1.00000e-02 *
#        [ 4.4207])
# g:tensor([ 0.1248])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1183])
# y grad tensor([ 0.1116])
# px tensor([ 0.3962])
# result tensor(1.00000e-02 *
#        [ 4.4207])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1183])
# y grad tensor([ 0.1116])
# px tensor([ 0.3962])
# result tensor(1.00000e-02 *
#        [ 4.4207])
# Sample: 794
# ========== simulate ==============
# pos:tensor([-2.0746]) True
# ------calling energy function------
# x tensor([ 0.1183])
# y grad tensor([ 0.1116])
# px tensor([ 0.3962])
# result tensor(1.00000e-02 *
#        [ 4.4207])
# g:tensor([ 0.1248])
# grad1:tensor([ 0.1248])
# momtensor([ 0.8681])
# ------calling energy function------
# x tensor([ 0.1283])
# y grad tensor([ 0.1204])
# px tensor([ 0.3957])
# result tensor(1.00000e-02 *
#        [ 4.7648])
# g:tensor([ 0.1359])
# ------calling energy function------
# x tensor([ 0.1389])
# y grad tensor([ 0.1297])
# px tensor([ 0.3951])
# result tensor(1.00000e-02 *
#        [ 5.1247])
# g:tensor([ 0.1477])
# ------calling energy function------
# x tensor([ 0.1501])
# y grad tensor([ 0.1394])
# px tensor([ 0.3945])
# result tensor(1.00000e-02 *
#        [ 5.4991])
# g:tensor([ 0.1603])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1501])
# y grad tensor([ 0.1394])
# px tensor([ 0.3945])
# result tensor(1.00000e-02 *
#        [ 5.4991])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1501])
# y grad tensor([ 0.1394])
# px tensor([ 0.3945])
# result tensor(1.00000e-02 *
#        [ 5.4991])
# Sample: 795
# ========== simulate ==============
# pos:tensor([-1.8202]) True
# ------calling energy function------
# x tensor([ 0.1501])
# y grad tensor([ 0.1394])
# px tensor([ 0.3945])
# result tensor(1.00000e-02 *
#        [ 5.4991])
# g:tensor([ 0.1603])
# grad1:tensor([ 0.1603])
# momtensor([ 1.0426])
# ------calling energy function------
# x tensor([ 0.1652])
# y grad tensor([ 0.1523])
# px tensor([ 0.3935])
# result tensor(1.00000e-02 *
#        [ 5.9929])
# g:tensor([ 0.1774])
# ------calling energy function------
# x tensor([ 0.1814])
# y grad tensor([ 0.1659])
# px tensor([ 0.3924])
# result tensor(1.00000e-02 *
#        [ 6.5097])
# g:tensor([ 0.1960])
# ------calling energy function------
# x tensor([ 0.1986])
# y grad tensor([ 0.1801])
# px tensor([ 0.3912])
# result tensor(1.00000e-02 *
#        [ 7.0462])
# g:tensor([ 0.2159])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1986])
# y grad tensor([ 0.1801])
# px tensor([ 0.3912])
# result tensor(1.00000e-02 *
#        [ 7.0462])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1986])
# y grad tensor([ 0.1801])
# px tensor([ 0.3912])
# result tensor(1.00000e-02 *
#        [ 7.0462])
# Sample: 796
# ========== simulate ==============
# pos:tensor([-1.5154]) True
# ------calling energy function------
# x tensor([ 0.1986])
# y grad tensor([ 0.1801])
# px tensor([ 0.3912])
# result tensor(1.00000e-02 *
#        [ 7.0462])
# g:tensor([ 0.2159])
# grad1:tensor([ 0.2159])
# momtensor([-0.7453])
# ------calling energy function------
# x tensor([ 0.1854])
# y grad tensor([ 0.1692])
# px tensor([ 0.3921])
# result tensor(1.00000e-02 *
#        [ 6.6367])
# g:tensor([ 0.2006])
# ------calling energy function------
# x tensor([ 0.1727])
# y grad tensor([ 0.1586])
# px tensor([ 0.3930])
# result tensor(1.00000e-02 *
#        [ 6.2339])
# g:tensor([ 0.1860])
# ------calling energy function------
# x tensor([ 0.1605])
# y grad tensor([ 0.1483])
# px tensor([ 0.3938])
# result tensor(1.00000e-02 *
#        [ 5.8401])
# g:tensor([ 0.1721])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1605])
# y grad tensor([ 0.1483])
# px tensor([ 0.3938])
# result tensor(1.00000e-02 *
#        [ 5.8401])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1605])
# y grad tensor([ 0.1483])
# px tensor([ 0.3938])
# result tensor(1.00000e-02 *
#        [ 5.8401])
# Sample: 797
# ========== simulate ==============
# pos:tensor([-1.7481]) True
# ------calling energy function------
# x tensor([ 0.1605])
# y grad tensor([ 0.1483])
# px tensor([ 0.3938])
# result tensor(1.00000e-02 *
#        [ 5.8401])
# g:tensor([ 0.1721])
# grad1:tensor([ 0.1721])
# momtensor(1.00000e-02 *
#        [-9.7392])
# ------calling energy function------
# x tensor([ 0.1589])
# y grad tensor([ 0.1470])
# px tensor([ 0.3939])
# result tensor(1.00000e-02 *
#        [ 5.7890])
# g:tensor([ 0.1703])
# ------calling energy function------
# x tensor([ 0.1571])
# y grad tensor([ 0.1454])
# px tensor([ 0.3940])
# result tensor(1.00000e-02 *
#        [ 5.7301])
# g:tensor([ 0.1683])
# ------calling energy function------
# x tensor([ 0.1551])
# y grad tensor([ 0.1437])
# px tensor([ 0.3942])
# result tensor(1.00000e-02 *
#        [ 5.6638])
# g:tensor([ 0.1660])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1551])
# y grad tensor([ 0.1437])
# px tensor([ 0.3942])
# result tensor(1.00000e-02 *
#        [ 5.6638])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1551])
# y grad tensor([ 0.1437])
# px tensor([ 0.3942])
# result tensor(1.00000e-02 *
#        [ 5.6638])
# Sample: 798
# ========== simulate ==============
# pos:tensor([-1.7850]) True
# ------calling energy function------
# x tensor([ 0.1551])
# y grad tensor([ 0.1437])
# px tensor([ 0.3942])
# result tensor(1.00000e-02 *
#        [ 5.6638])
# g:tensor([ 0.1660])
# grad1:tensor([ 0.1660])
# momtensor([-1.0448])
# ------calling energy function------
# x tensor([ 0.1407])
# y grad tensor([ 0.1312])
# px tensor([ 0.3950])
# result tensor(1.00000e-02 *
#        [ 5.1830])
# g:tensor([ 0.1497])
# ------calling energy function------
# x tensor([ 0.1273])
# y grad tensor([ 0.1195])
# px tensor([ 0.3957])
# result tensor(1.00000e-02 *
#        [ 4.7292])
# g:tensor([ 0.1347])
# ------calling energy function------
# x tensor([ 0.1149])
# y grad tensor([ 0.1086])
# px tensor([ 0.3963])
# result tensor(1.00000e-02 *
#        [ 4.3035])
# g:tensor([ 0.1211])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1149])
# y grad tensor([ 0.1086])
# px tensor([ 0.3963])
# result tensor(1.00000e-02 *
#        [ 4.3035])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1149])
# y grad tensor([ 0.1086])
# px tensor([ 0.3963])
# result tensor(1.00000e-02 *
#        [ 4.3035])
# Sample: 799
# ========== simulate ==============
# pos:tensor([-2.1053]) True
# ------calling energy function------
# x tensor([ 0.1149])
# y grad tensor([ 0.1086])
# px tensor([ 0.3963])
# result tensor(1.00000e-02 *
#        [ 4.3035])
# g:tensor([ 0.1211])
# grad1:tensor([ 0.1211])
# momtensor([-1.7015])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 9.7756])
# y grad tensor(1.00000e-02 *
#        [ 9.3130])
# px tensor([ 0.3970])
# result tensor(1.00000e-02 *
#        [ 3.6976])
# g:tensor([ 0.1022])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 8.2948])
# y grad tensor(1.00000e-02 *
#        [ 7.9601])
# px tensor([ 0.3976])
# result tensor(1.00000e-02 *
#        [ 3.1647])
# g:tensor(1.00000e-02 *
#        [ 8.6204])
# ------calling energy function------
# x tensor(1.00000e-02 *
#        [ 7.0247])
# y grad tensor(1.00000e-02 *
#        [ 6.7836])
# px tensor([ 0.3980])
# result tensor(1.00000e-02 *
#        [ 2.6996])
# g:tensor(1.00000e-02 *
#        [ 7.2601])
# ========== 2nd hamiltonian ==============
# x tensor(1.00000e-02 *
#        [ 7.0247])
# y grad tensor(1.00000e-02 *
#        [ 6.7836])
# px tensor([ 0.3980])
# result tensor(1.00000e-02 *
#        [ 2.6996])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1149])
# y grad tensor([ 0.1086])
# px tensor([ 0.3963])
# result tensor(1.00000e-02 *
#        [ 4.3035])

# %%
x_list = [np.log(1+np.exp(e)) for e in y_list]
plt.hist(x_list)
plt.show()

# %%
"""
x_list = []
y_list = []
for i in range(100):
    pos_samples, mom_samples, ratio = sampler.get_samples(init, 0.1, 5, 1, torch.tensor([1.], requires_grad=True))
    y = pos_samples.detach().numpy()[0][0]
    x = torch.log(1+torch.exp(pos_samples)).detach().numpy()[0][0]
    x_list.append(x)
    y_list.append(y)
"""
# Out:
# '\nx_list = []\ny_list = []\nfor i in range(100):\n    pos_samples, mom_samples, ratio = sampler.get_samples(init, 0.1, 5, 1, torch.tensor([1.], requires_grad=True))\n    y = pos_samples.detach().numpy()[0][0]\n    x = torch.log(1+torch.exp(pos_samples)).detach().numpy()[0][0]\n    x_list.append(x)\n    y_list.append(y)\n'

# %%
l = []
for i in range(1000):
    prng = np.random.RandomState()
    x = prng.normal(0)
    l.append(x)
x = prng.normal([0, 0])
print(x)
plt.hist(l)
plt.show()
# Out:
# [ 1.61497581  0.31790423]
