# %%
import sys
sys.path.append('F:\Cambridge\Project\MHMC-for-VAE/hmc_pytorch')
from hmc_base_pytorch import *
from hmc_unconstrained_pytorch import *
import autograd.numpy as np
import torch
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.distributions.normal import Normal
import matplotlib.pyplot as plt

# %% [markdown]
# # Get pdf p(y) of proxy variable y for x = g(y) where p(x) is known

# %%
def reparameter_pdf(transform, x_pdf, y):
    '''
    transform: function x = g(y) that transforms random variable y into x
    x_pdf: pdf of x
    '''
    # get gradient g'(y)
    #y.grad.zero_()
    #yy = torch.tensor([y.item()], requires_grad=True)
    #y.retain_grad()
    yy = y.clone()
    yy.retain_grad()
    x = transform(yy)
    print("x "+str(x))
    num = yy.shape[0]
    tmp = torch.ones(num)
    x.backward(tmp,retain_graph=True)
    print("y grad "+str(yy.grad))
    grad = torch.abs(yy.grad).float()

    
    # get p_x(x)
    px = x_pdf(x)
    print("px "+str(px))
    result = px*grad
    yy.grad.data.zero_()
    print("result "+str(result))
    #print(px.dtype)
    return result

# %%
def transform(y):
    return torch.log(1 + torch.exp(y))

def x_pdf(x):
    m = Normal(torch.tensor([0.]), torch.tensor([1.]))
    m.requires_grad=True
    n = torch.exp(m.log_prob(x))
    #n.requires_grad=True
    return n

def energy_function(y, cache):
    y.retain_grad()
    p = reparameter_pdf(transform, x_pdf, y)
    #y.grad.zero_()
    return 0-torch.log(p)

# %%
"""
def energy_function(y, cache):
    y.retain_grad()
    m = Normal(torch.tensor([0.]), torch.tensor([1.]))
    n = torch.exp(m.log_prob(y))
    return 0 - torch.log(n)
    
def gradient(pos, cache):
    pos.retain_grad()
    r = energy_function(pos, cache)
    r.backward(retain_graph=True)
    g = pos.grad.clone()
    
    print("g:"+str(pos.grad))
    #pos.grad.zero_()
    pos.grad.data.zero_()
    return g
    
pos = torch.tensor([0.], requires_grad=True)
gradient(pos, None)
"""
# Out:
# '\ndef energy_function(y, cache):\n    y.retain_grad()\n    m = Normal(torch.tensor([0.]), torch.tensor([1.]))\n    n = torch.exp(m.log_prob(y))\n    return 0 - torch.log(n)\n    \ndef gradient(pos, cache):\n    pos.retain_grad()\n    r = energy_function(pos, cache)\n    r.backward(retain_graph=True)\n    g = pos.grad.clone()\n    \n    print("g:"+str(pos.grad))\n    #pos.grad.zero_()\n    pos.grad.data.zero_()\n    return g\n    \npos = torch.tensor([0.], requires_grad=True)\ngradient(pos, None)\n'

# %%
y = torch.tensor([0.], requires_grad=True)
transform(y).requires_grad
#energy_function(y, None).requires_grad
# Out:
# True

# %%
sampler = IsotropicHmcSampler(energy_function, energy_grad=None, prng=None,
                 mom_resample_coeff=1., dtype=np.float64)

# %%
init = torch.tensor([0.], requires_grad=True)
pos_samples, mom_samples, ratio = sampler.get_samples(init, 0.1, 3, 800, torch.tensor([1.], requires_grad=True))
num = pos_samples.shape[0]
y_list = []
for i in range(num):
    y_list.append(pos_samples[i].item())
# Out:
# ========== 1st hamiltonian ==============
# x tensor([ 0.6931])
# y grad tensor([ 0.5000])
# px tensor([ 0.3137])
# result tensor([ 0.1569])
# Sample: 1
# ========== simulate ==============
# pos:tensor([ 0.]) True
# ------calling energy function------
# x tensor([ 0.6931])
# y grad tensor([ 0.5000])
# px tensor([ 0.3137])
# result tensor([ 0.1569])
# g:tensor([ 0.8466])
# grad1:tensor([ 0.8466])
# momtensor([-1.5002])
# ------calling energy function------
# x tensor([ 0.6190])
# y grad tensor([ 0.4615])
# px tensor([ 0.3294])
# result tensor([ 0.1520])
# g:tensor([ 0.7472])
# ------calling energy function------
# x tensor([ 0.5476])
# y grad tensor([ 0.4217])
# px tensor([ 0.3434])
# result tensor([ 0.1448])
# g:tensor([ 0.6525])
# ------calling energy function------
# x tensor([ 0.4801])
# y grad tensor([ 0.3813])
# px tensor([ 0.3555])
# result tensor([ 0.1355])
# g:tensor([ 0.5643])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4801])
# y grad tensor([ 0.3813])
# px tensor([ 0.3555])
# result tensor([ 0.1355])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6931])
# y grad tensor([ 0.5000])
# px tensor([ 0.3137])
# result tensor([ 0.1569])
# Sample: 2
# ========== simulate ==============
# pos:tensor([ 0.]) True
# ------calling energy function------
# x tensor([ 0.6931])
# y grad tensor([ 0.5000])
# px tensor([ 0.3137])
# result tensor([ 0.1569])
# g:tensor([ 0.8466])
# grad1:tensor([ 0.8466])
# momtensor([-0.6100])
# ------calling energy function------
# x tensor([ 0.6611])
# y grad tensor([ 0.4837])
# px tensor([ 0.3206])
# result tensor([ 0.1551])
# g:tensor([ 0.8034])
# ------calling energy function------
# x tensor([ 0.6263])
# y grad tensor([ 0.4654])
# px tensor([ 0.3279])
# result tensor([ 0.1526])
# g:tensor([ 0.7569])
# ------calling energy function------
# x tensor([ 0.5895])
# y grad tensor([ 0.4454])
# px tensor([ 0.3353])
# result tensor([ 0.1493])
# g:tensor([ 0.7079])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5895])
# y grad tensor([ 0.4454])
# px tensor([ 0.3353])
# result tensor([ 0.1493])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5895])
# y grad tensor([ 0.4454])
# px tensor([ 0.3353])
# result tensor([ 0.1493])
# Sample: 3
# ========== simulate ==============
# pos:tensor([-0.2193]) True
# ------calling energy function------
# x tensor([ 0.5895])
# y grad tensor([ 0.4454])
# px tensor([ 0.3353])
# result tensor([ 0.1493])
# g:tensor([ 0.7079])
# grad1:tensor([ 0.7079])
# momtensor([ 0.8506])
# ------calling energy function------
# x tensor([ 0.6266])
# y grad tensor([ 0.4656])
# px tensor([ 0.3278])
# result tensor([ 0.1526])
# g:tensor([ 0.7573])
# ------calling energy function------
# x tensor([ 0.6617])
# y grad tensor([ 0.4840])
# px tensor([ 0.3205])
# result tensor([ 0.1551])
# g:tensor([ 0.8043])
# ------calling energy function------
# x tensor([ 0.6942])
# y grad tensor([ 0.5005])
# px tensor([ 0.3135])
# result tensor([ 0.1569])
# g:tensor([ 0.8479])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6942])
# y grad tensor([ 0.5005])
# px tensor([ 0.3135])
# result tensor([ 0.1569])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6942])
# y grad tensor([ 0.5005])
# px tensor([ 0.3135])
# result tensor([ 0.1569])
# Sample: 4
# ========== simulate ==============
# pos:tensor(1.00000e-03 *
#        [ 2.0347]) True
# ------calling energy function------
# x tensor([ 0.6942])
# y grad tensor([ 0.5005])
# px tensor([ 0.3135])
# result tensor([ 0.1569])
# g:tensor([ 0.8479])
# grad1:tensor([ 0.8479])
# momtensor([-0.9346])
# ------calling energy function------
# x tensor([ 0.6465])
# y grad tensor([ 0.4761])
# px tensor([ 0.3237])
# result tensor([ 0.1541])
# g:tensor([ 0.7839])
# ------calling energy function------
# x tensor([ 0.5976])
# y grad tensor([ 0.4499])
# px tensor([ 0.3337])
# result tensor([ 0.1501])
# g:tensor([ 0.7187])
# ------calling energy function------
# x tensor([ 0.5485])
# y grad tensor([ 0.4222])
# px tensor([ 0.3432])
# result tensor([ 0.1449])
# g:tensor([ 0.6537])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5485])
# y grad tensor([ 0.4222])
# px tensor([ 0.3432])
# result tensor([ 0.1449])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5485])
# y grad tensor([ 0.4222])
# px tensor([ 0.3432])
# result tensor([ 0.1449])
# Sample: 5
# ========== simulate ==============
# pos:tensor([-0.3139]) True
# ------calling energy function------
# x tensor([ 0.5485])
# y grad tensor([ 0.4222])
# px tensor([ 0.3432])
# result tensor([ 0.1449])
# g:tensor([ 0.6537])
# grad1:tensor([ 0.6537])
# momtensor(1.00000e-02 *
#        [ 8.1181])
# ------calling energy function------
# x tensor([ 0.5505])
# y grad tensor([ 0.4233])
# px tensor([ 0.3428])
# result tensor([ 0.1451])
# g:tensor([ 0.6564])
# ------calling energy function------
# x tensor([ 0.5498])
# y grad tensor([ 0.4229])
# px tensor([ 0.3430])
# result tensor([ 0.1451])
# g:tensor([ 0.6554])
# ------calling energy function------
# x tensor([ 0.5463])
# y grad tensor([ 0.4209])
# px tensor([ 0.3436])
# result tensor([ 0.1446])
# g:tensor([ 0.6508])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5463])
# y grad tensor([ 0.4209])
# px tensor([ 0.3436])
# result tensor([ 0.1446])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5463])
# y grad tensor([ 0.4209])
# px tensor([ 0.3436])
# result tensor([ 0.1446])
# Sample: 6
# ========== simulate ==============
# pos:tensor([-0.3191]) True
# ------calling energy function------
# x tensor([ 0.5463])
# y grad tensor([ 0.4209])
# px tensor([ 0.3436])
# result tensor([ 0.1446])
# g:tensor([ 0.6508])
# grad1:tensor([ 0.6508])
# momtensor([ 1.0792])
# ------calling energy function------
# x tensor([ 0.5917])
# y grad tensor([ 0.4466])
# px tensor([ 0.3349])
# result tensor([ 0.1496])
# g:tensor([ 0.7109])
# ------calling energy function------
# x tensor([ 0.6364])
# y grad tensor([ 0.4708])
# px tensor([ 0.3258])
# result tensor([ 0.1534])
# g:tensor([ 0.7705])
# ------calling energy function------
# x tensor([ 0.6797])
# y grad tensor([ 0.4933])
# px tensor([ 0.3166])
# result tensor([ 0.1562])
# g:tensor([ 0.8285])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6797])
# y grad tensor([ 0.4933])
# px tensor([ 0.3166])
# result tensor([ 0.1562])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6797])
# y grad tensor([ 0.4933])
# px tensor([ 0.3166])
# result tensor([ 0.1562])
# Sample: 7
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [-2.6978]) True
# ------calling energy function------
# x tensor([ 0.6797])
# y grad tensor([ 0.4933])
# px tensor([ 0.3166])
# result tensor([ 0.1562])
# g:tensor([ 0.8285])
# grad1:tensor([ 0.8285])
# momtensor([ 0.1891])
# ------calling energy function------
# x tensor([ 0.6871])
# y grad tensor([ 0.4969])
# px tensor([ 0.3151])
# result tensor([ 0.1566])
# g:tensor([ 0.8384])
# ------calling energy function------
# x tensor([ 0.6902])
# y grad tensor([ 0.4985])
# px tensor([ 0.3144])
# result tensor([ 0.1567])
# g:tensor([ 0.8427])
# ------calling energy function------
# x tensor([ 0.6892])
# y grad tensor([ 0.4980])
# px tensor([ 0.3146])
# result tensor([ 0.1567])
# g:tensor([ 0.8413])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6892])
# y grad tensor([ 0.4980])
# px tensor([ 0.3146])
# result tensor([ 0.1567])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6892])
# y grad tensor([ 0.4980])
# px tensor([ 0.3146])
# result tensor([ 0.1567])
# Sample: 8
# ========== simulate ==============
# pos:tensor(1.00000e-03 *
#        [-7.8762]) True
# ------calling energy function------
# x tensor([ 0.6892])
# y grad tensor([ 0.4980])
# px tensor([ 0.3146])
# result tensor([ 0.1567])
# g:tensor([ 0.8413])
# grad1:tensor([ 0.8413])
# momtensor([-1.6575])
# ------calling energy function------
# x tensor([ 0.6082])
# y grad tensor([ 0.4557])
# px tensor([ 0.3316])
# result tensor([ 0.1511])
# g:tensor([ 0.7328])
# ------calling energy function------
# x tensor([ 0.5313])
# y grad tensor([ 0.4121])
# px tensor([ 0.3464])
# result tensor([ 0.1428])
# g:tensor([ 0.6311])
# ------calling energy function------
# x tensor([ 0.4596])
# y grad tensor([ 0.3685])
# px tensor([ 0.3590])
# result tensor([ 0.1323])
# g:tensor([ 0.5379])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4596])
# y grad tensor([ 0.3685])
# px tensor([ 0.3590])
# result tensor([ 0.1323])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4596])
# y grad tensor([ 0.3685])
# px tensor([ 0.3590])
# result tensor([ 0.1323])
# Sample: 9
# ========== simulate ==============
# pos:tensor([-0.5387]) True
# ------calling energy function------
# x tensor([ 0.4596])
# y grad tensor([ 0.3685])
# px tensor([ 0.3590])
# result tensor([ 0.1323])
# g:tensor([ 0.5379])
# grad1:tensor([ 0.5379])
# momtensor([-1.2232])
# ------calling energy function------
# x tensor([ 0.4154])
# y grad tensor([ 0.3399])
# px tensor([ 0.3660])
# result tensor([ 0.1244])
# g:tensor([ 0.4811])
# ------calling energy function------
# x tensor([ 0.3731])
# y grad tensor([ 0.3114])
# px tensor([ 0.3721])
# result tensor([ 0.1159])
# g:tensor([ 0.4276])
# ------calling energy function------
# x tensor([ 0.3332])
# y grad tensor([ 0.2834])
# px tensor([ 0.3774])
# result tensor([ 0.1070])
# g:tensor([ 0.3778])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3332])
# y grad tensor([ 0.2834])
# px tensor([ 0.3774])
# result tensor([ 0.1070])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4596])
# y grad tensor([ 0.3685])
# px tensor([ 0.3590])
# result tensor([ 0.1323])
# Sample: 10
# ========== simulate ==============
# pos:tensor([-0.5387]) True
# ------calling energy function------
# x tensor([ 0.4596])
# y grad tensor([ 0.3685])
# px tensor([ 0.3590])
# result tensor([ 0.1323])
# g:tensor([ 0.5379])
# grad1:tensor([ 0.5379])
# momtensor([ 0.2512])
# ------calling energy function------
# x tensor([ 0.4680])
# y grad tensor([ 0.3737])
# px tensor([ 0.3576])
# result tensor([ 0.1336])
# g:tensor([ 0.5486])
# ------calling energy function------
# x tensor([ 0.4743])
# y grad tensor([ 0.3777])
# px tensor([ 0.3565])
# result tensor([ 0.1346])
# g:tensor([ 0.5568])
# ------calling energy function------
# x tensor([ 0.4786])
# y grad tensor([ 0.3804])
# px tensor([ 0.3558])
# result tensor([ 0.1353])
# g:tensor([ 0.5624])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4786])
# y grad tensor([ 0.3804])
# px tensor([ 0.3558])
# result tensor([ 0.1353])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4786])
# y grad tensor([ 0.3804])
# px tensor([ 0.3558])
# result tensor([ 0.1353])
# Sample: 11
# ========== simulate ==============
# pos:tensor([-0.4880]) True
# ------calling energy function------
# x tensor([ 0.4786])
# y grad tensor([ 0.3804])
# px tensor([ 0.3558])
# result tensor([ 0.1353])
# g:tensor([ 0.5624])
# grad1:tensor([ 0.5624])
# momtensor([-0.3463])
# ------calling energy function------
# x tensor([ 0.4646])
# y grad tensor([ 0.3716])
# px tensor([ 0.3581])
# result tensor([ 0.1331])
# g:tensor([ 0.5442])
# ------calling energy function------
# x tensor([ 0.4488])
# y grad tensor([ 0.3616])
# px tensor([ 0.3607])
# result tensor([ 0.1304])
# g:tensor([ 0.5239])
# ------calling energy function------
# x tensor([ 0.4317])
# y grad tensor([ 0.3506])
# px tensor([ 0.3634])
# result tensor([ 0.1274])
# g:tensor([ 0.5019])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4317])
# y grad tensor([ 0.3506])
# px tensor([ 0.3634])
# result tensor([ 0.1274])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4317])
# y grad tensor([ 0.3506])
# px tensor([ 0.3634])
# result tensor([ 0.1274])
# Sample: 12
# ========== simulate ==============
# pos:tensor([-0.6164]) True
# ------calling energy function------
# x tensor([ 0.4317])
# y grad tensor([ 0.3506])
# px tensor([ 0.3634])
# result tensor([ 0.1274])
# g:tensor([ 0.5019])
# grad1:tensor([ 0.5019])
# momtensor([ 0.5061])
# ------calling energy function------
# x tensor([ 0.4488])
# y grad tensor([ 0.3616])
# px tensor([ 0.3607])
# result tensor([ 0.1304])
# g:tensor([ 0.5239])
# ------calling energy function------
# x tensor([ 0.4645])
# y grad tensor([ 0.3716])
# px tensor([ 0.3581])
# result tensor([ 0.1331])
# g:tensor([ 0.5442])
# ------calling energy function------
# x tensor([ 0.4786])
# y grad tensor([ 0.3803])
# px tensor([ 0.3558])
# result tensor([ 0.1353])
# g:tensor([ 0.5624])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4786])
# y grad tensor([ 0.3803])
# px tensor([ 0.3558])
# result tensor([ 0.1353])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4786])
# y grad tensor([ 0.3803])
# px tensor([ 0.3558])
# result tensor([ 0.1353])
# Sample: 13
# ========== simulate ==============
# pos:tensor([-0.4881]) True
# ------calling energy function------
# x tensor([ 0.4786])
# y grad tensor([ 0.3803])
# px tensor([ 0.3558])
# result tensor([ 0.1353])
# g:tensor([ 0.5624])
# grad1:tensor([ 0.5624])
# momtensor([ 0.7284])
# ------calling energy function------
# x tensor([ 0.5058])
# y grad tensor([ 0.3970])
# px tensor([ 0.3510])
# result tensor([ 0.1394])
# g:tensor([ 0.5978])
# ------calling energy function------
# x tensor([ 0.5317])
# y grad tensor([ 0.4124])
# px tensor([ 0.3463])
# result tensor([ 0.1428])
# g:tensor([ 0.6317])
# ------calling energy function------
# x tensor([ 0.5560])
# y grad tensor([ 0.4265])
# px tensor([ 0.3418])
# result tensor([ 0.1458])
# g:tensor([ 0.6636])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5560])
# y grad tensor([ 0.4265])
# px tensor([ 0.3418])
# result tensor([ 0.1458])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5560])
# y grad tensor([ 0.4265])
# px tensor([ 0.3418])
# result tensor([ 0.1458])
# Sample: 14
# ========== simulate ==============
# pos:tensor([-0.2963]) True
# ------calling energy function------
# x tensor([ 0.5560])
# y grad tensor([ 0.4265])
# px tensor([ 0.3418])
# result tensor([ 0.1458])
# g:tensor([ 0.6636])
# grad1:tensor([ 0.6636])
# momtensor([-0.4265])
# ------calling energy function------
# x tensor([ 0.5366])
# y grad tensor([ 0.4153])
# px tensor([ 0.3454])
# result tensor([ 0.1435])
# g:tensor([ 0.6381])
# ------calling energy function------
# x tensor([ 0.5152])
# y grad tensor([ 0.4026])
# px tensor([ 0.3494])
# result tensor([ 0.1407])
# g:tensor([ 0.6100])
# ------calling energy function------
# x tensor([ 0.4921])
# y grad tensor([ 0.3886])
# px tensor([ 0.3535])
# result tensor([ 0.1374])
# g:tensor([ 0.5799])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4921])
# y grad tensor([ 0.3886])
# px tensor([ 0.3535])
# result tensor([ 0.1374])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4921])
# y grad tensor([ 0.3886])
# px tensor([ 0.3535])
# result tensor([ 0.1374])
# Sample: 15
# ========== simulate ==============
# pos:tensor([-0.4530]) True
# ------calling energy function------
# x tensor([ 0.4921])
# y grad tensor([ 0.3886])
# px tensor([ 0.3535])
# result tensor([ 0.1374])
# g:tensor([ 0.5799])
# grad1:tensor([ 0.5799])
# momtensor([-1.0766])
# ------calling energy function------
# x tensor([ 0.4505])
# y grad tensor([ 0.3627])
# px tensor([ 0.3604])
# result tensor([ 0.1307])
# g:tensor([ 0.5261])
# ------calling energy function------
# x tensor([ 0.4101])
# y grad tensor([ 0.3364])
# px tensor([ 0.3668])
# result tensor([ 0.1234])
# g:tensor([ 0.4743])
# ------calling energy function------
# x tensor([ 0.3711])
# y grad tensor([ 0.3100])
# px tensor([ 0.3724])
# result tensor([ 0.1155])
# g:tensor([ 0.4251])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3711])
# y grad tensor([ 0.3100])
# px tensor([ 0.3724])
# result tensor([ 0.1155])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4921])
# y grad tensor([ 0.3886])
# px tensor([ 0.3535])
# result tensor([ 0.1374])
# Sample: 16
# ========== simulate ==============
# pos:tensor([-0.4530]) True
# ------calling energy function------
# x tensor([ 0.4921])
# y grad tensor([ 0.3886])
# px tensor([ 0.3535])
# result tensor([ 0.1374])
# g:tensor([ 0.5799])
# grad1:tensor([ 0.5799])
# momtensor([-1.3025])
# ------calling energy function------
# x tensor([ 0.4424])
# y grad tensor([ 0.3575])
# px tensor([ 0.3618])
# result tensor([ 0.1293])
# g:tensor([ 0.5157])
# ------calling energy function------
# x tensor([ 0.3951])
# y grad tensor([ 0.3264])
# px tensor([ 0.3690])
# result tensor([ 0.1204])
# g:tensor([ 0.4554])
# ------calling energy function------
# x tensor([ 0.3507])
# y grad tensor([ 0.2958])
# px tensor([ 0.3751])
# result tensor([ 0.1110])
# g:tensor([ 0.3995])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3507])
# y grad tensor([ 0.2958])
# px tensor([ 0.3751])
# result tensor([ 0.1110])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3507])
# y grad tensor([ 0.2958])
# px tensor([ 0.3751])
# result tensor([ 0.1110])
# Sample: 17
# ========== simulate ==============
# pos:tensor([-0.8673]) True
# ------calling energy function------
# x tensor([ 0.3507])
# y grad tensor([ 0.2958])
# px tensor([ 0.3751])
# result tensor([ 0.1110])
# g:tensor([ 0.3995])
# grad1:tensor([ 0.3995])
# momtensor([ 0.5593])
# ------calling energy function------
# x tensor([ 0.3670])
# y grad tensor([ 0.3072])
# px tensor([ 0.3730])
# result tensor([ 0.1146])
# g:tensor([ 0.4199])
# ------calling energy function------
# x tensor([ 0.3825])
# y grad tensor([ 0.3178])
# px tensor([ 0.3708])
# result tensor([ 0.1179])
# g:tensor([ 0.4394])
# ------calling energy function------
# x tensor([ 0.3971])
# y grad tensor([ 0.3278])
# px tensor([ 0.3687])
# result tensor([ 0.1208])
# g:tensor([ 0.4579])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3971])
# y grad tensor([ 0.3278])
# px tensor([ 0.3687])
# result tensor([ 0.1208])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3971])
# y grad tensor([ 0.3278])
# px tensor([ 0.3687])
# result tensor([ 0.1208])
# Sample: 18
# ========== simulate ==============
# pos:tensor([-0.7183]) True
# ------calling energy function------
# x tensor([ 0.3971])
# y grad tensor([ 0.3278])
# px tensor([ 0.3687])
# result tensor([ 0.1208])
# g:tensor([ 0.4579])
# grad1:tensor([ 0.4579])
# momtensor([ 1.2982])
# ------calling energy function------
# x tensor([ 0.4408])
# y grad tensor([ 0.3565])
# px tensor([ 0.3620])
# result tensor([ 0.1290])
# g:tensor([ 0.5136])
# ------calling energy function------
# x tensor([ 0.4861])
# y grad tensor([ 0.3850])
# px tensor([ 0.3545])
# result tensor([ 0.1365])
# g:tensor([ 0.5721])
# ------calling energy function------
# x tensor([ 0.5327])
# y grad tensor([ 0.4130])
# px tensor([ 0.3462])
# result tensor([ 0.1430])
# g:tensor([ 0.6329])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5327])
# y grad tensor([ 0.4130])
# px tensor([ 0.3462])
# result tensor([ 0.1430])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5327])
# y grad tensor([ 0.4130])
# px tensor([ 0.3462])
# result tensor([ 0.1430])
# Sample: 19
# ========== simulate ==============
# pos:tensor([-0.3517]) True
# ------calling energy function------
# x tensor([ 0.5327])
# y grad tensor([ 0.4130])
# px tensor([ 0.3462])
# result tensor([ 0.1430])
# g:tensor([ 0.6329])
# grad1:tensor([ 0.6329])
# momtensor([ 0.4578])
# ------calling energy function------
# x tensor([ 0.5505])
# y grad tensor([ 0.4233])
# px tensor([ 0.3429])
# result tensor([ 0.1451])
# g:tensor([ 0.6564])
# ------calling energy function------
# x tensor([ 0.5659])
# y grad tensor([ 0.4322])
# px tensor([ 0.3399])
# result tensor([ 0.1469])
# g:tensor([ 0.6767])
# ------calling energy function------
# x tensor([ 0.5787])
# y grad tensor([ 0.4394])
# px tensor([ 0.3374])
# result tensor([ 0.1483])
# g:tensor([ 0.6936])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5787])
# y grad tensor([ 0.4394])
# px tensor([ 0.3374])
# result tensor([ 0.1483])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5787])
# y grad tensor([ 0.4394])
# px tensor([ 0.3374])
# result tensor([ 0.1483])
# Sample: 20
# ========== simulate ==============
# pos:tensor([-0.2438]) True
# ------calling energy function------
# x tensor([ 0.5787])
# y grad tensor([ 0.4394])
# px tensor([ 0.3374])
# result tensor([ 0.1483])
# g:tensor([ 0.6936])
# grad1:tensor([ 0.6936])
# momtensor([-0.6826])
# ------calling energy function------
# x tensor([ 0.5478])
# y grad tensor([ 0.4218])
# px tensor([ 0.3434])
# result tensor([ 0.1448])
# g:tensor([ 0.6528])
# ------calling energy function------
# x tensor([ 0.5155])
# y grad tensor([ 0.4028])
# px tensor([ 0.3493])
# result tensor([ 0.1407])
# g:tensor([ 0.6105])
# ------calling energy function------
# x tensor([ 0.4824])
# y grad tensor([ 0.3827])
# px tensor([ 0.3551])
# result tensor([ 0.1359])
# g:tensor([ 0.5673])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4824])
# y grad tensor([ 0.3827])
# px tensor([ 0.3551])
# result tensor([ 0.1359])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4824])
# y grad tensor([ 0.3827])
# px tensor([ 0.3551])
# result tensor([ 0.1359])
# Sample: 21
# ========== simulate ==============
# pos:tensor([-0.4781]) True
# ------calling energy function------
# x tensor([ 0.4824])
# y grad tensor([ 0.3827])
# px tensor([ 0.3551])
# result tensor([ 0.1359])
# g:tensor([ 0.5673])
# grad1:tensor([ 0.5673])
# momtensor([ 0.3385])
# ------calling energy function------
# x tensor([ 0.4944])
# y grad tensor([ 0.3901])
# px tensor([ 0.3531])
# result tensor([ 0.1377])
# g:tensor([ 0.5829])
# ------calling energy function------
# x tensor([ 0.5043])
# y grad tensor([ 0.3961])
# px tensor([ 0.3513])
# result tensor([ 0.1391])
# g:tensor([ 0.5958])
# ------calling energy function------
# x tensor([ 0.5119])
# y grad tensor([ 0.4007])
# px tensor([ 0.3499])
# result tensor([ 0.1402])
# g:tensor([ 0.6058])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5119])
# y grad tensor([ 0.4007])
# px tensor([ 0.3499])
# result tensor([ 0.1402])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5119])
# y grad tensor([ 0.4007])
# px tensor([ 0.3499])
# result tensor([ 0.1402])
# Sample: 22
# ========== simulate ==============
# pos:tensor([-0.4027]) True
# ------calling energy function------
# x tensor([ 0.5119])
# y grad tensor([ 0.4007])
# px tensor([ 0.3499])
# result tensor([ 0.1402])
# g:tensor([ 0.6058])
# grad1:tensor([ 0.6058])
# momtensor([ 0.3661])
# ------calling energy function------
# x tensor([ 0.5255])
# y grad tensor([ 0.4088])
# px tensor([ 0.3475])
# result tensor([ 0.1420])
# g:tensor([ 0.6236])
# ------calling energy function------
# x tensor([ 0.5368])
# y grad tensor([ 0.4154])
# px tensor([ 0.3454])
# result tensor([ 0.1435])
# g:tensor([ 0.6384])
# ------calling energy function------
# x tensor([ 0.5456])
# y grad tensor([ 0.4205])
# px tensor([ 0.3438])
# result tensor([ 0.1446])
# g:tensor([ 0.6499])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5456])
# y grad tensor([ 0.4205])
# px tensor([ 0.3438])
# result tensor([ 0.1446])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5456])
# y grad tensor([ 0.4205])
# px tensor([ 0.3438])
# result tensor([ 0.1446])
# Sample: 23
# ========== simulate ==============
# pos:tensor([-0.3208]) True
# ------calling energy function------
# x tensor([ 0.5456])
# y grad tensor([ 0.4205])
# px tensor([ 0.3438])
# result tensor([ 0.1446])
# g:tensor([ 0.6499])
# grad1:tensor([ 0.6499])
# momtensor([-0.6550])
# ------calling energy function------
# x tensor([ 0.5172])
# y grad tensor([ 0.4038])
# px tensor([ 0.3490])
# result tensor([ 0.1409])
# g:tensor([ 0.6127])
# ------calling energy function------
# x tensor([ 0.4877])
# y grad tensor([ 0.3859])
# px tensor([ 0.3542])
# result tensor([ 0.1367])
# g:tensor([ 0.5741])
# ------calling energy function------
# x tensor([ 0.4573])
# y grad tensor([ 0.3670])
# px tensor([ 0.3593])
# result tensor([ 0.1319])
# g:tensor([ 0.5349])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4573])
# y grad tensor([ 0.3670])
# px tensor([ 0.3593])
# result tensor([ 0.1319])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4573])
# y grad tensor([ 0.3670])
# px tensor([ 0.3593])
# result tensor([ 0.1319])
# Sample: 24
# ========== simulate ==============
# pos:tensor([-0.5450]) True
# ------calling energy function------
# x tensor([ 0.4573])
# y grad tensor([ 0.3670])
# px tensor([ 0.3593])
# result tensor([ 0.1319])
# g:tensor([ 0.5349])
# grad1:tensor([ 0.5349])
# momtensor([ 0.3123])
# ------calling energy function------
# x tensor([ 0.4679])
# y grad tensor([ 0.3737])
# px tensor([ 0.3576])
# result tensor([ 0.1336])
# g:tensor([ 0.5485])
# ------calling energy function------
# x tensor([ 0.4766])
# y grad tensor([ 0.3791])
# px tensor([ 0.3561])
# result tensor([ 0.1350])
# g:tensor([ 0.5598])
# ------calling energy function------
# x tensor([ 0.4832])
# y grad tensor([ 0.3832])
# px tensor([ 0.3550])
# result tensor([ 0.1360])
# g:tensor([ 0.5684])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4832])
# y grad tensor([ 0.3832])
# px tensor([ 0.3550])
# result tensor([ 0.1360])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4832])
# y grad tensor([ 0.3832])
# px tensor([ 0.3550])
# result tensor([ 0.1360])
# Sample: 25
# ========== simulate ==============
# pos:tensor([-0.4759]) True
# ------calling energy function------
# x tensor([ 0.4832])
# y grad tensor([ 0.3832])
# px tensor([ 0.3550])
# result tensor([ 0.1360])
# g:tensor([ 0.5684])
# grad1:tensor([ 0.5684])
# momtensor([-0.9736])
# ------calling energy function------
# x tensor([ 0.4460])
# y grad tensor([ 0.3598])
# px tensor([ 0.3612])
# result tensor([ 0.1300])
# g:tensor([ 0.5203])
# ------calling energy function------
# x tensor([ 0.4094])
# y grad tensor([ 0.3359])
# px tensor([ 0.3669])
# result tensor([ 0.1232])
# g:tensor([ 0.4734])
# ------calling energy function------
# x tensor([ 0.3737])
# y grad tensor([ 0.3118])
# px tensor([ 0.3720])
# result tensor([ 0.1160])
# g:tensor([ 0.4283])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3737])
# y grad tensor([ 0.3118])
# px tensor([ 0.3720])
# result tensor([ 0.1160])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3737])
# y grad tensor([ 0.3118])
# px tensor([ 0.3720])
# result tensor([ 0.1160])
# Sample: 26
# ========== simulate ==============
# pos:tensor([-0.7917]) True
# ------calling energy function------
# x tensor([ 0.3737])
# y grad tensor([ 0.3118])
# px tensor([ 0.3720])
# result tensor([ 0.1160])
# g:tensor([ 0.4283])
# grad1:tensor([ 0.4283])
# momtensor([ 1.5796])
# ------calling energy function------
# x tensor([ 0.4249])
# y grad tensor([ 0.3462])
# px tensor([ 0.3645])
# result tensor([ 0.1262])
# g:tensor([ 0.4933])
# ------calling energy function------
# x tensor([ 0.4798])
# y grad tensor([ 0.3811])
# px tensor([ 0.3556])
# result tensor([ 0.1355])
# g:tensor([ 0.5639])
# ------calling energy function------
# x tensor([ 0.5376])
# y grad tensor([ 0.4159])
# px tensor([ 0.3453])
# result tensor([ 0.1436])
# g:tensor([ 0.6395])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5376])
# y grad tensor([ 0.4159])
# px tensor([ 0.3453])
# result tensor([ 0.1436])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5376])
# y grad tensor([ 0.4159])
# px tensor([ 0.3453])
# result tensor([ 0.1436])
# Sample: 27
# ========== simulate ==============
# pos:tensor([-0.3397]) True
# ------calling energy function------
# x tensor([ 0.5376])
# y grad tensor([ 0.4159])
# px tensor([ 0.3453])
# result tensor([ 0.1436])
# g:tensor([ 0.6395])
# grad1:tensor([ 0.6395])
# momtensor([-1.3245])
# ------calling energy function------
# x tensor([ 0.4834])
# y grad tensor([ 0.3833])
# px tensor([ 0.3549])
# result tensor([ 0.1361])
# g:tensor([ 0.5687])
# ------calling energy function------
# x tensor([ 0.4316])
# y grad tensor([ 0.3505])
# px tensor([ 0.3635])
# result tensor([ 0.1274])
# g:tensor([ 0.5018])
# ------calling energy function------
# x tensor([ 0.3827])
# y grad tensor([ 0.3180])
# px tensor([ 0.3708])
# result tensor([ 0.1179])
# g:tensor([ 0.4397])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3827])
# y grad tensor([ 0.3180])
# px tensor([ 0.3708])
# result tensor([ 0.1179])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5376])
# y grad tensor([ 0.4159])
# px tensor([ 0.3453])
# result tensor([ 0.1436])
# Sample: 28
# ========== simulate ==============
# pos:tensor([-0.3397]) True
# ------calling energy function------
# x tensor([ 0.5376])
# y grad tensor([ 0.4159])
# px tensor([ 0.3453])
# result tensor([ 0.1436])
# g:tensor([ 0.6395])
# grad1:tensor([ 0.6395])
# momtensor([ 0.7161])
# ------calling energy function------
# x tensor([ 0.5667])
# y grad tensor([ 0.4326])
# px tensor([ 0.3398])
# result tensor([ 0.1470])
# g:tensor([ 0.6777])
# ------calling energy function------
# x tensor([ 0.5938])
# y grad tensor([ 0.4478])
# px tensor([ 0.3345])
# result tensor([ 0.1498])
# g:tensor([ 0.7137])
# ------calling energy function------
# x tensor([ 0.6186])
# y grad tensor([ 0.4613])
# px tensor([ 0.3295])
# result tensor([ 0.1520])
# g:tensor([ 0.7466])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6186])
# y grad tensor([ 0.4613])
# px tensor([ 0.3295])
# result tensor([ 0.1520])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6186])
# y grad tensor([ 0.4613])
# px tensor([ 0.3295])
# result tensor([ 0.1520])
# Sample: 29
# ========== simulate ==============
# pos:tensor([-0.1552]) True
# ------calling energy function------
# x tensor([ 0.6186])
# y grad tensor([ 0.4613])
# px tensor([ 0.3295])
# result tensor([ 0.1520])
# g:tensor([ 0.7466])
# grad1:tensor([ 0.7466])
# momtensor([-0.3017])
# ------calling energy function------
# x tensor([ 0.6031])
# y grad tensor([ 0.4529])
# px tensor([ 0.3326])
# result tensor([ 0.1506])
# g:tensor([ 0.7260])
# ------calling energy function------
# x tensor([ 0.5846])
# y grad tensor([ 0.4427])
# px tensor([ 0.3363])
# result tensor([ 0.1489])
# g:tensor([ 0.7015])
# ------calling energy function------
# x tensor([ 0.5636])
# y grad tensor([ 0.4308])
# px tensor([ 0.3404])
# result tensor([ 0.1466])
# g:tensor([ 0.6737])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5636])
# y grad tensor([ 0.4308])
# px tensor([ 0.3404])
# result tensor([ 0.1466])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5636])
# y grad tensor([ 0.4308])
# px tensor([ 0.3404])
# result tensor([ 0.1466])
# Sample: 30
# ========== simulate ==============
# pos:tensor([-0.2784]) True
# ------calling energy function------
# x tensor([ 0.5636])
# y grad tensor([ 0.4308])
# px tensor([ 0.3404])
# result tensor([ 0.1466])
# g:tensor([ 0.6737])
# grad1:tensor([ 0.6737])
# momtensor([-0.2799])
# ------calling energy function------
# x tensor([ 0.5502])
# y grad tensor([ 0.4232])
# px tensor([ 0.3429])
# result tensor([ 0.1451])
# g:tensor([ 0.6560])
# ------calling energy function------
# x tensor([ 0.5343])
# y grad tensor([ 0.4139])
# px tensor([ 0.3459])
# result tensor([ 0.1432])
# g:tensor([ 0.6351])
# ------calling energy function------
# x tensor([ 0.5163])
# y grad tensor([ 0.4032])
# px tensor([ 0.3492])
# result tensor([ 0.1408])
# g:tensor([ 0.6114])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5163])
# y grad tensor([ 0.4032])
# px tensor([ 0.3492])
# result tensor([ 0.1408])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5163])
# y grad tensor([ 0.4032])
# px tensor([ 0.3492])
# result tensor([ 0.1408])
# Sample: 31
# ========== simulate ==============
# pos:tensor([-0.3920]) True
# ------calling energy function------
# x tensor([ 0.5163])
# y grad tensor([ 0.4032])
# px tensor([ 0.3492])
# result tensor([ 0.1408])
# g:tensor([ 0.6114])
# grad1:tensor([ 0.6114])
# momtensor([ 1.1348])
# ------calling energy function------
# x tensor([ 0.5623])
# y grad tensor([ 0.4301])
# px tensor([ 0.3406])
# result tensor([ 0.1465])
# g:tensor([ 0.6719])
# ------calling energy function------
# x tensor([ 0.6082])
# y grad tensor([ 0.4557])
# px tensor([ 0.3316])
# result tensor([ 0.1511])
# g:tensor([ 0.7328])
# ------calling energy function------
# x tensor([ 0.6533])
# y grad tensor([ 0.4797])
# px tensor([ 0.3223])
# result tensor([ 0.1546])
# g:tensor([ 0.7930])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6533])
# y grad tensor([ 0.4797])
# px tensor([ 0.3223])
# result tensor([ 0.1546])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6533])
# y grad tensor([ 0.4797])
# px tensor([ 0.3223])
# result tensor([ 0.1546])
# Sample: 32
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [-8.1439]) True
# ------calling energy function------
# x tensor([ 0.6533])
# y grad tensor([ 0.4797])
# px tensor([ 0.3223])
# result tensor([ 0.1546])
# g:tensor([ 0.7930])
# grad1:tensor([ 0.7930])
# momtensor([ 0.3414])
# ------calling energy function------
# x tensor([ 0.6678])
# y grad tensor([ 0.4872])
# px tensor([ 0.3192])
# result tensor([ 0.1555])
# g:tensor([ 0.8125])
# ------calling energy function------
# x tensor([ 0.6786])
# y grad tensor([ 0.4927])
# px tensor([ 0.3169])
# result tensor([ 0.1561])
# g:tensor([ 0.8271])
# ------calling energy function------
# x tensor([ 0.6855])
# y grad tensor([ 0.4961])
# px tensor([ 0.3154])
# result tensor([ 0.1565])
# g:tensor([ 0.8362])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6855])
# y grad tensor([ 0.4961])
# px tensor([ 0.3154])
# result tensor([ 0.1565])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6855])
# y grad tensor([ 0.4961])
# px tensor([ 0.3154])
# result tensor([ 0.1565])
# Sample: 33
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [-1.5448]) True
# ------calling energy function------
# x tensor([ 0.6855])
# y grad tensor([ 0.4961])
# px tensor([ 0.3154])
# result tensor([ 0.1565])
# g:tensor([ 0.8362])
# grad1:tensor([ 0.8362])
# momtensor([ 0.4615])
# ------calling energy function------
# x tensor([ 0.7065])
# y grad tensor([ 0.5066])
# px tensor([ 0.3108])
# result tensor([ 0.1575])
# g:tensor([ 0.8646])
# ------calling energy function------
# x tensor([ 0.7235])
# y grad tensor([ 0.5150])
# px tensor([ 0.3071])
# result tensor([ 0.1581])
# g:tensor([ 0.8875])
# ------calling energy function------
# x tensor([ 0.7362])
# y grad tensor([ 0.5211])
# px tensor([ 0.3042])
# result tensor([ 0.1585])
# g:tensor([ 0.9047])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7362])
# y grad tensor([ 0.5211])
# px tensor([ 0.3042])
# result tensor([ 0.1585])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7362])
# y grad tensor([ 0.5211])
# px tensor([ 0.3042])
# result tensor([ 0.1585])
# Sample: 34
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 8.4306]) True
# ------calling energy function------
# x tensor([ 0.7362])
# y grad tensor([ 0.5211])
# px tensor([ 0.3042])
# result tensor([ 0.1585])
# g:tensor([ 0.9047])
# grad1:tensor([ 0.9047])
# momtensor([ 1.0424])
# ------calling energy function------
# x tensor([ 0.7894])
# y grad tensor([ 0.5459])
# px tensor([ 0.2921])
# result tensor([ 0.1595])
# g:tensor([ 0.9768])
# ------calling energy function------
# x tensor([ 0.8395])
# y grad tensor([ 0.5681])
# px tensor([ 0.2805])
# result tensor([ 0.1593])
# g:tensor([ 1.0449])
# ------calling energy function------
# x tensor([ 0.8854])
# y grad tensor([ 0.5875])
# px tensor([ 0.2696])
# result tensor([ 0.1584])
# g:tensor([ 1.1076])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8854])
# y grad tensor([ 0.5875])
# px tensor([ 0.2696])
# result tensor([ 0.1584])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8854])
# y grad tensor([ 0.5875])
# px tensor([ 0.2696])
# result tensor([ 0.1584])
# Sample: 35
# ========== simulate ==============
# pos:tensor([ 0.3535]) True
# ------calling energy function------
# x tensor([ 0.8854])
# y grad tensor([ 0.5875])
# px tensor([ 0.2696])
# result tensor([ 0.1584])
# g:tensor([ 1.1076])
# grad1:tensor([ 1.1076])
# momtensor([-0.7073])
# ------calling energy function------
# x tensor([ 0.8413])
# y grad tensor([ 0.5689])
# px tensor([ 0.2800])
# result tensor([ 0.1593])
# g:tensor([ 1.0475])
# ------calling energy function------
# x tensor([ 0.7929])
# y grad tensor([ 0.5475])
# px tensor([ 0.2913])
# result tensor([ 0.1595])
# g:tensor([ 0.9816])
# ------calling energy function------
# x tensor([ 0.7412])
# y grad tensor([ 0.5235])
# px tensor([ 0.3031])
# result tensor([ 0.1587])
# g:tensor([ 0.9114])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7412])
# y grad tensor([ 0.5235])
# px tensor([ 0.3031])
# result tensor([ 0.1587])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7412])
# y grad tensor([ 0.5235])
# px tensor([ 0.3031])
# result tensor([ 0.1587])
# Sample: 36
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 9.3899]) True
# ------calling energy function------
# x tensor([ 0.7412])
# y grad tensor([ 0.5235])
# px tensor([ 0.3031])
# result tensor([ 0.1587])
# g:tensor([ 0.9114])
# grad1:tensor([ 0.9114])
# momtensor([ 0.8772])
# ------calling energy function------
# x tensor([ 0.7856])
# y grad tensor([ 0.5441])
# px tensor([ 0.2930])
# result tensor([ 0.1594])
# g:tensor([ 0.9716])
# ------calling energy function------
# x tensor([ 0.8262])
# y grad tensor([ 0.5623])
# px tensor([ 0.2836])
# result tensor([ 0.1595])
# g:tensor([ 1.0269])
# ------calling energy function------
# x tensor([ 0.8622])
# y grad tensor([ 0.5778])
# px tensor([ 0.2751])
# result tensor([ 0.1589])
# g:tensor([ 1.0760])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8622])
# y grad tensor([ 0.5778])
# px tensor([ 0.2751])
# result tensor([ 0.1589])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8622])
# y grad tensor([ 0.5778])
# px tensor([ 0.2751])
# result tensor([ 0.1589])
# Sample: 37
# ========== simulate ==============
# pos:tensor([ 0.3137]) True
# ------calling energy function------
# x tensor([ 0.8622])
# y grad tensor([ 0.5778])
# px tensor([ 0.2751])
# result tensor([ 0.1589])
# g:tensor([ 1.0760])
# grad1:tensor([ 1.0760])
# momtensor([-0.8901])
# ------calling energy function------
# x tensor([ 0.8088])
# y grad tensor([ 0.5546])
# px tensor([ 0.2876])
# result tensor([ 0.1595])
# g:tensor([ 1.0032])
# ------calling energy function------
# x tensor([ 0.7522])
# y grad tensor([ 0.5287])
# px tensor([ 0.3006])
# result tensor([ 0.1589])
# g:tensor([ 0.9264])
# ------calling energy function------
# x tensor([ 0.6937])
# y grad tensor([ 0.5003])
# px tensor([ 0.3136])
# result tensor([ 0.1569])
# g:tensor([ 0.8474])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6937])
# y grad tensor([ 0.5003])
# px tensor([ 0.3136])
# result tensor([ 0.1569])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8622])
# y grad tensor([ 0.5778])
# px tensor([ 0.2751])
# result tensor([ 0.1589])
# Sample: 38
# ========== simulate ==============
# pos:tensor([ 0.3137]) True
# ------calling energy function------
# x tensor([ 0.8622])
# y grad tensor([ 0.5778])
# px tensor([ 0.2751])
# result tensor([ 0.1589])
# g:tensor([ 1.0760])
# grad1:tensor([ 1.0760])
# momtensor([ 0.3462])
# ------calling energy function------
# x tensor([ 0.8792])
# y grad tensor([ 0.5849])
# px tensor([ 0.2710])
# result tensor([ 0.1585])
# g:tensor([ 1.0992])
# ------calling energy function------
# x tensor([ 0.8899])
# y grad tensor([ 0.5893])
# px tensor([ 0.2685])
# result tensor([ 0.1582])
# g:tensor([ 1.1138])
# ------calling energy function------
# x tensor([ 0.8941])
# y grad tensor([ 0.5910])
# px tensor([ 0.2675])
# result tensor([ 0.1581])
# g:tensor([ 1.1195])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8941])
# y grad tensor([ 0.5910])
# px tensor([ 0.2675])
# result tensor([ 0.1581])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8941])
# y grad tensor([ 0.5910])
# px tensor([ 0.2675])
# result tensor([ 0.1581])
# Sample: 39
# ========== simulate ==============
# pos:tensor([ 0.3683]) True
# ------calling energy function------
# x tensor([ 0.8941])
# y grad tensor([ 0.5910])
# px tensor([ 0.2675])
# result tensor([ 0.1581])
# g:tensor([ 1.1195])
# grad1:tensor([ 1.1195])
# momtensor([-0.8434])
# ------calling energy function------
# x tensor([ 0.8420])
# y grad tensor([ 0.5691])
# px tensor([ 0.2799])
# result tensor([ 0.1593])
# g:tensor([ 1.0483])
# ------calling energy function------
# x tensor([ 0.7861])
# y grad tensor([ 0.5444])
# px tensor([ 0.2929])
# result tensor([ 0.1595])
# g:tensor([ 0.9723])
# ------calling energy function------
# x tensor([ 0.7276])
# y grad tensor([ 0.5169])
# px tensor([ 0.3062])
# result tensor([ 0.1583])
# g:tensor([ 0.8931])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7276])
# y grad tensor([ 0.5169])
# px tensor([ 0.3062])
# result tensor([ 0.1583])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7276])
# y grad tensor([ 0.5169])
# px tensor([ 0.3062])
# result tensor([ 0.1583])
# Sample: 40
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 6.7773]) True
# ------calling energy function------
# x tensor([ 0.7276])
# y grad tensor([ 0.5169])
# px tensor([ 0.3062])
# result tensor([ 0.1583])
# g:tensor([ 0.8931])
# grad1:tensor([ 0.8931])
# momtensor([ 0.6162])
# ------calling energy function------
# x tensor([ 0.7576])
# y grad tensor([ 0.5312])
# px tensor([ 0.2994])
# result tensor([ 0.1591])
# g:tensor([ 0.9336])
# ------calling energy function------
# x tensor([ 0.7832])
# y grad tensor([ 0.5431])
# px tensor([ 0.2936])
# result tensor([ 0.1594])
# g:tensor([ 0.9684])
# ------calling energy function------
# x tensor([ 0.8041])
# y grad tensor([ 0.5525])
# px tensor([ 0.2887])
# result tensor([ 0.1595])
# g:tensor([ 0.9968])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8041])
# y grad tensor([ 0.5525])
# px tensor([ 0.2887])
# result tensor([ 0.1595])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8041])
# y grad tensor([ 0.5525])
# px tensor([ 0.2887])
# result tensor([ 0.1595])
# Sample: 41
# ========== simulate ==============
# pos:tensor([ 0.2109]) True
# ------calling energy function------
# x tensor([ 0.8041])
# y grad tensor([ 0.5525])
# px tensor([ 0.2887])
# result tensor([ 0.1595])
# g:tensor([ 0.9968])
# grad1:tensor([ 0.9968])
# momtensor([ 1.0535])
# ------calling energy function------
# x tensor([ 0.8608])
# y grad tensor([ 0.5772])
# px tensor([ 0.2754])
# result tensor([ 0.1590])
# g:tensor([ 1.0741])
# ------calling energy function------
# x tensor([ 0.9135])
# y grad tensor([ 0.5989])
# px tensor([ 0.2628])
# result tensor([ 0.1574])
# g:tensor([ 1.1460])
# ------calling energy function------
# x tensor([ 0.9611])
# y grad tensor([ 0.6175])
# px tensor([ 0.2514])
# result tensor([ 0.1552])
# g:tensor([ 1.2110])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.9611])
# y grad tensor([ 0.6175])
# px tensor([ 0.2514])
# result tensor([ 0.1552])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.9611])
# y grad tensor([ 0.6175])
# px tensor([ 0.2514])
# result tensor([ 0.1552])
# Sample: 42
# ========== simulate ==============
# pos:tensor([ 0.4790]) True
# ------calling energy function------
# x tensor([ 0.9611])
# y grad tensor([ 0.6175])
# px tensor([ 0.2514])
# result tensor([ 0.1552])
# g:tensor([ 1.2110])
# grad1:tensor([ 1.2110])
# momtensor([-0.9918])
# ------calling energy function------
# x tensor([ 0.8974])
# y grad tensor([ 0.5924])
# px tensor([ 0.2667])
# result tensor([ 0.1580])
# g:tensor([ 1.1240])
# ------calling energy function------
# x tensor([ 0.8301])
# y grad tensor([ 0.5640])
# px tensor([ 0.2827])
# result tensor([ 0.1594])
# g:tensor([ 1.0321])
# ------calling energy function------
# x tensor([ 0.7605])
# y grad tensor([ 0.5326])
# px tensor([ 0.2987])
# result tensor([ 0.1591])
# g:tensor([ 0.9376])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7605])
# y grad tensor([ 0.5326])
# px tensor([ 0.2987])
# result tensor([ 0.1591])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.9611])
# y grad tensor([ 0.6175])
# px tensor([ 0.2514])
# result tensor([ 0.1552])
# Sample: 43
# ========== simulate ==============
# pos:tensor([ 0.4790]) True
# ------calling energy function------
# x tensor([ 0.9611])
# y grad tensor([ 0.6175])
# px tensor([ 0.2514])
# result tensor([ 0.1552])
# g:tensor([ 1.2110])
# grad1:tensor([ 1.2110])
# momtensor([ 1.3474])
# ------calling energy function------
# x tensor([ 1.0425])
# y grad tensor([ 0.6474])
# px tensor([ 0.2317])
# result tensor([ 0.1500])
# g:tensor([ 1.3223])
# ------calling energy function------
# x tensor([ 1.1187])
# y grad tensor([ 0.6733])
# px tensor([ 0.2134])
# result tensor([ 0.1437])
# g:tensor([ 1.4266])
# ------calling energy function------
# x tensor([ 1.1880])
# y grad tensor([ 0.6952])
# px tensor([ 0.1970])
# result tensor([ 0.1369])
# g:tensor([ 1.5210])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.1880])
# y grad tensor([ 0.6952])
# px tensor([ 0.1970])
# result tensor([ 0.1369])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.1880])
# y grad tensor([ 0.6952])
# px tensor([ 0.1970])
# result tensor([ 0.1369])
# Sample: 44
# ========== simulate ==============
# pos:tensor([ 0.8244]) True
# ------calling energy function------
# x tensor([ 1.1880])
# y grad tensor([ 0.6952])
# px tensor([ 0.1970])
# result tensor([ 0.1369])
# g:tensor([ 1.5210])
# grad1:tensor([ 1.5210])
# momtensor([ 1.2356])
# ------calling energy function------
# x tensor([ 1.2700])
# y grad tensor([ 0.7192])
# px tensor([ 0.1781])
# result tensor([ 0.1281])
# g:tensor([ 1.6325])
# ------calling energy function------
# x tensor([ 1.3426])
# y grad tensor([ 0.7388])
# px tensor([ 0.1620])
# result tensor([ 0.1197])
# g:tensor([ 1.7308])
# ------calling energy function------
# x tensor([ 1.4041])
# y grad tensor([ 0.7544])
# px tensor([ 0.1489])
# result tensor([ 0.1123])
# g:tensor([ 1.8137])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.4041])
# y grad tensor([ 0.7544])
# px tensor([ 0.1489])
# result tensor([ 0.1123])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.4041])
# y grad tensor([ 0.7544])
# px tensor([ 0.1489])
# result tensor([ 0.1123])
# Sample: 45
# ========== simulate ==============
# pos:tensor([ 1.1223]) True
# ------calling energy function------
# x tensor([ 1.4041])
# y grad tensor([ 0.7544])
# px tensor([ 0.1489])
# result tensor([ 0.1123])
# g:tensor([ 1.8137])
# grad1:tensor([ 1.8137])
# momtensor(1.00000e-02 *
#        [-9.7531])
# ------calling energy function------
# x tensor([ 1.3899])
# y grad tensor([ 0.7509])
# px tensor([ 0.1518])
# result tensor([ 0.1140])
# g:tensor([ 1.7946])
# ------calling energy function------
# x tensor([ 1.3625])
# y grad tensor([ 0.7440])
# px tensor([ 0.1577])
# result tensor([ 0.1173])
# g:tensor([ 1.7576])
# ------calling energy function------
# x tensor([ 1.3223])
# y grad tensor([ 0.7335])
# px tensor([ 0.1664])
# result tensor([ 0.1221])
# g:tensor([ 1.7034])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.3223])
# y grad tensor([ 0.7335])
# px tensor([ 0.1664])
# result tensor([ 0.1221])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.3223])
# y grad tensor([ 0.7335])
# px tensor([ 0.1664])
# result tensor([ 0.1221])
# Sample: 46
# ========== simulate ==============
# pos:tensor([ 1.0124]) True
# ------calling energy function------
# x tensor([ 1.3223])
# y grad tensor([ 0.7335])
# px tensor([ 0.1664])
# result tensor([ 0.1221])
# g:tensor([ 1.7034])
# grad1:tensor([ 1.7034])
# momtensor([-0.6740])
# ------calling energy function------
# x tensor([ 1.2672])
# y grad tensor([ 0.7184])
# px tensor([ 0.1787])
# result tensor([ 0.1284])
# g:tensor([ 1.6287])
# ------calling energy function------
# x tensor([ 1.2018])
# y grad tensor([ 0.6994])
# px tensor([ 0.1938])
# result tensor([ 0.1355])
# g:tensor([ 1.5399])
# ------calling energy function------
# x tensor([ 1.1278])
# y grad tensor([ 0.6763])
# px tensor([ 0.2112])
# result tensor([ 0.1428])
# g:tensor([ 1.4390])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.1278])
# y grad tensor([ 0.6763])
# px tensor([ 0.2112])
# result tensor([ 0.1428])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.1278])
# y grad tensor([ 0.6763])
# px tensor([ 0.2112])
# result tensor([ 0.1428])
# Sample: 47
# ========== simulate ==============
# pos:tensor([ 0.7366]) True
# ------calling energy function------
# x tensor([ 1.1278])
# y grad tensor([ 0.6763])
# px tensor([ 0.2112])
# result tensor([ 0.1428])
# g:tensor([ 1.4390])
# grad1:tensor([ 1.4390])
# momtensor([ 0.1994])
# ------calling energy function------
# x tensor([ 1.1365])
# y grad tensor([ 0.6790])
# px tensor([ 0.2091])
# result tensor([ 0.1420])
# g:tensor([ 1.4508])
# ------calling energy function------
# x tensor([ 1.1353])
# y grad tensor([ 0.6787])
# px tensor([ 0.2094])
# result tensor([ 0.1421])
# g:tensor([ 1.4491])
# ------calling energy function------
# x tensor([ 1.1243])
# y grad tensor([ 0.6751])
# px tensor([ 0.2121])
# result tensor([ 0.1432])
# g:tensor([ 1.4341])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.1243])
# y grad tensor([ 0.6751])
# px tensor([ 0.2121])
# result tensor([ 0.1432])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.1243])
# y grad tensor([ 0.6751])
# px tensor([ 0.2121])
# result tensor([ 0.1432])
# Sample: 48
# ========== simulate ==============
# pos:tensor([ 0.7314]) True
# ------calling energy function------
# x tensor([ 1.1243])
# y grad tensor([ 0.6751])
# px tensor([ 0.2121])
# result tensor([ 0.1432])
# g:tensor([ 1.4341])
# grad1:tensor([ 1.4341])
# momtensor([ 0.5982])
# ------calling energy function------
# x tensor([ 1.1601])
# y grad tensor([ 0.6865])
# px tensor([ 0.2035])
# result tensor([ 0.1397])
# g:tensor([ 1.4830])
# ------calling energy function------
# x tensor([ 1.1862])
# y grad tensor([ 0.6946])
# px tensor([ 0.1974])
# result tensor([ 0.1371])
# g:tensor([ 1.5186])
# ------calling energy function------
# x tensor([ 1.2020])
# y grad tensor([ 0.6994])
# px tensor([ 0.1937])
# result tensor([ 0.1355])
# g:tensor([ 1.5401])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.2020])
# y grad tensor([ 0.6994])
# px tensor([ 0.1937])
# result tensor([ 0.1355])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.2020])
# y grad tensor([ 0.6994])
# px tensor([ 0.1937])
# result tensor([ 0.1355])
# Sample: 49
# ========== simulate ==============
# pos:tensor([ 0.8445]) True
# ------calling energy function------
# x tensor([ 1.2020])
# y grad tensor([ 0.6994])
# px tensor([ 0.1937])
# result tensor([ 0.1355])
# g:tensor([ 1.5401])
# grad1:tensor([ 1.5401])
# momtensor(1.00000e-02 *
#        [-3.7564])
# ------calling energy function------
# x tensor([ 1.1940])
# y grad tensor([ 0.6970])
# px tensor([ 0.1956])
# result tensor([ 0.1363])
# g:tensor([ 1.5292])
# ------calling energy function------
# x tensor([ 1.1754])
# y grad tensor([ 0.6913])
# px tensor([ 0.1999])
# result tensor([ 0.1382])
# g:tensor([ 1.5039])
# ------calling energy function------
# x tensor([ 1.1467])
# y grad tensor([ 0.6823])
# px tensor([ 0.2067])
# result tensor([ 0.1410])
# g:tensor([ 1.4648])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.1467])
# y grad tensor([ 0.6823])
# px tensor([ 0.2067])
# result tensor([ 0.1410])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.1467])
# y grad tensor([ 0.6823])
# px tensor([ 0.2067])
# result tensor([ 0.1410])
# Sample: 50
# ...
# ========== 2nd hamiltonian ==============
# x tensor([ 1.3445])
# y grad tensor([ 0.7393])
# px tensor([ 0.1616])
# result tensor([ 0.1195])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.3445])
# y grad tensor([ 0.7393])
# px tensor([ 0.1616])
# result tensor([ 0.1195])
# Sample: 784
# ========== simulate ==============
# pos:tensor([ 1.0425]) True
# ------calling energy function------
# x tensor([ 1.3445])
# y grad tensor([ 0.7393])
# px tensor([ 0.1616])
# result tensor([ 0.1195])
# g:tensor([ 1.7334])
# grad1:tensor([ 1.7334])
# momtensor([-0.8143])
# ------calling energy function------
# x tensor([ 1.2787])
# y grad tensor([ 0.7216])
# px tensor([ 0.1761])
# result tensor([ 0.1271])
# g:tensor([ 1.6443])
# ------calling energy function------
# x tensor([ 1.2030])
# y grad tensor([ 0.6997])
# px tensor([ 0.1935])
# result tensor([ 0.1354])
# g:tensor([ 1.5414])
# ------calling energy function------
# x tensor([ 1.1192])
# y grad tensor([ 0.6735])
# px tensor([ 0.2132])
# result tensor([ 0.1436])
# g:tensor([ 1.4273])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.1192])
# y grad tensor([ 0.6735])
# px tensor([ 0.2132])
# result tensor([ 0.1436])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.1192])
# y grad tensor([ 0.6735])
# px tensor([ 0.2132])
# result tensor([ 0.1436])
# Sample: 785
# ========== simulate ==============
# pos:tensor([ 0.7239]) True
# ------calling energy function------
# x tensor([ 1.1192])
# y grad tensor([ 0.6735])
# px tensor([ 0.2132])
# result tensor([ 0.1436])
# g:tensor([ 1.4273])
# grad1:tensor([ 1.4273])
# momtensor([-1.2340])
# ------calling energy function------
# x tensor([ 1.0332])
# y grad tensor([ 0.6441])
# px tensor([ 0.2339])
# result tensor([ 0.1507])
# g:tensor([ 1.3097])
# ------calling energy function------
# x tensor([ 0.9431])
# y grad tensor([ 0.6106])
# px tensor([ 0.2557])
# result tensor([ 0.1561])
# g:tensor([ 1.1864])
# ------calling energy function------
# x tensor([ 0.8511])
# y grad tensor([ 0.5730])
# px tensor([ 0.2777])
# result tensor([ 0.1592])
# g:tensor([ 1.0607])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8511])
# y grad tensor([ 0.5730])
# px tensor([ 0.2777])
# result tensor([ 0.1592])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8511])
# y grad tensor([ 0.5730])
# px tensor([ 0.2777])
# result tensor([ 0.1592])
# Sample: 786
# ========== simulate ==============
# pos:tensor([ 0.2943]) True
# ------calling energy function------
# x tensor([ 0.8511])
# y grad tensor([ 0.5730])
# px tensor([ 0.2777])
# result tensor([ 0.1592])
# g:tensor([ 1.0607])
# grad1:tensor([ 1.0607])
# momtensor(1.00000e-02 *
#        [-3.0625])
# ------calling energy function------
# x tensor([ 0.8463])
# y grad tensor([ 0.5710])
# px tensor([ 0.2789])
# result tensor([ 0.1592])
# g:tensor([ 1.0542])
# ------calling energy function------
# x tensor([ 0.8355])
# y grad tensor([ 0.5664])
# px tensor([ 0.2814])
# result tensor([ 0.1594])
# g:tensor([ 1.0396])
# ------calling energy function------
# x tensor([ 0.8190])
# y grad tensor([ 0.5591])
# px tensor([ 0.2853])
# result tensor([ 0.1595])
# g:tensor([ 1.0171])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8190])
# y grad tensor([ 0.5591])
# px tensor([ 0.2853])
# result tensor([ 0.1595])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8190])
# y grad tensor([ 0.5591])
# px tensor([ 0.2853])
# result tensor([ 0.1595])
# Sample: 787
# ========== simulate ==============
# pos:tensor([ 0.2377]) True
# ------calling energy function------
# x tensor([ 0.8190])
# y grad tensor([ 0.5591])
# px tensor([ 0.2853])
# result tensor([ 0.1595])
# g:tensor([ 1.0171])
# grad1:tensor([ 1.0171])
# momtensor(1.00000e-02 *
#        [ 2.2456])
# ------calling energy function------
# x tensor([ 0.8175])
# y grad tensor([ 0.5584])
# px tensor([ 0.2856])
# result tensor([ 0.1595])
# g:tensor([ 1.0149])
# ------calling energy function------
# x tensor([ 0.8102])
# y grad tensor([ 0.5552])
# px tensor([ 0.2873])
# result tensor([ 0.1595])
# g:tensor([ 1.0051])
# ------calling energy function------
# x tensor([ 0.7975])
# y grad tensor([ 0.5495])
# px tensor([ 0.2903])
# result tensor([ 0.1595])
# g:tensor([ 0.9878])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7975])
# y grad tensor([ 0.5495])
# px tensor([ 0.2903])
# result tensor([ 0.1595])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7975])
# y grad tensor([ 0.5495])
# px tensor([ 0.2903])
# result tensor([ 0.1595])
# Sample: 788
# ========== simulate ==============
# pos:tensor([ 0.1988]) True
# ------calling energy function------
# x tensor([ 0.7975])
# y grad tensor([ 0.5495])
# px tensor([ 0.2903])
# result tensor([ 0.1595])
# g:tensor([ 0.9878])
# grad1:tensor([ 0.9878])
# momtensor([-1.1187])
# ------calling energy function------
# x tensor([ 0.7350])
# y grad tensor([ 0.5205])
# px tensor([ 0.3045])
# result tensor([ 0.1585])
# g:tensor([ 0.9031])
# ------calling energy function------
# x tensor([ 0.6715])
# y grad tensor([ 0.4890])
# px tensor([ 0.3184])
# result tensor([ 0.1557])
# g:tensor([ 0.8174])
# ------calling energy function------
# x tensor([ 0.6082])
# y grad tensor([ 0.4557])
# px tensor([ 0.3316])
# result tensor([ 0.1511])
# g:tensor([ 0.7328])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6082])
# y grad tensor([ 0.4557])
# px tensor([ 0.3316])
# result tensor([ 0.1511])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7975])
# y grad tensor([ 0.5495])
# px tensor([ 0.2903])
# result tensor([ 0.1595])
# Sample: 789
# ========== simulate ==============
# pos:tensor([ 0.1988]) True
# ------calling energy function------
# x tensor([ 0.7975])
# y grad tensor([ 0.5495])
# px tensor([ 0.2903])
# result tensor([ 0.1595])
# g:tensor([ 0.9878])
# grad1:tensor([ 0.9878])
# momtensor([-0.5369])
# ------calling energy function------
# x tensor([ 0.7657])
# y grad tensor([ 0.5350])
# px tensor([ 0.2976])
# result tensor([ 0.1592])
# g:tensor([ 0.9446])
# ------calling energy function------
# x tensor([ 0.7299])
# y grad tensor([ 0.5180])
# px tensor([ 0.3057])
# result tensor([ 0.1583])
# g:tensor([ 0.8961])
# ------calling energy function------
# x tensor([ 0.6907])
# y grad tensor([ 0.4988])
# px tensor([ 0.3143])
# result tensor([ 0.1568])
# g:tensor([ 0.8433])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6907])
# y grad tensor([ 0.4988])
# px tensor([ 0.3143])
# result tensor([ 0.1568])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6907])
# y grad tensor([ 0.4988])
# px tensor([ 0.3143])
# result tensor([ 0.1568])
# Sample: 790
# ========== simulate ==============
# pos:tensor(1.00000e-03 *
#        [-4.9291]) True
# ------calling energy function------
# x tensor([ 0.6907])
# y grad tensor([ 0.4988])
# px tensor([ 0.3143])
# result tensor([ 0.1568])
# g:tensor([ 0.8433])
# grad1:tensor([ 0.8433])
# momtensor(1.00000e-02 *
#        [ 3.1093])
# ------calling energy function------
# x tensor([ 0.6901])
# y grad tensor([ 0.4985])
# px tensor([ 0.3144])
# result tensor([ 0.1567])
# g:tensor([ 0.8425])
# ------calling energy function------
# x tensor([ 0.6854])
# y grad tensor([ 0.4961])
# px tensor([ 0.3154])
# result tensor([ 0.1565])
# g:tensor([ 0.8361])
# ------calling energy function------
# x tensor([ 0.6766])
# y grad tensor([ 0.4916])
# px tensor([ 0.3173])
# result tensor([ 0.1560])
# g:tensor([ 0.8243])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6766])
# y grad tensor([ 0.4916])
# px tensor([ 0.3173])
# result tensor([ 0.1560])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6766])
# y grad tensor([ 0.4916])
# px tensor([ 0.3173])
# result tensor([ 0.1560])
# Sample: 791
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [-3.3462]) True
# ------calling energy function------
# x tensor([ 0.6766])
# y grad tensor([ 0.4916])
# px tensor([ 0.3173])
# result tensor([ 0.1560])
# g:tensor([ 0.8243])
# grad1:tensor([ 0.8243])
# momtensor([ 1.1327])
# ------calling energy function------
# x tensor([ 0.7317])
# y grad tensor([ 0.5189])
# px tensor([ 0.3052])
# result tensor([ 0.1584])
# g:tensor([ 0.8986])
# ------calling energy function------
# x tensor([ 0.7849])
# y grad tensor([ 0.5439])
# px tensor([ 0.2932])
# result tensor([ 0.1594])
# g:tensor([ 0.9707])
# ------calling energy function------
# x tensor([ 0.8351])
# y grad tensor([ 0.5662])
# px tensor([ 0.2815])
# result tensor([ 0.1594])
# g:tensor([ 1.0390])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8351])
# y grad tensor([ 0.5662])
# px tensor([ 0.2815])
# result tensor([ 0.1594])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8351])
# y grad tensor([ 0.5662])
# px tensor([ 0.2815])
# result tensor([ 0.1594])
# Sample: 792
# ========== simulate ==============
# pos:tensor([ 0.2663]) True
# ------calling energy function------
# x tensor([ 0.8351])
# y grad tensor([ 0.5662])
# px tensor([ 0.2815])
# result tensor([ 0.1594])
# g:tensor([ 1.0390])
# grad1:tensor([ 1.0390])
# momtensor([-0.6655])
# ------calling energy function------
# x tensor([ 0.7952])
# y grad tensor([ 0.5485])
# px tensor([ 0.2908])
# result tensor([ 0.1595])
# g:tensor([ 0.9846])
# ------calling energy function------
# x tensor([ 0.7512])
# y grad tensor([ 0.5282])
# px tensor([ 0.3009])
# result tensor([ 0.1589])
# g:tensor([ 0.9250])
# ------calling energy function------
# x tensor([ 0.7043])
# y grad tensor([ 0.5055])
# px tensor([ 0.3113])
# result tensor([ 0.1574])
# g:tensor([ 0.8616])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7043])
# y grad tensor([ 0.5055])
# px tensor([ 0.3113])
# result tensor([ 0.1574])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7043])
# y grad tensor([ 0.5055])
# px tensor([ 0.3113])
# result tensor([ 0.1574])
# Sample: 793
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 2.2149]) True
# ------calling energy function------
# x tensor([ 0.7043])
# y grad tensor([ 0.5055])
# px tensor([ 0.3113])
# result tensor([ 0.1574])
# g:tensor([ 0.8616])
# grad1:tensor([ 0.8616])
# momtensor([-0.7712])
# ------calling energy function------
# x tensor([ 0.6639])
# y grad tensor([ 0.4852])
# px tensor([ 0.3200])
# result tensor([ 0.1553])
# g:tensor([ 0.8073])
# ------calling energy function------
# x tensor([ 0.6215])
# y grad tensor([ 0.4629])
# px tensor([ 0.3289])
# result tensor([ 0.1522])
# g:tensor([ 0.7506])
# ------calling energy function------
# x tensor([ 0.5778])
# y grad tensor([ 0.4389])
# px tensor([ 0.3376])
# result tensor([ 0.1482])
# g:tensor([ 0.6924])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5778])
# y grad tensor([ 0.4389])
# px tensor([ 0.3376])
# result tensor([ 0.1482])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7043])
# y grad tensor([ 0.5055])
# px tensor([ 0.3113])
# result tensor([ 0.1574])
# Sample: 794
# ========== simulate ==============
# pos:tensor(1.00000e-02 *
#        [ 2.2149]) True
# ------calling energy function------
# x tensor([ 0.7043])
# y grad tensor([ 0.5055])
# px tensor([ 0.3113])
# result tensor([ 0.1574])
# g:tensor([ 0.8616])
# grad1:tensor([ 0.8616])
# momtensor([ 0.4487])
# ------calling energy function------
# x tensor([ 0.7250])
# y grad tensor([ 0.5157])
# px tensor([ 0.3067])
# result tensor([ 0.1582])
# g:tensor([ 0.8895])
# ------calling energy function------
# x tensor([ 0.7415])
# y grad tensor([ 0.5236])
# px tensor([ 0.3031])
# result tensor([ 0.1587])
# g:tensor([ 0.9118])
# ------calling energy function------
# x tensor([ 0.7533])
# y grad tensor([ 0.5292])
# px tensor([ 0.3004])
# result tensor([ 0.1590])
# g:tensor([ 0.9279])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7533])
# y grad tensor([ 0.5292])
# px tensor([ 0.3004])
# result tensor([ 0.1590])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7533])
# y grad tensor([ 0.5292])
# px tensor([ 0.3004])
# result tensor([ 0.1590])
# Sample: 795
# ========== simulate ==============
# pos:tensor([ 0.1169]) True
# ------calling energy function------
# x tensor([ 0.7533])
# y grad tensor([ 0.5292])
# px tensor([ 0.3004])
# result tensor([ 0.1590])
# g:tensor([ 0.9279])
# grad1:tensor([ 0.9279])
# momtensor([ 0.6121])
# ------calling energy function------
# x tensor([ 0.7837])
# y grad tensor([ 0.5433])
# px tensor([ 0.2935])
# result tensor([ 0.1594])
# g:tensor([ 0.9690])
# ------calling energy function------
# x tensor([ 0.8094])
# y grad tensor([ 0.5549])
# px tensor([ 0.2875])
# result tensor([ 0.1595])
# g:tensor([ 1.0040])
# ------calling energy function------
# x tensor([ 0.8300])
# y grad tensor([ 0.5640])
# px tensor([ 0.2827])
# result tensor([ 0.1594])
# g:tensor([ 1.0320])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8300])
# y grad tensor([ 0.5640])
# px tensor([ 0.2827])
# result tensor([ 0.1594])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8300])
# y grad tensor([ 0.5640])
# px tensor([ 0.2827])
# result tensor([ 0.1594])
# Sample: 796
# ========== simulate ==============
# pos:tensor([ 0.2572]) True
# ------calling energy function------
# x tensor([ 0.8300])
# y grad tensor([ 0.5640])
# px tensor([ 0.2827])
# result tensor([ 0.1594])
# g:tensor([ 1.0320])
# grad1:tensor([ 1.0320])
# momtensor([ 0.6686])
# ------calling energy function------
# x tensor([ 0.8653])
# y grad tensor([ 0.5791])
# px tensor([ 0.2744])
# result tensor([ 0.1589])
# g:tensor([ 1.0801])
# ------calling energy function------
# x tensor([ 0.8951])
# y grad tensor([ 0.5914])
# px tensor([ 0.2673])
# result tensor([ 0.1581])
# g:tensor([ 1.1208])
# ------calling energy function------
# x tensor([ 0.9187])
# y grad tensor([ 0.6010])
# px tensor([ 0.2616])
# result tensor([ 0.1572])
# g:tensor([ 1.1531])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.9187])
# y grad tensor([ 0.6010])
# px tensor([ 0.2616])
# result tensor([ 0.1572])
# ========== 3rd hamiltonian ==============
# x tensor([ 0.9187])
# y grad tensor([ 0.6010])
# px tensor([ 0.2616])
# result tensor([ 0.1572])
# Sample: 797
# ========== simulate ==============
# pos:tensor([ 0.4095]) True
# ------calling energy function------
# x tensor([ 0.9187])
# y grad tensor([ 0.6010])
# px tensor([ 0.2616])
# result tensor([ 0.1572])
# g:tensor([ 1.1531])
# grad1:tensor([ 1.1531])
# momtensor([ 1.0713])
# ------calling energy function------
# x tensor([ 0.9809])
# y grad tensor([ 0.6250])
# px tensor([ 0.2466])
# result tensor([ 0.1541])
# g:tensor([ 1.2381])
# ------calling energy function------
# x tensor([ 1.0374])
# y grad tensor([ 0.6456])
# px tensor([ 0.2329])
# result tensor([ 0.1504])
# g:tensor([ 1.3154])
# ------calling energy function------
# x tensor([ 1.0870])
# y grad tensor([ 0.6628])
# px tensor([ 0.2210])
# result tensor([ 0.1465])
# g:tensor([ 1.3832])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.0870])
# y grad tensor([ 0.6628])
# px tensor([ 0.2210])
# result tensor([ 0.1465])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.0870])
# y grad tensor([ 0.6628])
# px tensor([ 0.2210])
# result tensor([ 0.1465])
# Sample: 798
# ========== simulate ==============
# pos:tensor([ 0.6757]) True
# ------calling energy function------
# x tensor([ 1.0870])
# y grad tensor([ 0.6628])
# px tensor([ 0.2210])
# result tensor([ 0.1465])
# g:tensor([ 1.3832])
# grad1:tensor([ 1.3832])
# momtensor([ 0.8454])
# ------calling energy function------
# x tensor([ 1.1391])
# y grad tensor([ 0.6799])
# px tensor([ 0.2085])
# result tensor([ 0.1418])
# g:tensor([ 1.4544])
# ------calling energy function------
# x tensor([ 1.1825])
# y grad tensor([ 0.6935])
# px tensor([ 0.1983])
# result tensor([ 0.1375])
# g:tensor([ 1.5135])
# ------calling energy function------
# x tensor([ 1.2159])
# y grad tensor([ 0.7036])
# px tensor([ 0.1905])
# result tensor([ 0.1340])
# g:tensor([ 1.5591])
# ========== 2nd hamiltonian ==============
# x tensor([ 1.2159])
# y grad tensor([ 0.7036])
# px tensor([ 0.1905])
# result tensor([ 0.1340])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.2159])
# y grad tensor([ 0.7036])
# px tensor([ 0.1905])
# result tensor([ 0.1340])
# Sample: 799
# ========== simulate ==============
# pos:tensor([ 0.8644]) True
# ------calling energy function------
# x tensor([ 1.2159])
# y grad tensor([ 0.7036])
# px tensor([ 0.1905])
# result tensor([ 0.1340])
# g:tensor([ 1.5591])
# grad1:tensor([ 1.5591])
# momtensor([-2.6351])
# ------calling energy function------
# x tensor([ 1.0330])
# y grad tensor([ 0.6441])
# px tensor([ 0.2340])
# result tensor([ 0.1507])
# g:tensor([ 1.3094])
# ------calling energy function------
# x tensor([ 0.8593])
# y grad tensor([ 0.5766])
# px tensor([ 0.2758])
# result tensor([ 0.1590])
# g:tensor([ 1.0720])
# ------calling energy function------
# x tensor([ 0.6999])
# y grad tensor([ 0.5034])
# px tensor([ 0.3123])
# result tensor([ 0.1572])
# g:tensor([ 0.8557])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6999])
# y grad tensor([ 0.5034])
# px tensor([ 0.3123])
# result tensor([ 0.1572])
# ========== 3rd hamiltonian ==============
# x tensor([ 1.2159])
# y grad tensor([ 0.7036])
# px tensor([ 0.1905])
# result tensor([ 0.1340])

# %%
x_list = [np.log(1+np.exp(e)) for e in y_list]
plt.hist(x_list)
plt.show()

# %%
"""
x_list = []
y_list = []
for i in range(100):
    pos_samples, mom_samples, ratio = sampler.get_samples(init, 0.1, 5, 1, torch.tensor([1.], requires_grad=True))
    y = pos_samples.detach().numpy()[0][0]
    x = torch.log(1+torch.exp(pos_samples)).detach().numpy()[0][0]
    x_list.append(x)
    y_list.append(y)
"""
# Out:
# '\nx_list = []\ny_list = []\nfor i in range(100):\n    pos_samples, mom_samples, ratio = sampler.get_samples(init, 0.1, 5, 1, torch.tensor([1.], requires_grad=True))\n    y = pos_samples.detach().numpy()[0][0]\n    x = torch.log(1+torch.exp(pos_samples)).detach().numpy()[0][0]\n    x_list.append(x)\n    y_list.append(y)\n'

# %%
l = []
for i in range(1000):
    prng = np.random.RandomState()
    x = prng.normal(0)
    l.append(x)
x = prng.normal([0, 0])
print(x)
plt.hist(l)
plt.show()
# Out:
# [ 1.61497581  0.31790423]
