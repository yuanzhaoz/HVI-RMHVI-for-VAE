# %%
import sys
sys.path.append('F:\Cambridge\Project\MHMC-for-VAE\change_of_variable')
sys.path.append('F:\Cambridge\Project\MHMC-for-VAE\hmc_pytorch')
from change_of_variable_pytorch import * 
from hmc_base_pytorch import *
from hmc_unconstrained_pytorch import *
import autograd.numpy as np
import torch
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.distributions.normal import Normal

# %%
def transform(y):
    return torch.log(1 + torch.exp(y))

def x_pdf(x):
    mean = torch.tensor([0., 0.])
    cov = torch.eye(2)
    m = MultivariateNormal(mean, cov)
    m.requires_grad=True
    n = torch.exp(m.log_prob(x))
    #n.requires_grad=True
    return n

def energy_function(y, cache):
    y.retain_grad()
    p = reparameter_pdf(transform, x_pdf, y)
    #y.grad.zero_()
    return 0-torch.log(p)

# %%
energy_function(init, None)
# Out:
# x tensor([ 0.6931,  0.6931])
# y grad tensor([ 0.5000,  0.5000])
# px tensor(1.00000e-02 *
#        9.8438)
# result tensor(1.00000e-02 *
#        [ 4.9219,  4.9219])
# tensor([ 3.0115,  3.0115])

# %%
def jacobian(inputs, outputs):
    return torch.stack([grad([outputs[:, i].sum()], [inputs], retain_graph=True, create_graph=True)[0]
                        for i in range(outputs.size(1))], dim=-1)

# %%
x = torch.tensor([1.,2.], requires_grad=True)
#y = transform(x)
y = torch.zeros(2)
y[0] = x[0]+1
y[1] = x[1]**2+x[0]+1
gradients = torch.tensor([0., 1], dtype=torch.float)
y.backward(gradients)
x.grad
# Out:
# tensor([ 1.,  4.])

# %%
y = torch.zeros(2)
y
# Out:
# tensor([ 0.,  0.])

# %%
one = torch.tensor([1., 1.])
x= torch.tensor([0.5, 0.5], requires_grad=True)
x = x/x[0].item()
p = torch.equal(one, x)
if p ==True:
    raise ValueError('A very specific bad thing happened.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-ff45a19fdfbf> in <module>()
#       4 p = torch.equal(one, x)
#       5 if p ==True:
# ----> 6     raise ValueError('A very specific bad thing happened.')
#
# ValueError: A very specific bad thing happened.

# %%
sampler = IsotropicHmcSampler(energy_function, energy_grad=None, prng=None,
                 mom_resample_coeff=1., dtype=np.float64)
init = torch.tensor([0., 0.], requires_grad=True)
pos_samples, mom_samples, ratio = sampler.get_samples(init, 0.1, 6, 1000, torch.tensor([[1.,0.],[0.,1.]], requires_grad=True))
#num = pos_samples.shape[0]
#y_list = []
#for i in range(num):
#    y_list.append(pos_samples[i].item())
# Out:
# ========== 1st hamiltonian ==============
# x tensor([ 0.6931,  0.6931])
# tensor(0.2500)
# px tensor(1.00000e-02 *
#        9.8438)
# result tensor(1.00000e-02 *
#        2.4609)
# Sample: 1
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.6931,  0.6931])
# tensor(0.2500)
# px tensor(1.00000e-02 *
#        9.8438)
# result tensor(1.00000e-02 *
#        2.4609)
# g:tensor([ 0.3466,  0.3466])
# ------calling energy function------
# x tensor([ 0.6266,  0.6604])
# tensor(0.2250)
# px tensor(0.1052)
# result tensor(1.00000e-02 *
#        2.3666)
# g:tensor([ 0.2917,  0.3192])
# ------calling energy function------
# x tensor([ 0.5635,  0.6273])
# tensor(0.2007)
# px tensor(0.1115)
# result tensor(1.00000e-02 *
#        2.2389)
# g:tensor([ 0.2427,  0.2923])
# ------calling energy function------
# x tensor([ 0.5043,  0.5941])
# tensor(0.1774)
# px tensor(0.1175)
# result tensor(1.00000e-02 *
#        2.0842)
# g:tensor([ 0.1997,  0.2661])
# ------calling energy function------
# x tensor([ 0.4492,  0.5611])
# tensor(0.1554)
# px tensor(0.1229)
# result tensor(1.00000e-02 *
#        1.9102)
# g:tensor([ 0.1626,  0.2409])
# ------calling energy function------
# x tensor([ 0.3985,  0.5284])
# tensor(0.1349)
# px tensor(0.1278)
# result tensor(1.00000e-02 *
#        1.7250)
# g:tensor([ 0.1310,  0.2169])
# ------calling energy function------
# x tensor([ 0.3522,  0.4964])
# tensor(0.1162)
# px tensor(0.1322)
# result tensor(1.00000e-02 *
#        1.5362)
# g:tensor([ 0.1046,  0.1942])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3522,  0.4964])
# tensor(0.1162)
# px tensor(0.1322)
# result tensor(1.00000e-02 *
#        1.5362)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6931,  0.6931])
# tensor(0.2500)
# px tensor(1.00000e-02 *
#        9.8438)
# result tensor(1.00000e-02 *
#        2.4609)
# Sample: 2
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.6931,  0.6931])
# tensor(0.2500)
# px tensor(1.00000e-02 *
#        9.8438)
# result tensor(1.00000e-02 *
#        2.4609)
# g:tensor([ 0.3466,  0.3466])
# ------calling energy function------
# x tensor([ 0.7188,  0.6428])
# tensor(0.2431)
# px tensor(1.00000e-02 *
#        9.9973)
# result tensor(1.00000e-02 *
#        2.4305)
# g:tensor([ 0.3685,  0.3048])
# ------calling energy function------
# x tensor([ 0.7433,  0.5938])
# tensor(0.2348)
# px tensor(0.1012)
# result tensor(1.00000e-02 *
#        2.3771)
# g:tensor([ 0.3898,  0.2659])
# ------calling energy function------
# x tensor([ 0.7661,  0.5464])
# tensor(0.2253)
# px tensor(0.1022)
# result tensor(1.00000e-02 *
#        2.3031)
# g:tensor([ 0.4100,  0.2300])
# ------calling energy function------
# x tensor([ 0.7872,  0.5011])
# tensor(0.2148)
# px tensor(0.1030)
# result tensor(1.00000e-02 *
#        2.2114)
# g:tensor([ 0.4290,  0.1975])
# ------calling energy function------
# x tensor([ 0.8063,  0.4579])
# tensor(0.2034)
# px tensor(0.1035)
# result tensor(1.00000e-02 *
#        2.1056)
# g:tensor([ 0.4463,  0.1682])
# ------calling energy function------
# x tensor([ 0.8232,  0.4172])
# tensor(0.1914)
# px tensor(0.1040)
# result tensor(1.00000e-02 *
#        1.9894)
# g:tensor([ 0.4618,  0.1423])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8232,  0.4172])
# tensor(0.1914)
# px tensor(0.1040)
# result tensor(1.00000e-02 *
#        1.9894)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8232,  0.4172])
# tensor(0.1914)
# px tensor(0.1040)
# result tensor(1.00000e-02 *
#        1.9894)
# Sample: 3
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.8232,  0.4172])
# tensor(0.1914)
# px tensor(0.1040)
# result tensor(1.00000e-02 *
#        1.9894)
# g:tensor([ 0.4618,  0.1423])
# ------calling energy function------
# x tensor([ 0.7709,  0.4211])
# tensor(0.1847)
# px tensor(0.1082)
# result tensor(1.00000e-02 *
#        1.9986)
# g:tensor([ 0.4143,  0.1447])
# ------calling energy function------
# x tensor([ 0.7188,  0.4245])
# tensor(0.1773)
# px tensor(0.1123)
# result tensor(1.00000e-02 *
#        1.9921)
# g:tensor([ 0.3685,  0.1469])
# ------calling energy function------
# x tensor([ 0.6673,  0.4275])
# tensor(0.1694)
# px tensor(0.1163)
# result tensor(1.00000e-02 *
#        1.9692)
# g:tensor([ 0.3249,  0.1487])
# ------calling energy function------
# x tensor([ 0.6169,  0.4299])
# tensor(0.1609)
# px tensor(0.1200)
# result tensor(1.00000e-02 *
#        1.9300)
# g:tensor([ 0.2840,  0.1502])
# ------calling energy function------
# x tensor([ 0.5682,  0.4319])
# tensor(0.1520)
# px tensor(0.1234)
# result tensor(1.00000e-02 *
#        1.8754)
# g:tensor([ 0.2463,  0.1515])
# ------calling energy function------
# x tensor([ 0.5213,  0.4333])
# tensor(0.1428)
# px tensor(0.1265)
# result tensor(1.00000e-02 *
#        1.8068)
# g:tensor([ 0.2118,  0.1523])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5213,  0.4333])
# tensor(0.1428)
# px tensor(0.1265)
# result tensor(1.00000e-02 *
#        1.8068)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5213,  0.4333])
# tensor(0.1428)
# px tensor(0.1265)
# result tensor(1.00000e-02 *
#        1.8068)
# Sample: 4
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.5213,  0.4333])
# tensor(0.1428)
# px tensor(0.1265)
# result tensor(1.00000e-02 *
#        1.8068)
# g:tensor([ 0.2118,  0.1523])
# ------calling energy function------
# x tensor([ 0.5262,  0.4204])
# tensor(0.1404)
# px tensor(0.1269)
# result tensor(1.00000e-02 *
#        1.7814)
# g:tensor([ 0.2153,  0.1443])
# ------calling energy function------
# x tensor([ 0.5301,  0.4074])
# tensor(0.1377)
# px tensor(0.1273)
# result tensor(1.00000e-02 *
#        1.7524)
# g:tensor([ 0.2181,  0.1363])
# ------calling energy function------
# x tensor([ 0.5332,  0.3942])
# tensor(0.1346)
# px tensor(0.1277)
# result tensor(1.00000e-02 *
#        1.7200)
# g:tensor([ 0.2204,  0.1284])
# ------calling energy function------
# x tensor([ 0.5354,  0.3810])
# tensor(0.1313)
# px tensor(0.1282)
# result tensor(1.00000e-02 *
#        1.6845)
# g:tensor([ 0.2220,  0.1207])
# ------calling energy function------
# x tensor([ 0.5367,  0.3678])
# tensor(0.1278)
# px tensor(0.1288)
# result tensor(1.00000e-02 *
#        1.6461)
# g:tensor([ 0.2229,  0.1132])
# ------calling energy function------
# x tensor([ 0.5371,  0.3546])
# tensor(0.1241)
# px tensor(0.1294)
# result tensor(1.00000e-02 *
#        1.6052)
# g:tensor([ 0.2232,  0.1059])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5371,  0.3546])
# tensor(0.1241)
# px tensor(0.1294)
# result tensor(1.00000e-02 *
#        1.6052)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5371,  0.3546])
# tensor(0.1241)
# px tensor(0.1294)
# result tensor(1.00000e-02 *
#        1.6052)
# Sample: 5
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.5371,  0.3546])
# tensor(0.1241)
# px tensor(0.1294)
# result tensor(1.00000e-02 *
#        1.6052)
# g:tensor([ 0.2232,  0.1059])
# ------calling energy function------
# x tensor([ 0.4829,  0.3662])
# tensor(0.1174)
# px tensor(0.1325)
# result tensor(1.00000e-02 *
#        1.5555)
# g:tensor([ 0.1850,  0.1123])
# ------calling energy function------
# x tensor([ 0.4324,  0.3777])
# tensor(0.1104)
# px tensor(0.1350)
# result tensor(1.00000e-02 *
#        1.4906)
# g:tensor([ 0.1518,  0.1188])
# ------calling energy function------
# x tensor([ 0.3858,  0.3891])
# tensor(0.1032)
# px tensor(0.1370)
# result tensor(1.00000e-02 *
#        1.4133)
# g:tensor([ 0.1235,  0.1254])
# ------calling energy function------
# x tensor([ 0.3430,  0.4004])
# tensor(1.00000e-02 *
#        9.5813)
# px tensor(0.1385)
# result tensor(1.00000e-02 *
#        1.3270)
# g:tensor([ 0.0996,  0.1321])
# ------calling energy function------
# x tensor([ 0.3040,  0.4115])
# tensor(1.00000e-02 *
#        8.8442)
# px tensor(0.1396)
# result tensor(1.00000e-02 *
#        1.2349)
# g:tensor([ 0.0797,  0.1388])
# ------calling energy function------
# x tensor([ 0.2687,  0.4224])
# tensor(1.00000e-02 *
#        8.1181)
# px tensor(0.1404)
# result tensor(1.00000e-02 *
#        1.1399)
# g:tensor([ 0.0633,  0.1455])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2687,  0.4224])
# tensor(1.00000e-02 *
#        8.1181)
# px tensor(0.1404)
# result tensor(1.00000e-02 *
#        1.1399)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2687,  0.4224])
# tensor(1.00000e-02 *
#        8.1181)
# px tensor(0.1404)
# result tensor(1.00000e-02 *
#        1.1399)
# Sample: 6
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.2687,  0.4224])
# tensor(1.00000e-02 *
#        8.1181)
# px tensor(0.1404)
# result tensor(1.00000e-02 *
#        1.1399)
# g:tensor([ 0.0633,  0.1455])
# ------calling energy function------
# x tensor([ 0.2642,  0.3916])
# tensor(1.00000e-02 *
#        7.5237)
# px tensor(0.1423)
# result tensor(1.00000e-02 *
#        1.0710)
# g:tensor([ 0.0613,  0.1269])
# ------calling energy function------
# x tensor([ 0.2596,  0.3623])
# tensor(1.00000e-02 *
#        6.9501)
# px tensor(0.1441)
# result tensor(1.00000e-02 *
#        1.0015)
# g:tensor([ 0.0594,  0.1101])
# ------calling energy function------
# x tensor([ 0.2550,  0.3345])
# tensor(1.00000e-02 *
#        6.3999)
# px tensor(0.1457)
# result tensor(1.00000e-03 *
#        9.3233)
# g:tensor(1.00000e-02 *
#        [ 5.7403,  9.5111])
# ------calling energy function------
# x tensor([ 0.2503,  0.3083])
# tensor(1.00000e-02 *
#        5.8754)
# px tensor(0.1471)
# result tensor(1.00000e-03 *
#        8.6419)
# g:tensor(1.00000e-02 *
#        [ 5.5440,  8.1791])
# ------calling energy function------
# x tensor([ 0.2456,  0.2836])
# tensor(1.00000e-02 *
#        5.3783)
# px tensor(0.1483)
# result tensor(1.00000e-03 *
#        7.9780)
# g:tensor(1.00000e-02 *
#        [ 5.3489,  7.0049])
# ------calling energy function------
# x tensor([ 0.2409,  0.2606])
# tensor(1.00000e-02 *
#        4.9096)
# px tensor(0.1494)
# result tensor(1.00000e-03 *
#        7.3372)
# g:tensor(1.00000e-02 *
#        [ 5.1553,  5.9764])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2409,  0.2606])
# tensor(1.00000e-02 *
#        4.9096)
# px tensor(0.1494)
# result tensor(1.00000e-03 *
#        7.3372)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2409,  0.2606])
# tensor(1.00000e-02 *
#        4.9096)
# px tensor(0.1494)
# result tensor(1.00000e-03 *
#        7.3372)
# Sample: 7
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.2409,  0.2606])
# tensor(1.00000e-02 *
#        4.9096)
# px tensor(0.1494)
# result tensor(1.00000e-03 *
#        7.3372)
# g:tensor(1.00000e-02 *
#        [ 5.1553,  5.9764])
# ------calling energy function------
# x tensor([ 0.2271,  0.3044])
# tensor(1.00000e-02 *
#        5.3316)
# px tensor(0.1481)
# result tensor(1.00000e-03 *
#        7.8951)
# g:tensor(1.00000e-02 *
#        [ 4.6131,  7.9898])
# ------calling energy function------
# x tensor([ 0.2139,  0.3542])
# tensor(1.00000e-02 *
#        5.7448)
# px tensor(0.1461)
# result tensor(1.00000e-03 *
#        8.3929)
# g:tensor([ 0.0412,  0.1057])
# ------calling energy function------
# x tensor([ 0.2014,  0.4103])
# tensor(1.00000e-02 *
#        6.1387)
# px tensor(0.1434)
# result tensor(1.00000e-03 *
#        8.8011)
# g:tensor([ 0.0367,  0.1381])
# ------calling energy function------
# x tensor([ 0.1894,  0.4728])
# tensor(1.00000e-02 *
#        6.5021)
# px tensor(0.1398)
# result tensor(1.00000e-03 *
#        9.0895)
# g:tensor([ 0.0327,  0.1781])
# ------calling energy function------
# x tensor([ 0.1781,  0.5418])
# tensor(1.00000e-02 *
#        6.8242)
# px tensor(0.1353)
# result tensor(1.00000e-03 *
#        9.2309)
# g:tensor([ 0.0291,  0.2266])
# ------calling energy function------
# x tensor([ 0.1673,  0.6170])
# tensor(1.00000e-02 *
#        7.0951)
# px tensor(0.1297)
# result tensor(1.00000e-03 *
#        9.2049)
# g:tensor([ 0.0258,  0.2841])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1673,  0.6170])
# tensor(1.00000e-02 *
#        7.0951)
# px tensor(0.1297)
# result tensor(1.00000e-03 *
#        9.2049)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1673,  0.6170])
# tensor(1.00000e-02 *
#        7.0951)
# px tensor(0.1297)
# result tensor(1.00000e-03 *
#        9.2049)
# Sample: 8
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.1673,  0.6170])
# tensor(1.00000e-02 *
#        7.0951)
# px tensor(0.1297)
# result tensor(1.00000e-03 *
#        9.2049)
# g:tensor([ 0.0258,  0.2841])
# ------calling energy function------
# x tensor([ 0.1705,  0.5724])
# tensor(1.00000e-02 *
#        6.8307)
# px tensor(0.1332)
# result tensor(1.00000e-03 *
#        9.0953)
# g:tensor([ 0.0267,  0.2495])
# ------calling energy function------
# x tensor([ 0.1736,  0.5292])
# tensor(1.00000e-02 *
#        6.5487)
# px tensor(0.1363)
# result tensor(1.00000e-03 *
#        8.9250)
# g:tensor([ 0.0277,  0.2175])
# ------calling energy function------
# x tensor([ 0.1767,  0.4877])
# tensor(1.00000e-02 *
#        6.2524)
# px tensor(0.1391)
# result tensor(1.00000e-03 *
#        8.6983)
# g:tensor([ 0.0286,  0.1882])
# ------calling energy function------
# x tensor([ 0.1799,  0.4481])
# tensor(1.00000e-02 *
#        5.9453)
# px tensor(0.1416)
# result tensor(1.00000e-03 *
#        8.4211)
# g:tensor([ 0.0296,  0.1618])
# ------calling energy function------
# x tensor([ 0.1830,  0.4105])
# tensor(1.00000e-02 *
#        5.6309)
# px tensor(0.1439)
# result tensor(1.00000e-03 *
#        8.1008)
# g:tensor([ 0.0306,  0.1382])
# ------calling energy function------
# x tensor([ 0.1862,  0.3751])
# tensor(1.00000e-02 *
#        5.3126)
# px tensor(0.1458)
# result tensor(1.00000e-03 *
#        7.7456)
# g:tensor([ 0.0316,  0.1173])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1862,  0.3751])
# tensor(1.00000e-02 *
#        5.3126)
# px tensor(0.1458)
# result tensor(1.00000e-03 *
#        7.7456)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1862,  0.3751])
# tensor(1.00000e-02 *
#        5.3126)
# px tensor(0.1458)
# result tensor(1.00000e-03 *
#        7.7456)
# Sample: 9
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.1862,  0.3751])
# tensor(1.00000e-02 *
#        5.3126)
# px tensor(0.1458)
# result tensor(1.00000e-03 *
#        7.7456)
# g:tensor([ 0.0316,  0.1173])
# ------calling energy function------
# x tensor([ 0.1783,  0.4578])
# tensor(1.00000e-02 *
#        5.9983)
# px tensor(0.1411)
# result tensor(1.00000e-03 *
#        8.4612)
# g:tensor([ 0.0291,  0.1682])
# ------calling energy function------
# x tensor([ 0.1707,  0.5536])
# tensor(1.00000e-02 *
#        6.6697)
# px tensor(0.1346)
# result tensor(1.00000e-03 *
#        8.9754)
# g:tensor([ 0.0268,  0.2354])
# ------calling energy function------
# x tensor([ 0.1633,  0.6625])
# tensor(1.00000e-02 *
#        7.2986)
# px tensor(0.1261)
# result tensor(1.00000e-03 *
#        9.2035)
# g:tensor([ 0.0246,  0.3210])
# ------calling energy function------
# x tensor([ 0.1562,  0.7840])
# tensor(1.00000e-02 *
#        7.8578)
# px tensor(0.1156)
# result tensor(1.00000e-03 *
#        9.0857)
# g:tensor([ 0.0226,  0.4260])
# ------calling energy function------
# x tensor([ 0.1493,  0.9167])
# tensor(1.00000e-02 *
#        8.3256)
# px tensor(0.1034)
# result tensor(1.00000e-03 *
#        8.6081)
# g:tensor([ 0.0207,  0.5502])
# ------calling energy function------
# x tensor([ 0.1427,  1.0588])
# tensor(1.00000e-02 *
#        8.6876)
# px tensor(1.00000e-02 *
#        8.9946)
# result tensor(1.00000e-03 *
#        7.8142)
# g:tensor([ 0.0190,  0.6915])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1427,  1.0588])
# tensor(1.00000e-02 *
#        8.6876)
# px tensor(1.00000e-02 *
#        8.9946)
# result tensor(1.00000e-03 *
#        7.8142)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1427,  1.0588])
# tensor(1.00000e-02 *
#        8.6876)
# px tensor(1.00000e-02 *
#        8.9946)
# result tensor(1.00000e-03 *
#        7.8142)
# Sample: 10
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.1427,  1.0588])
# tensor(1.00000e-02 *
#        8.6876)
# px tensor(1.00000e-02 *
#        8.9946)
# result tensor(1.00000e-03 *
#        7.8142)
# g:tensor([ 0.0190,  0.6915])
# ------calling energy function------
# x tensor([ 0.1558,  1.0816])
# tensor(1.00000e-02 *
#        9.5366)
# px tensor(1.00000e-02 *
#        8.7600)
# result tensor(1.00000e-03 *
#        8.3540)
# g:tensor([ 0.0225,  0.7149])
# ------calling energy function------
# x tensor([ 0.1700,  1.1000])
# tensor(0.1043)
# px tensor(1.00000e-02 *
#        8.5664)
# result tensor(1.00000e-03 *
#        8.9326)
# g:tensor([ 0.0266,  0.7338])
# ------calling energy function------
# x tensor([ 0.1852,  1.1136])
# tensor(0.1136)
# px tensor(1.00000e-02 *
#        8.4155)
# result tensor(1.00000e-03 *
#        9.5570)
# g:tensor([ 0.0313,  0.7479])
# ------calling energy function------
# x tensor([ 0.2017,  1.1223])
# tensor(0.1232)
# px tensor(1.00000e-02 *
#        8.3081)
# result tensor(1.00000e-02 *
#        1.0234)
# g:tensor([ 0.0368,  0.7569])
# ------calling energy function------
# x tensor([ 0.2194,  1.1258])
# tensor(0.1331)
# px tensor(1.00000e-02 *
#        8.2441)
# result tensor(1.00000e-02 *
#        1.0971)
# g:tensor([ 0.0432,  0.7606])
# ------calling energy function------
# x tensor([ 0.2383,  1.1242])
# tensor(0.1432)
# px tensor(1.00000e-02 *
#        8.2229)
# result tensor(1.00000e-02 *
#        1.1772)
# g:tensor([ 0.0505,  0.7590])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2383,  1.1242])
# tensor(0.1432)
# px tensor(1.00000e-02 *
#        8.2229)
# result tensor(1.00000e-02 *
#        1.1772)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2383,  1.1242])
# tensor(0.1432)
# px tensor(1.00000e-02 *
#        8.2229)
# result tensor(1.00000e-02 *
#        1.1772)
# Sample: 11
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.2383,  1.1242])
# tensor(0.1432)
# px tensor(1.00000e-02 *
#        8.2229)
# result tensor(1.00000e-02 *
#        1.1772)
# g:tensor([ 0.0505,  0.7590])
# ------calling energy function------
# x tensor([ 0.2093,  0.9762])
# tensor(0.1177)
# px tensor(1.00000e-02 *
#        9.6690)
# result tensor(1.00000e-02 *
#        1.1382)
# g:tensor([ 0.0395,  0.6084])
# ------calling energy function------
# x tensor([ 0.1835,  0.8368])
# tensor(1.00000e-02 *
#        9.5028)
# px tensor(0.1103)
# result tensor(1.00000e-02 *
#        1.0478)
# g:tensor([ 0.0308,  0.4744])
# ------calling energy function------
# x tensor([ 0.1605,  0.7085])
# tensor(1.00000e-02 *
#        7.5273)
# px tensor(0.1222)
# result tensor(1.00000e-03 *
#        9.2015)
# g:tensor([ 0.0238,  0.3597])
# ------calling energy function------
# x tensor([ 0.1402,  0.5928])
# tensor(1.00000e-02 *
#        5.8497)
# px tensor(0.1322)
# result tensor(1.00000e-03 *
#        7.7336)
# g:tensor([ 0.0183,  0.2651])
# ------calling energy function------
# x tensor([ 0.1223,  0.4905])
# tensor(1.00000e-02 *
#        4.4618)
# px tensor(0.1401)
# result tensor(1.00000e-03 *
#        6.2493)
# g:tensor([ 0.0141,  0.1902])
# ------calling energy function------
# x tensor([ 0.1065,  0.4019])
# tensor(1.00000e-02 *
#        3.3432)
# px tensor(0.1460)
# result tensor(1.00000e-03 *
#        4.8803)
# g:tensor([ 0.0108,  0.1330])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1065,  0.4019])
# tensor(1.00000e-02 *
#        3.3432)
# px tensor(0.1460)
# result tensor(1.00000e-03 *
#        4.8803)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2383,  1.1242])
# tensor(0.1432)
# px tensor(1.00000e-02 *
#        8.2229)
# result tensor(1.00000e-02 *
#        1.1772)
# Sample: 12
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.2383,  1.1242])
# tensor(0.1432)
# px tensor(1.00000e-02 *
#        8.2229)
# result tensor(1.00000e-02 *
#        1.1772)
# g:tensor([ 0.0505,  0.7590])
# ------calling energy function------
# x tensor([ 0.2294,  1.0161])
# tensor(0.1308)
# px tensor(1.00000e-02 *
#        9.2516)
# result tensor(1.00000e-02 *
#        1.2099)
# g:tensor([ 0.0470,  0.6482])
# ------calling energy function------
# x tensor([ 0.2207,  0.9103])
# tensor(0.1183)
# px tensor(0.1026)
# result tensor(1.00000e-02 *
#        1.2145)
# g:tensor([ 0.0437,  0.5439])
# ------calling energy function------
# x tensor([ 0.2121,  0.8085])
# tensor(0.1060)
# px tensor(0.1122)
# result tensor(1.00000e-02 *
#        1.1894)
# g:tensor([ 0.0405,  0.4483])
# ------calling energy function------
# x tensor([ 0.2038,  0.7121])
# tensor(1.00000e-02 *
#        9.3931)
# px tensor(0.1210)
# result tensor(1.00000e-02 *
#        1.1363)
# g:tensor([ 0.0376,  0.3627])
# ------calling energy function------
# x tensor([ 0.1958,  0.6222])
# tensor(1.00000e-02 *
#        8.2362)
# px tensor(0.1287)
# result tensor(1.00000e-02 *
#        1.0596)
# g:tensor([ 0.0348,  0.2883])
# ------calling energy function------
# x tensor([ 0.1879,  0.5397])
# tensor(1.00000e-02 *
#        7.1447)
# px tensor(0.1352)
# result tensor(1.00000e-03 *
#        9.6582)
# g:tensor([ 0.0322,  0.2251])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1879,  0.5397])
# tensor(1.00000e-02 *
#        7.1447)
# px tensor(0.1352)
# result tensor(1.00000e-03 *
#        9.6582)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2383,  1.1242])
# tensor(0.1432)
# px tensor(1.00000e-02 *
#        8.2229)
# result tensor(1.00000e-02 *
#        1.1772)
# Sample: 13
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.2383,  1.1242])
# tensor(0.1432)
# px tensor(1.00000e-02 *
#        8.2229)
# result tensor(1.00000e-02 *
#        1.1772)
# g:tensor([ 0.0505,  0.7590])
# ------calling energy function------
# x tensor([ 0.2455,  1.1032])
# tensor(0.1455)
# px tensor(1.00000e-02 *
#        8.4031)
# result tensor(1.00000e-02 *
#        1.2224)
# g:tensor([ 0.0535,  0.7372])
# ------calling energy function------
# x tensor([ 0.2528,  1.0776])
# tensor(0.1473)
# px tensor(1.00000e-02 *
#        8.6259)
# result tensor(1.00000e-02 *
#        1.2708)
# g:tensor([ 0.0565,  0.7107])
# ------calling energy function------
# x tensor([ 0.2601,  1.0476])
# tensor(0.1487)
# px tensor(1.00000e-02 *
#        8.8882)
# result tensor(1.00000e-02 *
#        1.3216)
# g:tensor([ 0.0596,  0.6801])
# ------calling energy function------
# x tensor([ 0.2675,  1.0138])
# tensor(0.1495)
# px tensor(1.00000e-02 *
#        9.1856)
# result tensor(1.00000e-02 *
#        1.3735)
# g:tensor([ 0.0628,  0.6460])
# ------calling energy function------
# x tensor([ 0.2749,  0.9766])
# tensor(0.1498)
# px tensor(1.00000e-02 *
#        9.5130)
# result tensor(1.00000e-02 *
#        1.4252)
# g:tensor([ 0.0661,  0.6088])
# ------calling energy function------
# x tensor([ 0.2823,  0.9365])
# tensor(0.1495)
# px tensor(1.00000e-02 *
#        9.8645)
# result tensor(1.00000e-02 *
#        1.4750)
# g:tensor([ 0.0694,  0.5694])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2823,  0.9365])
# tensor(0.1495)
# px tensor(1.00000e-02 *
#        9.8645)
# result tensor(1.00000e-02 *
#        1.4750)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2823,  0.9365])
# tensor(0.1495)
# px tensor(1.00000e-02 *
#        9.8645)
# result tensor(1.00000e-02 *
#        1.4750)
# Sample: 14
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.2823,  0.9365])
# tensor(0.1495)
# px tensor(1.00000e-02 *
#        9.8645)
# result tensor(1.00000e-02 *
#        1.4750)
# g:tensor([ 0.0694,  0.5694])
# ------calling energy function------
# x tensor([ 0.3177,  0.9886])
# tensor(0.1709)
# px tensor(1.00000e-02 *
#        9.2828)
# result tensor(1.00000e-02 *
#        1.5863)
# g:tensor([ 0.0865,  0.6208])
# ------calling energy function------
# x tensor([ 0.3565,  1.0384])
# tensor(0.1937)
# px tensor(1.00000e-02 *
#        8.7114)
# result tensor(1.00000e-02 *
#        1.6876)
# g:tensor([ 0.1069,  0.6708])
# ------calling energy function------
# x tensor([ 0.3989,  1.0851])
# tensor(0.2178)
# px tensor(1.00000e-02 *
#        8.1583)
# result tensor(1.00000e-02 *
#        1.7769)
# g:tensor([ 0.1312,  0.7185])
# ------calling energy function------
# x tensor([ 0.4448,  1.1281])
# tensor(0.2428)
# px tensor(1.00000e-02 *
#        7.6302)
# result tensor(1.00000e-02 *
#        1.8529)
# g:tensor([ 0.1597,  0.7630])
# ------calling energy function------
# x tensor([ 0.4942,  1.1667])
# tensor(0.2685)
# px tensor(1.00000e-02 *
#        7.1321)
# result tensor(1.00000e-02 *
#        1.9150)
# g:tensor([ 0.1927,  0.8034])
# ------calling energy function------
# x tensor([ 0.5469,  1.2004])
# tensor(0.2944)
# px tensor(1.00000e-02 *
#        6.6678)
# result tensor(1.00000e-02 *
#        1.9632)
# g:tensor([ 0.2304,  0.8390])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5469,  1.2004])
# tensor(0.2944)
# px tensor(1.00000e-02 *
#        6.6678)
# result tensor(1.00000e-02 *
#        1.9632)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5469,  1.2004])
# tensor(0.2944)
# px tensor(1.00000e-02 *
#        6.6678)
# result tensor(1.00000e-02 *
#        1.9632)
# Sample: 15
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.5469,  1.2004])
# tensor(0.2944)
# px tensor(1.00000e-02 *
#        6.6678)
# result tensor(1.00000e-02 *
#        1.9632)
# g:tensor([ 0.2304,  0.8390])
# ------calling energy function------
# x tensor([ 0.5879,  1.1417])
# tensor(0.3026)
# px tensor(1.00000e-02 *
#        6.9782)
# result tensor(1.00000e-02 *
#        2.1115)
# g:tensor([ 0.2613,  0.7771])
# ------calling energy function------
# x tensor([ 0.6299,  1.0794])
# tensor(0.3085)
# px tensor(1.00000e-02 *
#        7.2891)
# result tensor(1.00000e-02 *
#        2.2490)
# g:tensor([ 0.2944,  0.7126])
# ------calling energy function------
# x tensor([ 0.6726,  1.0145])
# tensor(0.3121)
# px tensor(1.00000e-02 *
#        7.5877)
# result tensor(1.00000e-02 *
#        2.3680)
# g:tensor([ 0.3293,  0.6466])
# ------calling energy function------
# x tensor([ 0.7156,  0.9479])
# tensor(0.3130)
# px tensor(1.00000e-02 *
#        7.8617)
# result tensor(1.00000e-02 *
#        2.4608)
# g:tensor([ 0.3657,  0.5806])
# ------calling energy function------
# x tensor([ 0.7584,  0.8806])
# tensor(0.3112)
# px tensor(1.00000e-02 *
#        8.1003)
# result tensor(1.00000e-02 *
#        2.5212)
# g:tensor([ 0.4032,  0.5156])
# ------calling energy function------
# x tensor([ 0.8008,  0.8136])
# tensor(0.3068)
# px tensor(1.00000e-02 *
#        8.2956)
# result tensor(1.00000e-02 *
#        2.5448)
# g:tensor([ 0.4412,  0.4529])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.8008,  0.8136])
# tensor(0.3068)
# px tensor(1.00000e-02 *
#        8.2956)
# result tensor(1.00000e-02 *
#        2.5448)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.8008,  0.8136])
# tensor(0.3068)
# px tensor(1.00000e-02 *
#        8.2956)
# result tensor(1.00000e-02 *
#        2.5448)
# Sample: 16
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.8008,  0.8136])
# tensor(0.3068)
# px tensor(1.00000e-02 *
#        8.2956)
# result tensor(1.00000e-02 *
#        2.5448)
# g:tensor([ 0.4412,  0.4529])
# ------calling energy function------
# x tensor([ 0.8324,  0.8436])
# tensor(0.3220)
# px tensor(1.00000e-02 *
#        7.8854)
# result tensor(1.00000e-02 *
#        2.5388)
# g:tensor([ 0.4703,  0.4807])
# ------calling energy function------
# x tensor([ 0.8622,  0.8715])
# tensor(0.3361)
# px tensor(1.00000e-02 *
#        7.5074)
# result tensor(1.00000e-02 *
#        2.5229)
# g:tensor([ 0.4981,  0.5069])
# ------calling energy function------
# x tensor([ 0.8896,  0.8969])
# tensor(0.3489)
# px tensor(1.00000e-02 *
#        7.1659)
# result tensor(1.00000e-02 *
#        2.5002)
# g:tensor([ 0.5242,  0.5311])
# ------calling energy function------
# x tensor([ 0.9145,  0.9196])
# tensor(0.3604)
# px tensor(1.00000e-02 *
#        6.8639)
# result tensor(1.00000e-02 *
#        2.4735)
# g:tensor([ 0.5480,  0.5530])
# ------calling energy function------
# x tensor([ 0.9364,  0.9393])
# tensor(0.3703)
# px tensor(1.00000e-02 *
#        6.6040)
# result tensor(1.00000e-02 *
#        2.4456)
# g:tensor([ 0.5693,  0.5722])
# ------calling energy function------
# x tensor([ 0.9552,  0.9558])
# tensor(0.3787)
# px tensor(1.00000e-02 *
#        6.3877)
# result tensor(1.00000e-02 *
#        2.4189)
# g:tensor([ 0.5877,  0.5883])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.9552,  0.9558])
# tensor(0.3787)
# px tensor(1.00000e-02 *
#        6.3877)
# result tensor(1.00000e-02 *
#        2.4189)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.9552,  0.9558])
# tensor(0.3787)
# px tensor(1.00000e-02 *
#        6.3877)
# result tensor(1.00000e-02 *
#        2.4189)
# Sample: 17
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.9552,  0.9558])
# tensor(0.3787)
# px tensor(1.00000e-02 *
#        6.3877)
# result tensor(1.00000e-02 *
#        2.4189)
# g:tensor([ 0.5877,  0.5883])
# ------calling energy function------
# x tensor([ 0.8874,  0.9917])
# tensor(0.3701)
# px tensor(1.00000e-02 *
#        6.5655)
# result tensor(1.00000e-02 *
#        2.4296)
# g:tensor([ 0.5221,  0.6238])
# ------calling energy function------
# x tensor([ 0.8198,  1.0243])
# tensor(0.3586)
# px tensor(1.00000e-02 *
#        6.7302)
# result tensor(1.00000e-02 *
#        2.4135)
# g:tensor([ 0.4587,  0.6566])
# ------calling energy function------
# x tensor([ 0.7532,  1.0534])
# tensor(0.3446)
# px tensor(1.00000e-02 *
#        6.8816)
# result tensor(1.00000e-02 *
#        2.3714)
# g:tensor([ 0.3985,  0.6860])
# ------calling energy function------
# x tensor([ 0.6883,  1.0783])
# tensor(0.3283)
# px tensor(1.00000e-02 *
#        7.0219)
# result tensor(1.00000e-02 *
#        2.3054)
# g:tensor([ 0.3425,  0.7115])
# ------calling energy function------
# x tensor([ 0.6258,  1.0988])
# tensor(0.3102)
# px tensor(1.00000e-02 *
#        7.1547)
# result tensor(1.00000e-02 *
#        2.2191)
# g:tensor([ 0.2911,  0.7326])
# ------calling energy function------
# x tensor([ 0.5663,  1.1146])
# tensor(0.2905)
# px tensor(1.00000e-02 *
#        7.2847)
# result tensor(1.00000e-02 *
#        2.1165)
# g:tensor([ 0.2449,  0.7490])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5663,  1.1146])
# tensor(0.2905)
# px tensor(1.00000e-02 *
#        7.2847)
# result tensor(1.00000e-02 *
#        2.1165)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5663,  1.1146])
# tensor(0.2905)
# px tensor(1.00000e-02 *
#        7.2847)
# result tensor(1.00000e-02 *
#        2.1165)
# Sample: 18
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.5663,  1.1146])
# tensor(0.2905)
# px tensor(1.00000e-02 *
#        7.2847)
# result tensor(1.00000e-02 *
#        2.1165)
# g:tensor([ 0.2449,  0.7490])
# ------calling energy function------
# x tensor([ 0.5675,  1.1017])
# tensor(0.2891)
# px tensor(1.00000e-02 *
#        7.3844)
# result tensor(1.00000e-02 *
#        2.1351)
# g:tensor([ 0.2457,  0.7356])
# ------calling energy function------
# x tensor([ 0.5676,  1.0841])
# tensor(0.2866)
# px tensor(1.00000e-02 *
#        7.5278)
# result tensor(1.00000e-02 *
#        2.1576)
# g:tensor([ 0.2458,  0.7174])
# ------calling energy function------
# x tensor([ 0.5666,  1.0619])
# tensor(0.2830)
# px tensor(1.00000e-02 *
#        7.7135)
# result tensor(1.00000e-02 *
#        2.1827)
# g:tensor([ 0.2451,  0.6947])
# ------calling energy function------
# x tensor([ 0.5646,  1.0355])
# tensor(0.2782)
# px tensor(1.00000e-02 *
#        7.9393)
# result tensor(1.00000e-02 *
#        2.2089)
# g:tensor([ 0.2436,  0.6678])
# ------calling energy function------
# x tensor([ 0.5615,  1.0052])
# tensor(0.2724)
# px tensor(1.00000e-02 *
#        8.2026)
# result tensor(1.00000e-02 *
#        2.2345)
# g:tensor([ 0.2413,  0.6373])
# ------calling energy function------
# x tensor([ 0.5574,  0.9715])
# tensor(0.2656)
# px tensor(1.00000e-02 *
#        8.5000)
# result tensor(1.00000e-02 *
#        2.2573)
# g:tensor([ 0.2382,  0.6037])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5574,  0.9715])
# tensor(0.2656)
# px tensor(1.00000e-02 *
#        8.5000)
# result tensor(1.00000e-02 *
#        2.2573)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5574,  0.9715])
# tensor(0.2656)
# px tensor(1.00000e-02 *
#        8.5000)
# result tensor(1.00000e-02 *
#        2.2573)
# Sample: 19
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.5574,  0.9715])
# tensor(0.2656)
# px tensor(1.00000e-02 *
#        8.5000)
# result tensor(1.00000e-02 *
#        2.2573)
# g:tensor([ 0.2382,  0.6037])
# ------calling energy function------
# x tensor([ 0.5432,  0.9878])
# tensor(0.2630)
# px tensor(1.00000e-02 *
#        8.4312)
# result tensor(1.00000e-02 *
#        2.2176)
# g:tensor([ 0.2276,  0.6199])
# ------calling energy function------
# x tensor([ 0.5283,  1.0003])
# tensor(0.2595)
# px tensor(1.00000e-02 *
#        8.3936)
# result tensor(1.00000e-02 *
#        2.1777)
# g:tensor([ 0.2168,  0.6324])
# ------calling energy function------
# x tensor([ 0.5128,  1.0089])
# tensor(0.2549)
# px tensor(1.00000e-02 *
#        8.3886)
# result tensor(1.00000e-02 *
#        2.1383)
# g:tensor([ 0.2057,  0.6410])
# ------calling energy function------
# x tensor([ 0.4969,  1.0134])
# tensor(0.2495)
# px tensor(1.00000e-02 *
#        8.4175)
# result tensor(1.00000e-02 *
#        2.0997)
# g:tensor([ 0.1946,  0.6456])
# ------calling energy function------
# x tensor([ 0.4806,  1.0139])
# tensor(0.2432)
# px tensor(1.00000e-02 *
#        8.4808)
# result tensor(1.00000e-02 *
#        2.0621)
# g:tensor([ 0.1834,  0.6460])
# ------calling energy function------
# x tensor([ 0.4641,  1.0102])
# tensor(0.2361)
# px tensor(1.00000e-02 *
#        8.5791)
# result tensor(1.00000e-02 *
#        2.0254)
# g:tensor([ 0.1723,  0.6424])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4641,  1.0102])
# tensor(0.2361)
# px tensor(1.00000e-02 *
#        8.5791)
# result tensor(1.00000e-02 *
#        2.0254)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4641,  1.0102])
# tensor(0.2361)
# px tensor(1.00000e-02 *
#        8.5791)
# result tensor(1.00000e-02 *
#        2.0254)
# Sample: 20
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.4641,  1.0102])
# tensor(0.2361)
# px tensor(1.00000e-02 *
#        8.5791)
# result tensor(1.00000e-02 *
#        2.0254)
# g:tensor([ 0.1723,  0.6424])
# ------calling energy function------
# x tensor([ 0.3720,  1.0202])
# tensor(0.1987)
# px tensor(1.00000e-02 *
#        8.8258)
# result tensor(1.00000e-02 *
#        1.7534)
# g:tensor([ 0.1156,  0.6524])
# ------calling energy function------
# x tensor([ 0.2953,  1.0260])
# tensor(0.1641)
# px tensor(1.00000e-02 *
#        9.0007)
# result tensor(1.00000e-02 *
#        1.4766)
# g:tensor([ 0.0755,  0.6583])
# ------calling energy function------
# x tensor([ 0.2325,  1.0277])
# tensor(0.1332)
# px tensor(1.00000e-02 *
#        9.1360)
# result tensor(1.00000e-02 *
#        1.2168)
# g:tensor([ 0.0482,  0.6599])
# ------calling energy function------
# x tensor([ 0.1817,  1.0251])
# tensor(0.1065)
# px tensor(1.00000e-02 *
#        9.2573)
# result tensor(1.00000e-03 *
#        9.8619)
# g:tensor([ 0.0302,  0.6573])
# ------calling energy function------
# x tensor([ 0.1412,  1.0182])
# tensor(1.00000e-02 *
#        8.4111)
# px tensor(1.00000e-02 *
#        9.3831)
# result tensor(1.00000e-03 *
#        7.8922)
# g:tensor([ 0.0186,  0.6504])
# ------calling energy function------
# x tensor([ 0.1092,  1.0073])
# tensor(1.00000e-02 *
#        6.5676)
# px tensor(1.00000e-02 *
#        9.5255)
# result tensor(1.00000e-03 *
#        6.2560)
# g:tensor([ 0.0113,  0.6395])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1092,  1.0073])
# tensor(1.00000e-02 *
#        6.5676)
# px tensor(1.00000e-02 *
#        9.5255)
# result tensor(1.00000e-03 *
#        6.2560)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4641,  1.0102])
# tensor(0.2361)
# px tensor(1.00000e-02 *
#        8.5791)
# result tensor(1.00000e-02 *
#        2.0254)
# Sample: 21
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.4641,  1.0102])
# tensor(0.2361)
# px tensor(1.00000e-02 *
#        8.5791)
# result tensor(1.00000e-02 *
#        2.0254)
# g:tensor([ 0.1723,  0.6424])
# ------calling energy function------
# x tensor([ 0.5056,  1.0162])
# tensor(0.2532)
# px tensor(1.00000e-02 *
#        8.3571)
# result tensor(1.00000e-02 *
#        2.1162)
# g:tensor([ 0.2007,  0.6484])
# ------calling energy function------
# x tensor([ 0.5491,  1.0181])
# tensor(0.2699)
# px tensor(1.00000e-02 *
#        8.1520)
# result tensor(1.00000e-02 *
#        2.2001)
# g:tensor([ 0.2320,  0.6503])
# ------calling energy function------
# x tensor([ 0.5944,  1.0158])
# tensor(0.2858)
# px tensor(1.00000e-02 *
#        7.9624)
# result tensor(1.00000e-02 *
#        2.2759)
# g:tensor([ 0.2663,  0.6480])
# ------calling energy function------
# x tensor([ 0.6410,  1.0094])
# tensor(0.3008)
# px tensor(1.00000e-02 *
#        7.7867)
# result tensor(1.00000e-02 *
#        2.3420)
# g:tensor([ 0.3033,  0.6415])
# ------calling energy function------
# x tensor([ 0.6886,  0.9990])
# tensor(0.3144)
# px tensor(1.00000e-02 *
#        7.6233)
# result tensor(1.00000e-02 *
#        2.3971)
# g:tensor([ 0.3428,  0.6311])
# ------calling energy function------
# x tensor([ 0.7369,  0.9846])
# tensor(0.3266)
# px tensor(1.00000e-02 *
#        7.4709)
# result tensor(1.00000e-02 *
#        2.4402)
# g:tensor([ 0.3842,  0.6168])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.7369,  0.9846])
# tensor(0.3266)
# px tensor(1.00000e-02 *
#        7.4709)
# result tensor(1.00000e-02 *
#        2.4402)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.7369,  0.9846])
# tensor(0.3266)
# px tensor(1.00000e-02 *
#        7.4709)
# result tensor(1.00000e-02 *
#        2.4402)
# Sample: 22
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.7369,  0.9846])
# tensor(0.3266)
# px tensor(1.00000e-02 *
#        7.4709)
# result tensor(1.00000e-02 *
#        2.4402)
# g:tensor([ 0.3842,  0.6168])
# ------calling energy function------
# x tensor([ 0.6617,  0.9491])
# tensor(0.2967)
# px tensor(1.00000e-02 *
#        8.1499)
# result tensor(1.00000e-02 *
#        2.4178)
# g:tensor([ 0.3203,  0.5817])
# ------calling energy function------
# x tensor([ 0.5907,  0.9108])
# tensor(0.2666)
# px tensor(1.00000e-02 *
#        8.8295)
# result tensor(1.00000e-02 *
#        2.3543)
# g:tensor([ 0.2635,  0.5445])
# ------calling energy function------
# x tensor([ 0.5243,  0.8703])
# tensor(0.2371)
# px tensor(1.00000e-02 *
#        9.4987)
# result tensor(1.00000e-02 *
#        2.2524)
# g:tensor([ 0.2139,  0.5058])
# ------calling energy function------
# x tensor([ 0.4630,  0.8281])
# tensor(0.2087)
# px tensor(0.1015)
# result tensor(1.00000e-02 *
#        2.1176)
# g:tensor([ 0.1716,  0.4663])
# ------calling energy function------
# x tensor([ 0.4068,  0.7847])
# tensor(0.1817)
# px tensor(0.1077)
# result tensor(1.00000e-02 *
#        1.9572)
# g:tensor([ 0.1360,  0.4267])
# ------calling energy function------
# x tensor([ 0.3560,  0.7406])
# tensor(0.1567)
# px tensor(0.1136)
# result tensor(1.00000e-02 *
#        1.7793)
# g:tensor([ 0.1066,  0.3875])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3560,  0.7406])
# tensor(0.1567)
# px tensor(0.1136)
# result tensor(1.00000e-02 *
#        1.7793)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3560,  0.7406])
# tensor(0.1567)
# px tensor(0.1136)
# result tensor(1.00000e-02 *
#        1.7793)
# Sample: 23
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.3560,  0.7406])
# tensor(0.1567)
# px tensor(0.1136)
# result tensor(1.00000e-02 *
#        1.7793)
# g:tensor([ 0.1066,  0.3875])
# ------calling energy function------
# x tensor([ 0.3846,  0.7023])
# tensor(0.1611)
# px tensor(0.1155)
# result tensor(1.00000e-02 *
#        1.8607)
# g:tensor([ 0.1228,  0.3544])
# ------calling energy function------
# x tensor([ 0.4147,  0.6637])
# tensor(0.1647)
# px tensor(0.1172)
# result tensor(1.00000e-02 *
#        1.9293)
# g:tensor([ 0.1408,  0.3219])
# ------calling energy function------
# x tensor([ 0.4462,  0.6251])
# tensor(0.1673)
# px tensor(0.1185)
# result tensor(1.00000e-02 *
#        1.9824)
# g:tensor([ 0.1606,  0.2905])
# ------calling energy function------
# x tensor([ 0.4789,  0.5868])
# tensor(0.1689)
# px tensor(0.1195)
# result tensor(1.00000e-02 *
#        2.0180)
# g:tensor([ 0.1822,  0.2605])
# ------calling energy function------
# x tensor([ 0.5127,  0.5492])
# tensor(0.1695)
# px tensor(0.1200)
# result tensor(1.00000e-02 *
#        2.0344)
# g:tensor([ 0.2057,  0.2321])
# ------calling energy function------
# x tensor([ 0.5475,  0.5125])
# tensor(0.1691)
# px tensor(0.1201)
# result tensor(1.00000e-02 *
#        2.0311)
# g:tensor([ 0.2308,  0.2055])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5475,  0.5125])
# tensor(0.1691)
# px tensor(0.1201)
# result tensor(1.00000e-02 *
#        2.0311)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5475,  0.5125])
# tensor(0.1691)
# px tensor(0.1201)
# result tensor(1.00000e-02 *
#        2.0311)
# Sample: 24
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.5475,  0.5125])
# tensor(0.1691)
# px tensor(0.1201)
# result tensor(1.00000e-02 *
#        2.0311)
# g:tensor([ 0.2308,  0.2055])
# ------calling energy function------
# x tensor([ 0.5591,  0.5610])
# tensor(0.1839)
# px tensor(0.1163)
# result tensor(1.00000e-02 *
#        2.1388)
# g:tensor([ 0.2395,  0.2409])
# ------calling energy function------
# x tensor([ 0.5700,  0.6118])
# tensor(0.1988)
# px tensor(0.1122)
# result tensor(1.00000e-02 *
#        2.2308)
# g:tensor([ 0.2476,  0.2800])
# ------calling energy function------
# x tensor([ 0.5799,  0.6645])
# tensor(0.2136)
# px tensor(0.1079)
# result tensor(1.00000e-02 *
#        2.3045)
# g:tensor([ 0.2552,  0.3226])
# ------calling energy function------
# x tensor([ 0.5887,  0.7187])
# tensor(0.2281)
# px tensor(0.1034)
# result tensor(1.00000e-02 *
#        2.3579)
# g:tensor([ 0.2620,  0.3684])
# ------calling energy function------
# x tensor([ 0.5966,  0.7738])
# tensor(0.2421)
# px tensor(1.00000e-02 *
#        9.8747)
# result tensor(1.00000e-02 *
#        2.3902)
# g:tensor([ 0.2680,  0.4169])
# ------calling energy function------
# x tensor([ 0.6032,  0.8293])
# tensor(0.2553)
# px tensor(1.00000e-02 *
#        9.4075)
# result tensor(1.00000e-02 *
#        2.4017)
# g:tensor([ 0.2732,  0.4674])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.6032,  0.8293])
# tensor(0.2553)
# px tensor(1.00000e-02 *
#        9.4075)
# result tensor(1.00000e-02 *
#        2.4017)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6032,  0.8293])
# tensor(0.2553)
# px tensor(1.00000e-02 *
#        9.4075)
# result tensor(1.00000e-02 *
#        2.4017)
# Sample: 25
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.6032,  0.8293])
# tensor(0.2553)
# px tensor(1.00000e-02 *
#        9.4075)
# result tensor(1.00000e-02 *
#        2.4017)
# g:tensor([ 0.2732,  0.4674])
# ------calling energy function------
# x tensor([ 0.5852,  0.7779])
# tensor(0.2395)
# px tensor(1.00000e-02 *
#        9.9098)
# result tensor(1.00000e-02 *
#        2.3734)
# g:tensor([ 0.2593,  0.4205])
# ------calling energy function------
# x tensor([ 0.5665,  0.7264])
# tensor(0.2233)
# px tensor(0.1041)
# result tensor(1.00000e-02 *
#        2.3253)
# g:tensor([ 0.2450,  0.3751])
# ------calling energy function------
# x tensor([ 0.5472,  0.6755])
# tensor(0.2070)
# px tensor(0.1091)
# result tensor(1.00000e-02 *
#        2.2574)
# g:tensor([ 0.2306,  0.3317])
# ------calling energy function------
# x tensor([ 0.5274,  0.6256])
# tensor(0.1906)
# px tensor(0.1139)
# result tensor(1.00000e-02 *
#        2.1706)
# g:tensor([ 0.2162,  0.2909])
# ------calling energy function------
# x tensor([ 0.5073,  0.5771])
# tensor(0.1745)
# px tensor(0.1185)
# result tensor(1.00000e-02 *
#        2.0670)
# g:tensor([ 0.2019,  0.2530])
# ------calling energy function------
# x tensor([ 0.4871,  0.5304])
# tensor(0.1587)
# px tensor(0.1228)
# result tensor(1.00000e-02 *
#        1.9491)
# g:tensor([ 0.1878,  0.2183])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4871,  0.5304])
# tensor(0.1587)
# px tensor(0.1228)
# result tensor(1.00000e-02 *
#        1.9491)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.6032,  0.8293])
# tensor(0.2553)
# px tensor(1.00000e-02 *
#        9.4075)
# result tensor(1.00000e-02 *
#        2.4017)
# Sample: 26
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.6032,  0.8293])
# tensor(0.2553)
# px tensor(1.00000e-02 *
#        9.4075)
# result tensor(1.00000e-02 *
#        2.4017)
# g:tensor([ 0.2732,  0.4674])
# ------calling energy function------
# x tensor([ 0.5955,  0.8908])
# tensor(0.2646)
# px tensor(1.00000e-02 *
#        8.9645)
# result tensor(1.00000e-02 *
#        2.3718)
# g:tensor([ 0.2672,  0.5252])
# ------calling energy function------
# x tensor([ 0.5866,  0.9518])
# tensor(0.2725)
# px tensor(1.00000e-02 *
#        8.5190)
# result tensor(1.00000e-02 *
#        2.3211)
# g:tensor([ 0.2603,  0.5843])
# ------calling energy function------
# x tensor([ 0.5767,  1.0115])
# tensor(0.2789)
# px tensor(1.00000e-02 *
#        8.0803)
# result tensor(1.00000e-02 *
#        2.2533)
# g:tensor([ 0.2527,  0.6437])
# ------calling energy function------
# x tensor([ 0.5658,  1.0691])
# tensor(0.2838)
# px tensor(1.00000e-02 *
#        7.6577)
# result tensor(1.00000e-02 *
#        2.1729)
# g:tensor([ 0.2445,  0.7021])
# ------calling energy function------
# x tensor([ 0.5540,  1.1238])
# tensor(0.2871)
# px tensor(1.00000e-02 *
#        7.2600)
# result tensor(1.00000e-02 *
#        2.0844)
# g:tensor([ 0.2357,  0.7585])
# ------calling energy function------
# x tensor([ 0.5415,  1.1747])
# tensor(0.2889)
# px tensor(1.00000e-02 *
#        6.8949)
# result tensor(1.00000e-02 *
#        1.9922)
# g:tensor([ 0.2264,  0.8118])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5415,  1.1747])
# tensor(0.2889)
# px tensor(1.00000e-02 *
#        6.8949)
# result tensor(1.00000e-02 *
#        1.9922)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5415,  1.1747])
# tensor(0.2889)
# px tensor(1.00000e-02 *
#        6.8949)
# result tensor(1.00000e-02 *
#        1.9922)
# Sample: 27
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.5415,  1.1747])
# tensor(0.2889)
# px tensor(1.00000e-02 *
#        6.8949)
# result tensor(1.00000e-02 *
#        1.9922)
# g:tensor([ 0.2264,  0.8118])
# ------calling energy function------
# x tensor([ 0.5268,  1.1513])
# tensor(0.2800)
# px tensor(1.00000e-02 *
#        7.1402)
# result tensor(1.00000e-02 *
#        1.9995)
# g:tensor([ 0.2158,  0.7873])
# ------calling energy function------
# x tensor([ 0.5116,  1.1229])
# tensor(0.2702)
# px tensor(1.00000e-02 *
#        7.4329)
# result tensor(1.00000e-02 *
#        2.0084)
# g:tensor([ 0.2049,  0.7576])
# ------calling energy function------
# x tensor([ 0.4960,  1.0899])
# tensor(0.2595)
# px tensor(1.00000e-02 *
#        7.7708)
# result tensor(1.00000e-02 *
#        2.0169)
# g:tensor([ 0.1940,  0.7234])
# ------calling energy function------
# x tensor([ 0.4800,  1.0526])
# tensor(0.2482)
# px tensor(1.00000e-02 *
#        8.1504)
# result tensor(1.00000e-02 *
#        2.0226)
# g:tensor([ 0.1830,  0.6853])
# ------calling energy function------
# x tensor([ 0.4637,  1.0118])
# tensor(0.2361)
# px tensor(1.00000e-02 *
#        8.5672)
# result tensor(1.00000e-02 *
#        2.0230)
# g:tensor([ 0.1720,  0.6439])
# ------calling energy function------
# x tensor([ 0.4472,  0.9679])
# tensor(0.2236)
# px tensor(1.00000e-02 *
#        9.0153)
# result tensor(1.00000e-02 *
#        2.0158)
# g:tensor([ 0.1613,  0.6002])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4472,  0.9679])
# tensor(0.2236)
# px tensor(1.00000e-02 *
#        9.0153)
# result tensor(1.00000e-02 *
#        2.0158)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4472,  0.9679])
# tensor(0.2236)
# px tensor(1.00000e-02 *
#        9.0153)
# result tensor(1.00000e-02 *
#        2.0158)
# Sample: 28
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.4472,  0.9679])
# tensor(0.2236)
# px tensor(1.00000e-02 *
#        9.0153)
# result tensor(1.00000e-02 *
#        2.0158)
# g:tensor([ 0.1613,  0.6002])
# ------calling energy function------
# x tensor([ 0.4533,  0.9732])
# tensor(0.2268)
# px tensor(1.00000e-02 *
#        8.9436)
# result tensor(1.00000e-02 *
#        2.0281)
# g:tensor([ 0.1652,  0.6055])
# ------calling energy function------
# x tensor([ 0.4589,  0.9749])
# tensor(0.2292)
# px tensor(1.00000e-02 *
#        8.9067)
# result tensor(1.00000e-02 *
#        2.0414)
# g:tensor([ 0.1689,  0.6071])
# ------calling energy function------
# x tensor([ 0.4639,  0.9727])
# tensor(0.2309)
# px tensor(1.00000e-02 *
#        8.9047)
# result tensor(1.00000e-02 *
#        2.0558)
# g:tensor([ 0.1722,  0.6050])
# ------calling energy function------
# x tensor([ 0.4684,  0.9668])
# tensor(0.2318)
# px tensor(1.00000e-02 *
#        8.9374)
# result tensor(1.00000e-02 *
#        2.0713)
# g:tensor([ 0.1752,  0.5991])
# ------calling energy function------
# x tensor([ 0.4722,  0.9572])
# tensor(0.2318)
# px tensor(1.00000e-02 *
#        9.0041)
# result tensor(1.00000e-02 *
#        2.0876)
# g:tensor([ 0.1777,  0.5897])
# ------calling energy function------
# x tensor([ 0.4753,  0.9441])
# tensor(0.2311)
# px tensor(1.00000e-02 *
#        9.1036)
# result tensor(1.00000e-02 *
#        2.1041)
# g:tensor([ 0.1798,  0.5768])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.4753,  0.9441])
# tensor(0.2311)
# px tensor(1.00000e-02 *
#        9.1036)
# result tensor(1.00000e-02 *
#        2.1041)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.4753,  0.9441])
# tensor(0.2311)
# px tensor(1.00000e-02 *
#        9.1036)
# result tensor(1.00000e-02 *
#        2.1041)
# Sample: 29
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.4753,  0.9441])
# tensor(0.2311)
# px tensor(1.00000e-02 *
#        9.1036)
# result tensor(1.00000e-02 *
#        2.1041)
# g:tensor([ 0.1798,  0.5768])
# ------calling energy function------
# x tensor([ 0.5175,  0.9108])
# tensor(0.2415)
# px tensor(1.00000e-02 *
#        9.1948)
# result tensor(1.00000e-02 *
#        2.2204)
# g:tensor([ 0.2090,  0.5445])
# ------calling energy function------
# x tensor([ 0.5615,  0.8750])
# tensor(0.2506)
# px tensor(1.00000e-02 *
#        9.2702)
# result tensor(1.00000e-02 *
#        2.3227)
# g:tensor([ 0.2413,  0.5103])
# ------calling energy function------
# x tensor([ 0.6072,  0.8373])
# tensor(0.2581)
# px tensor(1.00000e-02 *
#        9.3226)
# ...
#        1.7268)
# px tensor(0.1583)
# result tensor(1.00000e-04 *
#        2.7337)
# g:tensor(1.00000e-03 *
#        [ 9.8418,  0.3215])
# ------calling energy function------
# x tensor([ 0.1139,  0.0185])
# tensor(1.00000e-03 *
#        1.9773)
# px tensor(0.1581)
# result tensor(1.00000e-04 *
#        3.1261)
# g:tensor(1.00000e-02 *
#        [ 1.2272,  0.0340])
# ------calling energy function------
# x tensor([ 0.1275,  0.0191])
# tensor(1.00000e-03 *
#        2.2607)
# px tensor(0.1578)
# result tensor(1.00000e-04 *
#        3.5683)
# g:tensor(1.00000e-02 *
#        [ 1.5266,  0.0360])
# ------calling energy function------
# x tensor([ 0.1426,  0.0196])
# tensor(1.00000e-03 *
#        2.5805)
# px tensor(0.1575)
# result tensor(1.00000e-04 *
#        4.0647)
# g:tensor(1.00000e-02 *
#        [ 1.8943,  0.0381])
# ------calling energy function------
# x tensor([ 0.1592,  0.0202])
# tensor(1.00000e-03 *
#        2.9402)
# px tensor(0.1571)
# result tensor(1.00000e-04 *
#        4.6196)
# g:tensor(1.00000e-02 *
#        [ 2.3439,  0.0403])
# ------calling energy function------
# x tensor([ 0.1776,  0.0208])
# tensor(1.00000e-03 *
#        3.3433)
# px tensor(0.1566)
# result tensor(1.00000e-04 *
#        5.2367)
# g:tensor(1.00000e-02 *
#        [ 2.8910,  0.0426])
# ------calling energy function------
# x tensor([ 0.1979,  0.0214])
# tensor(1.00000e-03 *
#        3.7934)
# px tensor(0.1560)
# result tensor(1.00000e-04 *
#        5.9190)
# g:tensor(1.00000e-02 *
#        [ 3.5537,  0.0451])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1979,  0.0214])
# tensor(1.00000e-03 *
#        3.7934)
# px tensor(0.1560)
# result tensor(1.00000e-04 *
#        5.9190)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.1979,  0.0214])
# tensor(1.00000e-03 *
#        3.7934)
# px tensor(0.1560)
# result tensor(1.00000e-04 *
#        5.9190)
# Sample: 1192
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.1979,  0.0214])
# tensor(1.00000e-03 *
#        3.7934)
# px tensor(0.1560)
# result tensor(1.00000e-04 *
#        5.9190)
# g:tensor(1.00000e-02 *
#        [ 3.5537,  0.0451])
# ------calling energy function------
# x tensor([ 0.2093,  0.0198])
# tensor(1.00000e-03 *
#        3.7057)
# px tensor(0.1557)
# result tensor(1.00000e-04 *
#        5.7689)
# g:tensor(1.00000e-02 *
#        [ 3.9508,  0.0389])
# ------calling energy function------
# x tensor([ 0.2211,  0.0184])
# tensor(1.00000e-03 *
#        3.6163)
# px tensor(0.1553)
# result tensor(1.00000e-04 *
#        5.6157)
# g:tensor(1.00000e-02 *
#        [ 4.3855,  0.0335])
# ------calling energy function------
# x tensor([ 0.2334,  0.0171])
# tensor(1.00000e-03 *
#        3.5254)
# px tensor(0.1549)
# result tensor(1.00000e-04 *
#        5.4593)
# g:tensor(1.00000e-02 *
#        [ 4.8599,  0.0289])
# ------calling energy function------
# x tensor([ 0.2463,  0.0159])
# tensor(1.00000e-03 *
#        3.4331)
# px tensor(0.1544)
# result tensor(1.00000e-04 *
#        5.3000)
# g:tensor(1.00000e-02 *
#        [ 5.3762,  0.0249])
# ------calling energy function------
# x tensor([ 0.2596,  0.0147])
# tensor(1.00000e-03 *
#        3.3394)
# px tensor(0.1539)
# result tensor(1.00000e-04 *
#        5.1381)
# g:tensor(1.00000e-02 *
#        [ 5.9364,  0.0215])
# ------calling energy function------
# x tensor([ 0.2735,  0.0137])
# tensor(1.00000e-03 *
#        3.2445)
# px tensor(0.1533)
# result tensor(1.00000e-04 *
#        4.9738)
# g:tensor(1.00000e-02 *
#        [ 6.5423,  0.0185])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2735,  0.0137])
# tensor(1.00000e-03 *
#        3.2445)
# px tensor(0.1533)
# result tensor(1.00000e-04 *
#        4.9738)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2735,  0.0137])
# tensor(1.00000e-03 *
#        3.2445)
# px tensor(0.1533)
# result tensor(1.00000e-04 *
#        4.9738)
# Sample: 1193
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.2735,  0.0137])
# tensor(1.00000e-03 *
#        3.2445)
# px tensor(0.1533)
# result tensor(1.00000e-04 *
#        4.9738)
# g:tensor(1.00000e-02 *
#        [ 6.5423,  0.0185])
# ------calling energy function------
# x tensor([ 0.2829,  0.0148])
# tensor(1.00000e-03 *
#        3.6266)
# px tensor(0.1529)
# result tensor(1.00000e-04 *
#        5.5449)
# g:tensor(1.00000e-02 *
#        [ 6.9719,  0.0218])
# ------calling energy function------
# x tensor([ 0.2925,  0.0161])
# tensor(1.00000e-03 *
#        4.0501)
# px tensor(0.1525)
# result tensor(1.00000e-04 *
#        6.1752)
# g:tensor(1.00000e-02 *
#        [ 7.4180,  0.0257])
# ------calling energy function------
# x tensor([ 0.3022,  0.0175])
# tensor(1.00000e-03 *
#        4.5188)
# px tensor(0.1520)
# result tensor(1.00000e-04 *
#        6.8698)
# g:tensor(1.00000e-02 *
#        [ 7.8800,  0.0303])
# ------calling energy function------
# x tensor([ 0.3119,  0.0190])
# tensor(1.00000e-03 *
#        5.0368)
# px tensor(0.1516)
# result tensor(1.00000e-04 *
#        7.6344)
# g:tensor(1.00000e-02 *
#        [ 8.3566,  0.0357])
# ------calling energy function------
# x tensor([ 0.3216,  0.0206])
# tensor(1.00000e-03 *
#        5.6086)
# px tensor(0.1511)
# result tensor(1.00000e-04 *
#        8.4745)
# g:tensor(1.00000e-02 *
#        [ 8.8468,  0.0420])
# ------calling energy function------
# x tensor([ 0.3314,  0.0224])
# tensor(1.00000e-03 *
#        6.2388)
# px tensor(0.1506)
# result tensor(1.00000e-04 *
#        9.3964)
# g:tensor(1.00000e-02 *
#        [ 9.3490,  0.0495])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3314,  0.0224])
# tensor(1.00000e-03 *
#        6.2388)
# px tensor(0.1506)
# result tensor(1.00000e-04 *
#        9.3964)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3314,  0.0224])
# tensor(1.00000e-03 *
#        6.2388)
# px tensor(0.1506)
# result tensor(1.00000e-04 *
#        9.3964)
# Sample: 1194
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.3314,  0.0224])
# tensor(1.00000e-03 *
#        6.2388)
# px tensor(0.1506)
# result tensor(1.00000e-04 *
#        9.3964)
# g:tensor(1.00000e-02 *
#        [ 9.3490,  0.0495])
# ------calling energy function------
# x tensor([ 0.3370,  0.0237])
# tensor(1.00000e-03 *
#        6.7013)
# px tensor(0.1503)
# result tensor(1.00000e-03 *
#        1.0074)
# g:tensor(1.00000e-02 *
#        [ 9.6392,  0.0555])
# ------calling energy function------
# x tensor([ 0.3423,  0.0251])
# tensor(1.00000e-03 *
#        7.1919)
# px tensor(0.1501)
# result tensor(1.00000e-03 *
#        1.0791)
# g:tensor(1.00000e-02 *
#        [ 9.9223,  0.0623])
# ------calling energy function------
# x tensor([ 0.3474,  0.0266])
# tensor(1.00000e-03 *
#        7.7118)
# px tensor(0.1498)
# result tensor(1.00000e-03 *
#        1.1551)
# g:tensor([ 0.1020,  0.0007])
# ------calling energy function------
# x tensor([ 0.3523,  0.0282])
# tensor(1.00000e-03 *
#        8.2620)
# px tensor(0.1495)
# result tensor(1.00000e-03 *
#        1.2353)
# g:tensor([ 0.1046,  0.0008])
# ------calling energy function------
# x tensor([ 0.3569,  0.0299])
# tensor(1.00000e-03 *
#        8.8436)
# px tensor(0.1493)
# result tensor(1.00000e-03 *
#        1.3200)
# g:tensor([ 0.1071,  0.0009])
# ------calling energy function------
# x tensor([ 0.3613,  0.0317])
# tensor(1.00000e-03 *
#        9.4576)
# px tensor(0.1490)
# result tensor(1.00000e-03 *
#        1.4094)
# g:tensor([ 0.1096,  0.0010])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3613,  0.0317])
# tensor(1.00000e-03 *
#        9.4576)
# px tensor(0.1490)
# result tensor(1.00000e-03 *
#        1.4094)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3613,  0.0317])
# tensor(1.00000e-03 *
#        9.4576)
# px tensor(0.1490)
# result tensor(1.00000e-03 *
#        1.4094)
# Sample: 1195
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.3613,  0.0317])
# tensor(1.00000e-03 *
#        9.4576)
# px tensor(0.1490)
# result tensor(1.00000e-03 *
#        1.4094)
# g:tensor([ 0.1096,  0.0010])
# ------calling energy function------
# x tensor([ 0.3302,  0.0334])
# tensor(1.00000e-03 *
#        9.2289)
# px tensor(0.1506)
# result tensor(1.00000e-03 *
#        1.3901)
# g:tensor(1.00000e-02 *
#        [ 9.2852,  0.1095])
# ------calling energy function------
# x tensor([ 0.3011,  0.0351])
# tensor(1.00000e-03 *
#        8.9780)
# px tensor(0.1520)
# result tensor(1.00000e-03 *
#        1.3647)
# g:tensor(1.00000e-02 *
#        [ 7.8300,  0.1213])
# ------calling energy function------
# x tensor([ 0.2741,  0.0370])
# tensor(1.00000e-03 *
#        8.7086)
# px tensor(0.1532)
# result tensor(1.00000e-03 *
#        1.3340)
# g:tensor(1.00000e-02 *
#        [ 6.5718,  0.1344])
# ------calling energy function------
# x tensor([ 0.2491,  0.0390])
# tensor(1.00000e-03 *
#        8.4240)
# px tensor(0.1542)
# result tensor(1.00000e-03 *
#        1.2988)
# g:tensor(1.00000e-02 *
#        [ 5.4915,  0.1488])
# ------calling energy function------
# x tensor([ 0.2260,  0.0410])
# tensor(1.00000e-03 *
#        8.1276)
# px tensor(0.1550)
# result tensor(1.00000e-03 *
#        1.2599)
# g:tensor(1.00000e-02 *
#        [ 4.5702,  0.1648])
# ------calling energy function------
# x tensor([ 0.2047,  0.0432])
# tensor(1.00000e-03 *
#        7.8226)
# px tensor(0.1557)
# result tensor(1.00000e-03 *
#        1.2181)
# g:tensor(1.00000e-02 *
#        [ 3.7891,  0.1825])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.2047,  0.0432])
# tensor(1.00000e-03 *
#        7.8226)
# px tensor(0.1557)
# result tensor(1.00000e-03 *
#        1.2181)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.2047,  0.0432])
# tensor(1.00000e-03 *
#        7.8226)
# px tensor(0.1557)
# result tensor(1.00000e-03 *
#        1.2181)
# Sample: 1196
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.2047,  0.0432])
# tensor(1.00000e-03 *
#        7.8226)
# px tensor(0.1557)
# result tensor(1.00000e-03 *
#        1.2181)
# g:tensor(1.00000e-02 *
#        [ 3.7891,  0.1825])
# ------calling energy function------
# x tensor([ 0.2467,  0.0450])
# tensor(1.00000e-03 *
#        9.6215)
# px tensor(0.1542)
# result tensor(1.00000e-03 *
#        1.4839)
# g:tensor(1.00000e-02 *
#        [ 5.3927,  0.1981])
# ------calling energy function------
# x tensor([ 0.2959,  0.0469])
# tensor(1.00000e-02 *
#        1.1741)
# px tensor(0.1522)
# result tensor(1.00000e-03 *
#        1.7866)
# g:tensor(1.00000e-02 *
#        [ 7.5811,  0.2150])
# ------calling energy function------
# x tensor([ 0.3532,  0.0489])
# tensor(1.00000e-02 *
#        1.4201)
# px tensor(0.1494)
# result tensor(1.00000e-03 *
#        2.1209)
# g:tensor([ 0.1051,  0.0023])
# ------calling energy function------
# x tensor([ 0.4190,  0.0510])
# tensor(1.00000e-02 *
#        1.7009)
# px tensor(0.1456)
# result tensor(1.00000e-03 *
#        2.4763)
# g:tensor([ 0.1435,  0.0025])
# ------calling energy function------
# x tensor([ 0.4939,  0.0531])
# tensor(1.00000e-02 *
#        2.0160)
# px tensor(0.1407)
# result tensor(1.00000e-03 *
#        2.8362)
# g:tensor([ 0.1925,  0.0027])
# ------calling energy function------
# x tensor([ 0.5778,  0.0553])
# tensor(1.00000e-02 *
#        2.3630)
# px tensor(0.1345)
# result tensor(1.00000e-03 *
#        3.1778)
# g:tensor([ 0.2536,  0.0030])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.5778,  0.0553])
# tensor(1.00000e-02 *
#        2.3630)
# px tensor(0.1345)
# result tensor(1.00000e-03 *
#        3.1778)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.5778,  0.0553])
# tensor(1.00000e-02 *
#        2.3630)
# px tensor(0.1345)
# result tensor(1.00000e-03 *
#        3.1778)
# Sample: 1197
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.5778,  0.0553])
# tensor(1.00000e-02 *
#        2.3630)
# px tensor(0.1345)
# result tensor(1.00000e-03 *
#        3.1778)
# g:tensor([ 0.2536,  0.0030])
# ------calling energy function------
# x tensor([ 0.5242,  0.0507])
# tensor(1.00000e-02 *
#        2.0181)
# px tensor(0.1385)
# result tensor(1.00000e-03 *
#        2.7960)
# g:tensor([ 0.2139,  0.0025])
# ------calling energy function------
# x tensor([ 0.4737,  0.0465])
# tensor(1.00000e-02 *
#        1.7140)
# px tensor(0.1421)
# result tensor(1.00000e-03 *
#        2.4357)
# g:tensor([ 0.1787,  0.0021])
# ------calling energy function------
# x tensor([ 0.4265,  0.0426])
# tensor(1.00000e-02 *
#        1.4478)
# px tensor(0.1452)
# result tensor(1.00000e-03 *
#        2.1021)
# g:tensor([ 0.1481,  0.0018])
# ------calling energy function------
# x tensor([ 0.3826,  0.0390])
# tensor(1.00000e-02 *
#        1.2166)
# px tensor(0.1478)
# result tensor(1.00000e-03 *
#        1.7983)
# g:tensor([ 0.1216,  0.0015])
# ------calling energy function------
# x tensor([ 0.3422,  0.0357])
# tensor(1.00000e-02 *
#        1.0173)
# px tensor(0.1500)
# result tensor(1.00000e-03 *
#        1.5261)
# g:tensor(1.00000e-02 *
#        [ 9.9161,  0.1255])
# ------calling energy function------
# x tensor([ 0.3051,  0.0327])
# tensor(1.00000e-03 *
#        8.4671)
# px tensor(0.1518)
# result tensor(1.00000e-03 *
#        1.2856)
# g:tensor(1.00000e-02 *
#        [ 8.0244,  0.1054])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.3051,  0.0327])
# tensor(1.00000e-03 *
#        8.4671)
# px tensor(0.1518)
# result tensor(1.00000e-03 *
#        1.2856)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3051,  0.0327])
# tensor(1.00000e-03 *
#        8.4671)
# px tensor(0.1518)
# result tensor(1.00000e-03 *
#        1.2856)
# Sample: 1198
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.3051,  0.0327])
# tensor(1.00000e-03 *
#        8.4671)
# px tensor(0.1518)
# result tensor(1.00000e-03 *
#        1.2856)
# g:tensor(1.00000e-02 *
#        [ 8.0244,  0.1054])
# ------calling energy function------
# x tensor([ 0.2595,  0.0320])
# tensor(1.00000e-03 *
#        7.2085)
# px tensor(0.1538)
# result tensor(1.00000e-03 *
#        1.1087)
# g:tensor(1.00000e-02 *
#        [ 5.9319,  0.1011])
# ------calling energy function------
# x tensor([ 0.2199,  0.0314])
# tensor(1.00000e-03 *
#        6.0968)
# px tensor(0.1553)
# result tensor(1.00000e-04 *
#        9.4670)
# g:tensor(1.00000e-02 *
#        [ 4.3396,  0.0969])
# ------calling energy function------
# x tensor([ 0.1856,  0.0307])
# tensor(1.00000e-03 *
#        5.1262)
# px tensor(0.1564)
# result tensor(1.00000e-04 *
#        8.0155)
# g:tensor(1.00000e-02 *
#        [ 3.1455,  0.0929])
# ------calling energy function------
# x tensor([ 0.1563,  0.0301])
# tensor(1.00000e-03 *
#        4.2878)
# px tensor(0.1572)
# result tensor(1.00000e-04 *
#        6.7383)
# g:tensor(1.00000e-02 *
#        [ 2.2616,  0.0891])
# ------calling energy function------
# x tensor([ 0.1313,  0.0295])
# tensor(1.00000e-03 *
#        3.5702)
# px tensor(0.1577)
# result tensor(1.00000e-04 *
#        5.6309)
# g:tensor(1.00000e-02 *
#        [ 1.6147,  0.0855])
# ------calling energy function------
# x tensor([ 0.1100,  0.0288])
# tensor(1.00000e-03 *
#        2.9609)
# px tensor(0.1581)
# result tensor(1.00000e-04 *
#        4.6821)
# g:tensor(1.00000e-02 *
#        [ 1.1459,  0.0820])
# ========== 2nd hamiltonian ==============
# x tensor([ 0.1100,  0.0288])
# tensor(1.00000e-03 *
#        2.9609)
# px tensor(0.1581)
# result tensor(1.00000e-04 *
#        4.6821)
# ========== 3rd hamiltonian ==============
# x tensor([ 0.3051,  0.0327])
# tensor(1.00000e-03 *
#        8.4671)
# px tensor(0.1518)
# result tensor(1.00000e-03 *
#        1.2856)
# Sample: 1199
# ========== simulate ==============
# ------calling energy function------
# x tensor([ 0.3051,  0.0327])
# tensor(1.00000e-03 *
#        8.4671)
# px tensor(0.1518)
# result tensor(1.00000e-03 *
#        1.2856)
# g:tensor(1.00000e-02 *
#        [ 8.0244,  0.1054])
# ------calling energy function------
# x tensor([ 0.2948,  0.0314])
# tensor(1.00000e-03 *
#        7.8908)
# px tensor(0.1523)
# result tensor(1.00000e-03 *
#        1.2019)
# g:tensor(1.00000e-02 *
#        [ 7.5277,  0.0970])
# ------calling energy function------
# x tensor([ 0.2846,  0.0301])
# tensor(1.00000e-03 *
#        7.3470)
# px tensor(0.1528)
# result tensor(1.00000e-03 *
#        1.1224)
# g:tensor(1.00000e-02 *
#        [ 7.0499,  0.0893])
# ------calling energy function------
# x tensor([ 0.2746,  0.0289])
# tensor(1.00000e-03 *
#        6.8345)
# px tensor(0.1532)
# result tensor(1.00000e-03 *
#        1.0471)
# g:tensor(1.00000e-02 *
#        [ 6.5917,  0.0822])
# ------calling energy function------
# x tensor([ 0.2646,  0.0277])
# tensor(1.00000e-03 *
#        6.3521)
# px tensor(0.1536)
# result tensor(1.00000e-04 *
#        9.7581)
# g:tensor(1.00000e-02 *
#        [ 6.1536,  0.0757])
# ------calling energy function------
# x tensor([ 0.2549,  0.0266])
# tensor(1.00000e-03 *
#        5.8989)
# px tensor(0.1540)
# result tensor(1.00000e-04 *
#        9.0850)
# g:tensor(1.00000e-02 *
#        [ 5.7359,  0.0696])
# ------calling energy function------
# x tensor([ 0.2454,  0.0255])
# tensor(1.00000e-03 *
#        5.4735)
# px tensor(0.1544)
# result tensor(1.00000e-04 *
#        8.4502)

# %%
pos_samples.shape

# %%
num = pos_samples.shape[0]
y1_list = []
y2_list = []
for i in range(num):
    y1_list.append(pos_samples[i][0].item())
    y2_list.append(pos_samples[i][1].item())
x1_list = [np.log(1+np.exp(e)) for e in y1_list]
x2_list = [np.log(1+np.exp(e)) for e in y2_list]
#plt.hist(x_list)
#plt.show()

# %%
h = plt.hist2d(x1_list, x2_list, bins = [200, 200])

# %%
from autograd import grad
def test(x):
    return np.mean(x)

# %%
gg = grad(test)
gg(np.array([1,1]))
# Out:
# array([ 0.5,  0.5])

# %%
from torch.autograd.gradcheck import zero_gradients
def compute_jacobian(inputs, output):
	"""
	:param inputs: Batch X Size (e.g. Depth X Width X Height)
	:param output: Batch X Classes
	:return: jacobian: Batch X Classes X Size
	"""
	assert inputs.requires_grad

	num_classes = output.size()[1]

	jacobian = torch.zeros(num_classes, *inputs.size())
	grad_output = torch.zeros(*output.size())
	if inputs.is_cuda:
		grad_output = grad_output.cuda()
		jacobian = jacobian.cuda()

	for i in range(num_classes):
		zero_gradients(inputs)
		grad_output.zero_()
		grad_output[:, i] = 1
		output.backward(grad_output, retain_graph = True)
		jacobian[i] = inputs.grad.data

	return torch.transpose(jacobian, dim0=0, dim1=1)

# %%
x = torch.tensor([1.,2.,3.], requires_grad=True)
tmp = torch.zeros(1,3, requires_grad=True)
tmp.data[0] = x.data
y = transform(tmp)
y
# Out:
# tensor([[ 1.3133,  2.1269,  3.0486]])

# %%
z = compute_jacobian(tmp, y)

# %%
x.shape[0]
# Out:
# 3

# %%
torch.det(z)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-40145bc38d4d> in <module>()
# ----> 1 torch.det(z)
#
# RuntimeError: det(torch.FloatTensor{[1, 3, 3]}): expected a 2D square tensor of floating types
